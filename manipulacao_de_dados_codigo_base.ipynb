# %% [markdown]
# ## **Pandas Essencial**
# **Prof. Dr. Samuel Martins (@hisamuka @xavecoding)** <br/>
# xavecoding: https://youtube.com/c/xavecoding <br/>
#
# Neste tutorial, vamos aprender o essencial da biblioteca _Pandas_ para manipulação de dados.<br/><br/>
#
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %% [markdown]
# ### Pacotes usados neste Notebook

# %%
# pacotes usados neste notebook
import pandas as pd

# %% [markdown]
# <h1>Manipulação de Dados com Pandas</h1><hr/>

# %% [markdown]
# <h2>1. Manipulação Básica de Datasets</h2>
# <hr/>

# %% [markdown]
# **Dataset**: Gas Prices in Brazil: https://www.kaggle.com/matheusfreitag/gas-prices-in-brazil <br/>
#
# Este dataset contém os **registros dos preços médios semanais dos combustíveis do Brasil entre os anos de 2004 e 2019**. <br/>
# Cada *amostra (registro/linha)* consiste em um registro de preço aferido para um dado tipo de combustível em uma dada localidade do Brasil. <br/>
# Alguns dos principais *atributos* (colunas) do dataset são: 'ESTADO', 'PRODUTO', 'NÚMERO DE POSTOS PESQUISADOS', 'PREÇO MÉDIO REVENDA'.
#
#
# \* O arquivo disponibilizado no Kaggle está no formato *tsv*. Embora o _pandas_ consiga abrí-lo normalmente, convertemos tal arquivo para o formato *CSV*, que é um dos formatos mais utilizados, e mudamos seu separado para ';' apenas para mostrar algumas opções da função de carregamento.

# %% [markdown]
# ### 1.1. Importando o Dataset
# Para carregar um dataset no formato csv, basta utilizar a função `read_csv` do pandas. Por padrão, ela considera _','_ como separador.

# %%
data = pd.read_csv('./datasets/GasPricesinBrazil_2004-2019.csv')

# %%
data
# Out:
#        Unnamed: 0;DATA INICIAL;DATA FINAL;REGIÃO;ESTADO;PRODUTO;NÚMERO DE POSTOS PESQUISADOS;UNIDADE DE MEDIDA;PREÇO MÉDIO REVENDA;DESVIO PADRÃO REVENDA;PREÇO MÍNIMO REVENDA;PREÇO MÁXIMO REVENDA;MARGEM MÉDIA REVENDA;COEF DE VARIAÇÃO REVENDA;PREÇO MÉDIO DISTRIBUIÇÃO;DESVIO PADRÃO DISTRIBUIÇÃO;PREÇO MÍNIMO DISTRIBUIÇÃO;PREÇO MÁXIMO DISTRIBUIÇÃO;COEF DE VARIAÇÃO DISTRIBUIÇÃO;MÊS;ANO
# 0       0;2004-05-09;2004-05-15;CENTRO OESTE;DISTRITO ...
# 1       1;2004-05-09;2004-05-15;CENTRO OESTE;GOIAS;ETA...
# 2       2;2004-05-09;2004-05-15;CENTRO OESTE;MATO GROS...
# 3       3;2004-05-09;2004-05-15;CENTRO OESTE;MATO GROS...
# 4       4;2004-05-09;2004-05-15;NORDESTE;ALAGOAS;ETANO...
# ...                                                   ...
# 106818  106818;2019-06-23;2019-06-29;NORDESTE;RIO GRAN...
# 106819  106819;2019-06-23;2019-06-29;SUL;RIO GRANDE DO...
# 106820  106820;2019-06-23;2019-06-29;SUL;SANTA CATARIN...
# 106821  106821;2019-06-23;2019-06-29;SUDESTE;SAO PAULO...
# 106822  106822;2019-06-23;2019-06-29;NORDESTE;SERGIPE;...
#
# [106823 rows x 1 columns]

# %% [markdown]
# O dataset não foi carregado corretamente pois o separador utilizado seu arquivo CSV era ';' e não a ','. <br/>
# Vamos então carregá-lo corretamente:

# %%
# Carregando o dataset corretamente -> nesse caso usou separador ';'
data = pd.read_csv('./datasets/GasPricesinBrazil_2004-2019.csv', sep=';')

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %% [markdown]
# ### 1.2. Exibindo as primeiras linhas do Dataset
# A função `.head()` exibe as 5 primeiras linhas do dataset/tabela/Data Frame.

# %%
# por padrão as 5 primeiras linhas
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
# retorna as 10 primeiras linhas do dataset
data.head(10)
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6           6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7           7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8           8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9           9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
# 6  ETANOL HIDRATADO                           278              R$/l
# 7  ETANOL HIDRATADO                           105              R$/l
# 8  ETANOL HIDRATADO                           125              R$/l
# 9  ETANOL HIDRATADO                           423              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
# 5                1.383                  0.132  ...                 2.050
# 6                1.453                  0.218  ...                 1.950
# 7                1.631                  0.158  ...                 2.000
# 8                1.284                  0.130  ...                 1.699
# 9                1.224                  0.141  ...                 1.700
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
# 5                 0.426                    0.095                     0.957
# 6                 0.353                    0.150                       1.1
# 7                 0.515                    0.097                     1.116
# 8                 0.353                    0.101                     0.931
# 9                 0.277                    0.115                     0.947
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
# 5                      0.128                    0.5686
# 6                      0.068                    0.7332
# 7                      0.091                    0.9923
# 8                      0.072                    0.7577
# 9                      0.091                    0.5643
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
# 5                      1.35                         0.134   5  2004
# 6                     1.294                         0.062   5  2004
# 7                   1.36183                         0.082   5  2004
# 8                    1.2972                         0.077   5  2004
# 9                    1.3541                         0.096   5  2004
#
# [10 rows x 21 columns]

# %% [markdown]
# ### 1.3 Informações do Dataset e Elementos Chave

# %% [markdown]
# ### 1.3.1 Informações gerais sobre o Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  object
#  2   DATA FINAL                     106823 non-null  object
#  3   REGIÃO                         106823 non-null  object
#  4   ESTADO                         106823 non-null  object
#  5   PRODUTO                        106823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  object
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  12  MARGEM MÉDIA REVENDA           106823 non-null  object
#  13  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  14  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  object
#  15  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  object
#  16  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  object
#  17  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  object
#  18  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  object
#  19  MÊS                            106823 non-null  int64
#  20  ANO                            106823 non-null  int64
# dtypes: float64(5), int64(4), object(12)
# memory usage: 17.1+ MB

# %% [markdown]
# A primeira coluna da tabela, chamada _'Unnamed: 0'_, parece não significar nada. Na verdade, ela parece ser os **índices** da tabela, que foram salvos como uma _coluna_.<br/>
# Veremos jajá como **remover tal coluna**.
#
# Outro ponto é que, aparentemente, nenhum atributo/coluna possui valores nulos (_null_), uma vez que o número de registros do dataframe e os números de valores _non-null_ é de **106823**. <br/>
# Mas, veremos que não é bem assim para esse caso.

# %% [markdown]
# ### 1.3.2 Data Frame
# Todo dataset carregado (dados estruturados) é um `Data Frame`: 'Tabela' bi-dimensional, de tamanho mutável, com dados potencialmente heterogêneos. <br/>

# %%
# todo dataset é de fato um DataFrame, carregado da memória.
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Podemos acessar as **dimensões do Data Frame** (número de linhas x número de colunas) utilizando o atributo `.shape` do Data Frame.

# %%
# é uma tupla
data.shape
# Out:
# (106823, 21)

# %%
print(
    f'O DataFrame possui {data.shape[0]} linhas/observações/registros e {data.shape[1]} colunas/atributos/variáveis.'
)

# %% [markdown]
# #### **Criando um DataFrame**
#
# Podemos criar um DataFrame a partir de um _dicionário_, onde cada **chave** possui uma **lista de elementos de igual tamanho**.<br/>
# As **chaves** representam as **colunas** e **cada um dos valores de sua lista** representa o **valor da linha** correspondente para aquela coluna.

# %%
alunos_df = pd.DataFrame(
    {
        'nome': ['Luke Skywalker', 'Yoda', 'Palpatine'],
        'idade': [16, 1000, 70],
        'peso': [70, 15, 60],
        'eh jedi': [True, True, False],  # o nome das colunas podem ter espaços
    }
)

# %%
alunos_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16    70     True
# 1            Yoda   1000    15     True
# 2       Palpatine     70    60    False

# %%
alunos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nome     3 non-null      object
#  1   idade    3 non-null      int64
#  2   peso     3 non-null      int64
#  3   eh jedi  3 non-null      bool
# dtypes: bool(1), int64(2), object(1)
# memory usage: 207.0+ bytes

# %%
# contatos - dataset (extra)
# index,    nome, idade,  telefone,              e-mail, salário
#     0,  samuka,    30, 321654789,   samuka@samuka.com, 2530.78
#     1,  marcos,    27, 123789654,   marcos@marcos.com, 6845.63
#     2, willian,    42, 986547825, willian@willian.com, 9245.63

# transformando/convertido
contato = {
    'nome': ['samuka', 'marcos', 'willian'],
    'idade': [30, 27, 42],
    'telefone': [321654789, 123789654, 986547825],
    'e-mail': [
        'samuka@samuka.com',
        'marcos@marcos.com',
        'willian@willian.com',
    ],
    'salário': [2530.78, 6845.63, 9245.63],
}

# em DataFrame
df = pd.DataFrame(contato)

# %%
df
# Out:
#       nome  idade   telefone               e-mail  salário
# 0   samuka     30  321654789    samuka@samuka.com  2530.78
# 1   marcos     27  123789654    marcos@marcos.com  6845.63
# 2  willian     42  986547825  willian@willian.com  9245.63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   nome      3 non-null      object
#  1   idade     3 non-null      int64
#  2   telefone  3 non-null      int64
#  3   e-mail    3 non-null      object
#  4   salário   3 non-null      float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 252.0+ bytes

# %%
# com índices para os atributos/colunas (extra)
df = pd.DataFrame(contato, index=['a', 'b', 'c'])

# %%
df
# Out:
#       nome  idade   telefone               e-mail  salário
# a   samuka     30  321654789    samuka@samuka.com  2530.78
# b   marcos     27  123789654    marcos@marcos.com  6845.63
# c  willian     42  986547825  willian@willian.com  9245.63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, a to c
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   nome      3 non-null      object
#  1   idade     3 non-null      int64
#  2   telefone  3 non-null      int64
#  3   e-mail    3 non-null      object
#  4   salário   3 non-null      float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 144.0+ bytes

# %%
# por colunas (extra)
df = pd.DataFrame(contato, columns=['nome', 'salário'])

# %%
df
# Out:
#       nome  salário
# 0   samuka  2530.78
# 1   marcos  6845.63
# 2  willian  9245.63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nome     3 non-null      object
#  1   salário  3 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 180.0+ bytes

# %%
# com ambos, indice e colunas
df = pd.DataFrame(contato, index=['a', 'b', 'c'], columns=['nome', 'salário'])

# %%
df
# Out:
#       nome  salário
# a   samuka  2530.78
# b   marcos  6845.63
# c  willian  9245.63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, a to c
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nome     3 non-null      object
#  1   salário  3 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 72.0+ bytes

# %% [markdown]
# #### **VEJA MAIS**
# Criando um Data Frame a partir de um dicionário: https://www.geeksforgeeks.org/how-to-create-dataframe-from-dictionary-in-python-pandas/

# %% [markdown]
# #### **Renomeando as colunas de um DataFrame**
# **===>** O método `DataFrame.columns` retorna uma ";lista" com os **nomes de todas as colunas** do data frame.

# %%
# retorna um indice com a lista
df.columns
# Out:
# Index(['nome', 'idade', 'telefone', 'e-mail', 'salário'], dtype='object')

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
# agora retorna a lista das colunas na ordem
list(df.columns)
# Out:
# ['nome', 'idade', 'telefone', 'e-mail', 'salário']

# %% [markdown]
# <br/>
#
# **===>** Para **renomear colunas** do data frame, utilize o método `DataFrame.rename`, que retorna uma _cópia_ do data frame com as as colunas renomeadas:

# %%
df
# Out:
#       nome  idade   telefone               e-mail  salário
# 0   samuka     30  321654789    samuka@samuka.com  2530.78
# 1   marcos     27  123789654    marcos@marcos.com  6845.63
# 2  willian     42  986547825  willian@willian.com  9245.63

# %%
# cria uma cópia, então nao altera o original
df_copy = df.rename(
    columns={
        'nome': 'Nome Completo',  # renomei de 'nome' para 'Nome Completo'
        'idade': 'Idade',
        'telefone': 'Telefone Contado',
        'e-mail': 'E-mail',
        'salário': 'Salário',
    },
)

# %%
df_copy
# Out:
#   Nome Completo  Idade  Telefone Contado               E-mail  Salário
# 0        samuka     30         321654789    samuka@samuka.com  2530.78
# 1        marcos     27         123789654    marcos@marcos.com  6845.63
# 2       willian     42         986547825  willian@willian.com  9245.63

# %%
# permanece sem alterações
df
# Out:
#       nome  idade   telefone               e-mail  salário
# 0   samuka     30  321654789    samuka@samuka.com  2530.78
# 1   marcos     27  123789654    marcos@marcos.com  6845.63
# 2  willian     42  986547825  willian@willian.com  9245.63

# %% [markdown]
# Para renomear o _próprio_ data frame em questão, utilize o parâmetro `inplace=True`:

# %%
# caso queira sem ser uma cópia, passa o inplace True
df.rename(
    columns={
        'nome': 'Nome Completo',
        'idade': 'Idade',
        'salário': 'Salário',
    },
    inplace=True,  # aqui ele vai alterar
)

# %%
# modificado direto no DataFrame
df
# Out:
#   Nome Completo  Idade   telefone               e-mail  Salário
# 0        samuka     30  321654789    samuka@samuka.com  2530.78
# 1        marcos     27  123789654    marcos@marcos.com  6845.63
# 2       willian     42  986547825  willian@willian.com  9245.63

# %% [markdown]
# <br/>
#
# **===>** Uma outra forma de **renomear todas as listas** de um data frame é passar uma _lista_ com os novos nomes das colunas para o atributo `DataFrame.columns`:

# %%
# remomeia os atributos/colunas
df.columns

# %%
# recebe uma lisata com os novos nomes respectivamentes
df.columns = ['NOME', 'IDADE', 'FONE', 'E-MAIL', 'SALARIO']

# %%
df
# Out:
#       NOME  IDADE       FONE               E-MAIL  SALARIO
# 0   samuka     30  321654789    samuka@samuka.com  2530.78
# 1   marcos     27  123789654    marcos@marcos.com  6845.63
# 2  willian     42  986547825  willian@willian.com  9245.63

# %% [markdown]
# ### 1.3.3 Series

# %% [markdown]
# Array uni-dimensional com os dados e rótulos de um eixo.

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
# acessando toda coluna Estado
data['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
# Essa forma é apenas para atributos que nao tenha, caracteres especiais e ou tenham espaços
data.ESTADO
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
# É uma Series
type(data['ESTADO'])
# Out:
# pandas.core.series.Series

# %%
type(data.ESTADO)
# Out:
# pandas.core.series.Series

# %%
# Seleciona a observação/linha indexada no indice [1] do DataFrame
# indice de localização
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# Name: 1, dtype: object

# %%
# também é uma Series
type(data.iloc[1])
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### **Criando uma Series**
#
# Podemos criar um DataFrame a partir de uma lista de elementos.

# %%
# cria a propria Series
pd.Series([6.9, 9.4, 8])
# Out:
# 0    6.9
# 1    9.4
# 2    8.0
# dtype: float64

# %% [markdown]
# Podemos alterar o **nome dos índices** (veremos melhor jajá) e o **nome da Series** (o que ela representa):

# %%
# nome para os indices e Series
pd.Series(
    [6.9, 9.4, 8], index=['Português', 'Matemática', 'Inglês'], name='Nota dos Alunos'
)
# Out:
# Português     6.9
# Matemática    9.4
# Inglês        8.0
# Name: Nota dos Alunos, dtype: float64

# %%
# também tem essa forma (Extra)
ex = {
    "Português": 6.9,
    "Matemática": 9.4,
    "Inglês": 8,
}
pd.Series(ex, name='Notas Bimestrais')
# Out:
# Português     6.9
# Matemática    9.4
# Inglês        8.0
# Name: Notas Bimestrais, dtype: float64

# %%
# também um novo Index (NaN) (Extra)
ex = {
    "Português": 6.9,
    "Matemática": 9.4,
    "Inglês": 8,
}
pd.Series(
    ex, index=['Português', 'Matemática', 'Hosória', 'Inglês'], name='Notas Bimestrais'
)
# Out:
# Português     6.9
# Matemática    9.4
# Hosória       NaN
# Inglês        8.0
# Name: Notas Bimestrais, dtype: float64

# %% [markdown]
# #### **VEJA MAIS**
# https://pandas.pydata.org/pandas-docs/stable/user_guide/dsintro.html

# %% [markdown]
# ### 1.3.4 Atribuindo Dados

# %% [markdown]
# #### 1.3.4.1 Atribuindo constantes

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
produto_view = data[
    'PRODUTO'
]  # Series retornando referencia a coluna, NAO UMA COPIA, mas sim uma REFERENCIA/VIEW a coluna do dataframe

# %%
produto_view
# Out:
# 0         Combustível
# 1         Combustível
# 2         Combustível
# 3         Combustível
# 4         Combustível
#              ...
# 106818    Combustível
# 106819    Combustível
# 106820    Combustível
# 106821    Combustível
# 106822    Combustível
# Name: PRODUTO, Length: 106823, dtype: object

# %%
# pode ser de ambas as formas desde que nao tenha espaços ou acentos
# produto_copy = data.PRODUTO.copy()
produto_copy_bkp = data['PRODUTO'].copy()

# %%
produto_copy_bkp
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
# atribuido o valor a cada linha/observacao do dataframe na coluna PRODUTO
data['PRODUTO'] = 'Combustível'

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#        PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  Combustível                           127              R$/l
# 1  Combustível                           387              R$/l
# 2  Combustível                           192              R$/l
# 3  Combustível                           162              R$/l
# 4  Combustível                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
produto_view
# Out:
# 0         Combustível
# 1         Combustível
# 2         Combustível
# 3         Combustível
# 4         Combustível
#              ...
# 106818    Combustível
# 106819    Combustível
# 106820    Combustível
# 106821    Combustível
# 106822    Combustível
# Name: PRODUTO, Length: 106823, dtype: object

# %%
produto_copy_bkp
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %% [markdown]
# #### 1.3.4.2 Atribuindo listas ou series

# %%
nrows, ncols = data.shape
nrows, ncols
# Out:
# (106823, 21)

# %%
novo_produto = [f'Produto {x}' for x in range(nrows)]
len(novo_produto)
# Out:
# 106823

# %%
# a quantidade a nova lista é igual do numero de linha do dataframe
data.PRODUTO = novo_produto

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO         PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL       Produto 0                           127
# 1                     GOIAS       Produto 1                           387
# 2               MATO GROSSO       Produto 2                           192
# 3        MATO GROSSO DO SUL       Produto 3                           162
# 4                   ALAGOAS       Produto 4                           103
# ...                     ...             ...                           ...
# 106818  RIO GRANDE DO NORTE  Produto 106818                             7
# 106819    RIO GRANDE DO SUL  Produto 106819                            23
# 106820       SANTA CATARINA  Produto 106820                            24
# 106821            SAO PAULO  Produto 106821                            52
# 106822              SERGIPE  Produto 106822                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %%
print(produto_view)
print('\n')
print(produto_copy_bkp)
# Out:
# 0         Combustível
# 1         Combustível
# 2         Combustível
# 3         Combustível
# 4         Combustível
#              ...
# 106818    Combustível
# 106819    Combustível
# 106820    Combustível
# 106821    Combustível
# 106822    Combustível
# Name: PRODUTO, Length: 106823, dtype: object
#
#
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
# voltando para os produtos originais
data.PRODUTO = produto_copy_bkp  # pruduto_copy tbm é uma Series

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %% [markdown]
# #### 1.3.4.3 Criando novas colunas
# Para **criar uma nova coluna** em um data frame, basta atribuirmos uma _lista/Series de valores_ a uma **nova 'chave'** do data frame. <br/>
#
# **PS:** A _quantidade de valores_ da lista precisa ser **igual** ao _número de linhas/registros_ do data frame.

# %%
# cria uma coluna a parti de um valor constante/default
# todas a linhas terão o mesmo valor na nova coluna
data['sem nocao'] = 'DEFAULT'
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      0.463                     0.012
# 1                      0.399                     0.098
# 2                      0.419                     0.070
# 3                      0.432                     0.055
# 4                       0.24                     0.066
# ...                      ...                       ...
# 106818                 0.818                     0.018
# 106819                  0.95                     0.038
# 106820                 0.914                     0.065
# 106821                 0.646                     0.076
# 106822                 1.179                     0.001
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                        0.11
# 1                         0.763                       0.088
# 2                          0.97                       0.095
# 3                          0.83                       0.119
# 4                         0.941                       0.077
# ...                         ...                         ...
# 106818                    2.756                           0
# 106819                    2.451                       0.402
# 106820                    1.998                           0
# 106821                    2.374                       0.165
# 106822                    2.518                           0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  sem nocao
# 0                              0.133   5  2004    DEFAULT
# 1                              0.115   5  2004    DEFAULT
# 2                              0.098   5  2004    DEFAULT
# 3                              0.143   5  2004    DEFAULT
# 4                              0.082   5  2004    DEFAULT
# ...                              ...  ..   ...        ...
# 106818                             0   6  2019    DEFAULT
# 106819                         0.164   6  2019    DEFAULT
# 106820                             0   6  2019    DEFAULT
# 106821                          0.07   6  2019    DEFAULT
# 106822                             0   6  2019    DEFAULT
#
# [106823 rows x 22 columns]

# %%
data.shape[0]  # numero de linhas/observacao
# Out:
# 106823

# %%
data.shape[1]  # numero de colunas/atrinuto
# Out:
# 22

# %%
# a parti de uma lista
data['de uma lista'] = range(data.shape[0])  # shape[0] contem todoas a linha (tupla)
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                          0.012                     0.825
# 1                          0.098                     0.763
# 2                          0.070                      0.97
# 3                          0.055                      0.83
# 4                          0.066                     0.941
# ...                          ...                       ...
# 106818                     0.018                     2.756
# 106819                     0.038                     2.451
# 106820                     0.065                     1.998
# 106821                     0.076                     2.374
# 106822                     0.001                     2.518
#
#        DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                            0.11                     0.4201
# 1                           0.088                     0.5013
# 2                           0.095                     0.5614
# 3                           0.119                     0.5991
# 4                           0.077                     0.7441
# ...                           ...                        ...
# 106818                          0                      2.756
# 106819                      0.402                     1.9842
# 106820                          0                     1.9981
# 106821                      0.165                     2.0179
# 106822                          0                     2.5175
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                         0.9666                         0.133   5  2004
# 1                           1.05                         0.115   5  2004
# 2                          1.161                         0.098   5  2004
# 3                        1.22242                         0.143   5  2004
# 4                         1.0317                         0.082   5  2004
# ...                          ...                           ...  ..   ...
# 106818                     2.756                             0   6  2019
# 106819                    2.8661                         0.164   6  2019
# 106820                    1.9981                             0   6  2019
# 106821                    2.5093                          0.07   6  2019
# 106822                    2.5175                             0   6  2019
#
#        sem nocao  de uma lista
# 0        DEFAULT             0
# 1        DEFAULT             1
# 2        DEFAULT             2
# 3        DEFAULT             3
# 4        DEFAULT             4
# ...          ...           ...
# 106818   DEFAULT        106818
# 106819   DEFAULT        106819
# 106820   DEFAULT        106820
# 106821   DEFAULT        106821
# 106822   DEFAULT        106822
#
# [106823 rows x 23 columns]

# %%
# dessa forma nao funciona
# onde o numero é menor que o atual dataframe
data['nao funciona'] = ['a', 'b', 'c']
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[110], line 3
#       1 # dessa forma nao funciona
#       2 # onde o numero é menor que o atual dataframe
# ----> 3 data['nao funciona'] = ['a', 'b', 'c']
#       4 data
#
# File c:\Python312\Envs\pandas_etl_env\Lib\site-packages\pandas\core\frame.py:4322, in DataFrame.__setitem__(self, key, value)
#    4319     self._setitem_array([key], value)
#    4320 else:
#    4321     # set column
# -> 4322     self._set_item(key, value)
#
# File c:\Python312\Envs\pandas_etl_env\Lib\site-packages\pandas\core\frame.py:4535, in DataFrame._set_item(self, key, value)
#    4525 def _set_item(self, key, value) -> None:
#    4526     """
#    4527     Add series to DataFrame in specified column.
#    4528
#    (...)   4533     ensure homogeneity.
#    4534     """
# -> 4535     value, refs = self._sanitize_column(value)
#    4537     if (
#    4538         key in self.columns
#    4539         and value.ndim == 1
#    4540         and not isinstance(value.dtype, ExtensionDtype)
#    4541     ):
#    4542         # broadcast across multiple columns if necessary
#    4543         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File c:\Python312\Envs\pandas_etl_env\Lib\site-packages\pandas\core\frame.py:5288, in DataFrame._sanitize_column(self, value)
#    5285     return _reindex_for_setitem(value, self.index)
#    5287 if is_list_like(value):
# -> 5288     com.require_length_match(value, self.index)
#    5289 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5290 if (
#    5291     isinstance(value, Index)
#    5292     and value.dtype == "object"
#    (...)   5295     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5296     # this deprecation
#
# File c:\Python312\Envs\pandas_etl_env\Lib\site-packages\pandas\core\common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (3) does not match length of index (106823)

# %%
# ValueError: Length of values (3) does not match length of index (106823)

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  COEF DE VARIAÇÃO REVENDA  \
# 0                1.288                  0.016  ...                     0.012
# 1                1.162                  0.114  ...                     0.098
# 2                1.389                  0.097  ...                     0.070
# 3                1.262                  0.070  ...                     0.055
# 4                1.181                  0.078  ...                     0.066
#
#    PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.11
# 1                     0.763                      0.088
# 2                      0.97                      0.095
# 3                      0.83                      0.119
# 4                     0.941                      0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.9666
# 1                     0.5013                      1.05
# 2                     0.5614                     1.161
# 3                     0.5991                   1.22242
# 4                     0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO sem nocao  de uma lista
# 0                         0.133   5  2004   DEFAULT             0
# 1                         0.115   5  2004   DEFAULT             1
# 2                         0.098   5  2004   DEFAULT             2
# 3                         0.143   5  2004   DEFAULT             3
# 4                         0.082   5  2004   DEFAULT             4
#
# [5 rows x 23 columns]

# %% [markdown]
# <br/>
#
# Outro exemplo:

# %%
# simulação apenas, não calculo real
# valor a parti de uma coluna/atributo existente
data['PREÇO MÉDIO REVENDA por DOLAR'] = data['PREÇO MÉDIO REVENDA'] * 6.0

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                        0.11
# 1                          0.763                       0.088
# 2                           0.97                       0.095
# 3                           0.83                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 106818                     2.756                           0
# 106819                     2.451                       0.402
# 106820                     1.998                           0
# 106821                     2.374                       0.165
# 106822                     2.518                           0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                     0.9666
# 1                         0.5013                       1.05
# 2                         0.5614                      1.161
# 3                         0.5991                    1.22242
# 4                         0.7441                     1.0317
# ...                          ...                        ...
# 106818                     2.756                      2.756
# 106819                    1.9842                     2.8661
# 106820                    1.9981                     1.9981
# 106821                    2.0179                     2.5093
# 106822                    2.5175                     2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO sem nocao de uma lista  \
# 0                              0.133   5  2004   DEFAULT            0
# 1                              0.115   5  2004   DEFAULT            1
# 2                              0.098   5  2004   DEFAULT            2
# 3                              0.143   5  2004   DEFAULT            3
# 4                              0.082   5  2004   DEFAULT            4
# ...                              ...  ..   ...       ...          ...
# 106818                             0   6  2019   DEFAULT       106818
# 106819                         0.164   6  2019   DEFAULT       106819
# 106820                             0   6  2019   DEFAULT       106820
# 106821                          0.07   6  2019   DEFAULT       106821
# 106822                             0   6  2019   DEFAULT       106822
#
#         PREÇO MÉDIO REVENDA por DOLAR
# 0                               7.728
# 1                               6.972
# 2                               8.334
# 3                               7.572
# 4                               7.086
# ...                               ...
# 106818                         21.444
# 106819                         20.406
# 106820                         17.472
# 106821                         18.120
# 106822                         22.182
#
# [106823 rows x 24 columns]

# %% [markdown]
# **PS:** Obviamente, a lógica correta em converter o preço dos combustíveis em reais para dólares não é considerar uma taxa de câmbio fixa, uma vez que cada preço foi aferido em um momento diferente.

# %% [markdown]
# ### 1.3.4 Índices

# %% [markdown]
# Todo Data Frame possui **índices**, que não são considerado colunas da tabela. Tais índices são comumente **númericos**, de 0 a num_linhas-1, mas também podem ser **textuais (rótulos/labels)**.

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                        0.11
# 1                          0.763                       0.088
# 2                           0.97                       0.095
# 3                           0.83                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 106818                     2.756                           0
# 106819                     2.451                       0.402
# 106820                     1.998                           0
# 106821                     2.374                       0.165
# 106822                     2.518                           0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                     0.9666
# 1                         0.5013                       1.05
# 2                         0.5614                      1.161
# 3                         0.5991                    1.22242
# 4                         0.7441                     1.0317
# ...                          ...                        ...
# 106818                     2.756                      2.756
# 106819                    1.9842                     2.8661
# 106820                    1.9981                     1.9981
# 106821                    2.0179                     2.5093
# 106822                    2.5175                     2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO sem nocao de uma lista  \
# 0                              0.133   5  2004   DEFAULT            0
# 1                              0.115   5  2004   DEFAULT            1
# 2                              0.098   5  2004   DEFAULT            2
# 3                              0.143   5  2004   DEFAULT            3
# 4                              0.082   5  2004   DEFAULT            4
# ...                              ...  ..   ...       ...          ...
# 106818                             0   6  2019   DEFAULT       106818
# 106819                         0.164   6  2019   DEFAULT       106819
# 106820                             0   6  2019   DEFAULT       106820
# 106821                          0.07   6  2019   DEFAULT       106821
# 106822                             0   6  2019   DEFAULT       106822
#
#         PREÇO MÉDIO REVENDA por DOLAR
# 0                               7.728
# 1                               6.972
# 2                               8.334
# 3                               7.572
# 4                               7.086
# ...                               ...
# 106818                         21.444
# 106819                         20.406
# 106820                         17.472
# 106821                         18.120
# 106822                         22.182
#
# [106823 rows x 24 columns]

# %%
data.index
# Out:
# RangeIndex(start=0, stop=106823, step=1)

# %% [markdown]
# Use `list(data.index)` ou `data.index.to_list()` para converter um RangeIndex para uma python list.

# %% [markdown]
# #### **Exemplo de Data Frame com Índices Textuais (labels)**

# %%
pesquisa_de_satisfacao = pd.DataFrame(
    {'bom': [50, 21, 100], 'ruim': [131, 2, 30], 'pessimo': [30, 20, 1]},
    index=['XboxOne', 'Playstation4', 'Switch'],
)

# %%
pesquisa_de_satisfacao.head()
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
pesquisa_de_satisfacao.index
# Out:
# Index(['XboxOne', 'Playstation4', 'Switch'], dtype='object')

# %% [markdown]
# ### 1.4 Selecionando uma ou mais amostras (Indexação)

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %% [markdown]
# #### **==>  Index-based selection (seleção baseada em Índices)**
# Mostrando linhas específicas de um DataFrame:
#
# `iloc`: seleciona elementos do Dataframe, baseado em seu **índice (número)** --> row-first, column-second

# %% [markdown]
# **Selecionando uma observação/linha:**

# %%
# seleciona a linha/observação do indice [1]  do dataframe
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# Name: 1, dtype: object

# %% [markdown]
# **Selecionando múltiplias observação/linhas:**

# %%
# selecionando a observações de 0 a 5 (incluso)
data.iloc[:6]  # 6-1
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
# 5                1.383                  0.132  ...                 2.050
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
# 5                 0.426                    0.095                     0.957
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
# 5                      0.128                    0.5686
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
# 5                      1.35                         0.134   5  2004
#
# [6 rows x 21 columns]

# %%
# dessa vez será do intervalo do 10-15 (16)
data.iloc[10:16]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL    REGIÃO               ESTADO  \
# 10          10   2004-05-09  2004-05-15  NORDESTE                PIAUI
# 11          11   2004-05-09  2004-05-15  NORDESTE  RIO GRANDE DO NORTE
# 12          12   2004-05-09  2004-05-15  NORDESTE              SERGIPE
# 13          13   2004-05-09  2004-05-15     NORTE                 ACRE
# 14          14   2004-05-09  2004-05-15     NORTE                AMAPA
# 15          15   2004-05-09  2004-05-15     NORTE             AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 10  ETANOL HIDRATADO                            89              R$/l
# 11  ETANOL HIDRATADO                           131              R$/l
# 12  ETANOL HIDRATADO                            57              R$/l
# 13  ETANOL HIDRATADO                            33              R$/l
# 14  ETANOL HIDRATADO                            15              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 10                1.573                  0.134  ...                  1.78
# 11                1.276                  0.116  ...                  1.59
# 12                1.301                  0.109  ...                  1.75
# 13                1.805                  0.134  ...                  1.98
# 14                1.785                  0.035  ...                  1.85
# 15                1.578                  0.123  ...                  1.85
#
#     MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 10                 0.494                    0.085                     1.079
# 11                 0.332                    0.091                     0.944
# 12                 0.321                    0.084                      0.98
# 13                 0.689                    0.074                     1.116
# 14                 0.412                    0.020                     1.373
# 15                 0.441                    0.078                     1.137
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 10                      0.078                    0.8857
# 11                      0.078                    0.7119
# 12                      0.052                    0.8267
# 13                      0.171                     0.767
# 14                      0.167                    0.8339
# 15                      0.068                    0.9515
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 10                    1.2499                         0.072   5  2004
# 11                    1.1386                         0.083   5  2004
# 12                    1.1059                         0.053   5  2004
# 13                    1.2992                         0.153   5  2004
# 14                    1.4912                         0.122   5  2004
# 15                    1.2109                          0.06   5  2004
#
# [6 rows x 21 columns]

# %%
# podemos selecionar indicies distintos do dataframe como 1, 5, 10, 15
data.iloc[[1, 5, 10, 15]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 1   ETANOL HIDRATADO                           387              R$/l
# 5   ETANOL HIDRATADO                           408              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 1                 1.162                  0.114  ...                 1.449
# 5                 1.383                  0.132  ...                 2.050
# 10                1.573                  0.134  ...                 1.780
# 15                1.578                  0.123  ...                 1.850
#
#     MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 1                  0.399                    0.098                     0.763
# 5                  0.426                    0.095                     0.957
# 10                 0.494                    0.085                     1.079
# 15                 0.441                    0.078                     1.137
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 1                       0.088                    0.5013
# 5                       0.128                    0.5686
# 10                      0.078                    0.8857
# 15                      0.068                    0.9515
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 1                       1.05                         0.115   5  2004
# 5                       1.35                         0.134   5  2004
# 10                    1.2499                         0.072   5  2004
# 15                    1.2109                          0.06   5  2004
#
# [4 rows x 21 columns]

# %%
# tbm pode ser na sequencia que escolher 5, 1, 15, 10
# tem que esta entre cochetes iloc[[aqui]]
data.iloc[[5, 1, 15, 10]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5   ETANOL HIDRATADO                           408              R$/l
# 1   ETANOL HIDRATADO                           387              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 5                 1.383                  0.132  ...                 2.050
# 1                 1.162                  0.114  ...                 1.449
# 15                1.578                  0.123  ...                 1.850
# 10                1.573                  0.134  ...                 1.780
#
#     MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 5                  0.426                    0.095                     0.957
# 1                  0.399                    0.098                     0.763
# 15                 0.441                    0.078                     1.137
# 10                 0.494                    0.085                     1.079
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 5                       0.128                    0.5686
# 1                       0.088                    0.5013
# 15                      0.068                    0.9515
# 10                      0.078                    0.8857
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 5                       1.35                         0.134   5  2004
# 1                       1.05                         0.115   5  2004
# 15                    1.2109                          0.06   5  2004
# 10                    1.2499                         0.072   5  2004
#
# [4 rows x 21 columns]

# %%
# tambem pode escolher uma 'celula', como linha/observacao indice [1] da coluna/atributo 4 ['ESTADO']
data.iloc[1, 4]
# Out:
# 'GOIAS'

# %%
# e assim por diante!

# %% [markdown]
# #### **==>  Label-based selection (seleção baseadas em Rótulos)**
#
# `loc`: seleciona elementos do Dataframe, baseado em seus **rótulos** --> row-first, column-second

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
# retorna a linha de indice 0 implicito usando iloc
pesquisa_de_satisfacao.iloc[0]
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
# retorna valor da linha indice 0 e coluna de indice 1, tambem usando iloc
pesquisa_de_satisfacao.iloc[0, 1]  # 131
# Out:
# np.int64(131)

# %%
# retorna a linha cujo o rótulo/label é o 'XboxOne'
pesquisa_de_satisfacao.loc['XboxOne']
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
# NAO FUNCIONA iloc acessando rótulos
# pesquisa_de_satisfacao.iloc['XboxOne']
# TypeError: Cannot index by location index with a non-integer key

# %%
# NAO FUNCIONA loc acessando indices
# pesquisa_de_satisfacao.loc[0]

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
# retorna a linha do 'Playstation4' com a coluna 'ruim'
pesquisa_de_satisfacao.loc['Playstation4', 'ruim']  # 2
# Out:
# np.int64(2)

# %%
# retona as linhas de indices rotulados 'Playstation4', 'Switch'
pesquisa_de_satisfacao.loc[['Playstation4', 'Switch']]
# Out:
#               bom  ruim  pessimo
# Playstation4   21     2       20
# Switch        100    30        1

# %%
# retorna todas as linhas e apenas as colunas com rotulos bom	'ruim', 'pessimo'
pesquisa_de_satisfacao[['bom', 'pessimo']]
# Out:
#               bom  pessimo
# XboxOne        50       30
# Playstation4   21       20
# Switch        100        1

# %%
# retorna todas as linhas e apenas as colunas com rotulos bom	'ruim', 'pessimo'
pesquisa_de_satisfacao.loc[:, ['bom', 'pessimo']]
# Out:
#               bom  pessimo
# XboxOne        50       30
# Playstation4   21       20
# Switch        100        1

# %% [markdown]
# #### Observação
# *nesse caso comom temos indice implicito como numero o `loc` e o `iloc` entende como rótulos*

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# Name: 1, dtype: object

# %%
data.loc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# Name: 1, dtype: object

# %% [markdown]
# ### 1.5 Selecionando um ou mais atributos (colunas)

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
data['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data.ESTADO
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data.loc[:, 'ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
# NÃO FUNCIONA
# data.DATA INICIAL

# funciona
data['DATA INICIAL']
# Out:
# 0         2004-05-09
# 1         2004-05-09
# 2         2004-05-09
# 3         2004-05-09
# 4         2004-05-09
#              ...
# 106818    2019-06-23
# 106819    2019-06-23
# 106820    2019-06-23
# 106821    2019-06-23
# 106822    2019-06-23
# Name: DATA INICIAL, Length: 106823, dtype: object

# %%
# seleciona multiplas colunas/atributos
data[['DATA INICIAL', 'PRODUTO', 'REGIÃO']]
# Out:
#        DATA INICIAL           PRODUTO        REGIÃO
# 0        2004-05-09  ETANOL HIDRATADO  CENTRO OESTE
# 1        2004-05-09  ETANOL HIDRATADO  CENTRO OESTE
# 2        2004-05-09  ETANOL HIDRATADO  CENTRO OESTE
# 3        2004-05-09  ETANOL HIDRATADO  CENTRO OESTE
# 4        2004-05-09  ETANOL HIDRATADO      NORDESTE
# ...             ...               ...           ...
# 106818   2019-06-23               GNV      NORDESTE
# 106819   2019-06-23               GNV           SUL
# 106820   2019-06-23               GNV           SUL
# 106821   2019-06-23               GNV       SUDESTE
# 106822   2019-06-23               GNV      NORDESTE
#
# [106823 rows x 3 columns]

# %% [markdown]
# Como o rótulo da coluna 'DATA INICIAL' **possui espaço**, não é possível acessá-la como método: `data.DATA INICIAL`

# %% [markdown]
# ### 1.6 Removendo um Atributo (Coluna) do Data Frame

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %% [markdown]
# Como vimos anteriormente, o atributo 'Unnamed: 0' parece ser um **ruído** em nosso dataset. Desta maneira, vamos eliminá-lo,

# %%
# deleta/remove in-place (ou seja, no proprio dataframe) a coluna com o rotulo 'Unnamed: 0'
del data['Unnamed: 0']

# %%
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 106818               GNV                             7             R$/m3
# 106819               GNV                            23             R$/m3
# 106820               GNV                            24             R$/m3
# 106821               GNV                            52             R$/m3
# 106822               GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     1.288                  0.016                 1.190  ...
# 1                     1.162                  0.114                 0.890  ...
# 2                     1.389                  0.097                 1.180  ...
# 3                     1.262                  0.070                 1.090  ...
# 4                     1.181                  0.078                 1.050  ...
# ...                     ...                    ...                   ...  ...
# 106818                3.574                  0.065                 3.499  ...
# 106819                3.401                  0.129                 3.230  ...
# 106820                2.912                  0.190                 2.699  ...
# 106821                3.020                  0.229                 2.699  ...
# 106822                3.697                  0.005                 3.689  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.9666
# 1                          0.5013                      1.05
# 2                          0.5614                     1.161
# 3                          0.5991                   1.22242
# 4                          0.7441                    1.0317
# ...                           ...                       ...
# 106818                      2.756                     2.756
# 106819                     1.9842                    2.8661
# 106820                     1.9981                    1.9981
# 106821                     2.0179                    2.5093
# 106822                     2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO sem nocao  de uma lista  \
# 0                              0.133   5  2004   DEFAULT             0
# 1                              0.115   5  2004   DEFAULT             1
# 2                              0.098   5  2004   DEFAULT             2
# 3                              0.143   5  2004   DEFAULT             3
# 4                              0.082   5  2004   DEFAULT             4
# ...                              ...  ..   ...       ...           ...
# 106818                             0   6  2019   DEFAULT        106818
# 106819                         0.164   6  2019   DEFAULT        106819
# 106820                             0   6  2019   DEFAULT        106820
# 106821                          0.07   6  2019   DEFAULT        106821
# 106822                             0   6  2019   DEFAULT        106822
#
#         PREÇO MÉDIO REVENDA por DOLAR
# 0                               7.728
# 1                               6.972
# 2                               8.334
# 3                               7.572
# 4                               7.086
# ...                               ...
# 106818                         21.444
# 106819                         20.406
# 106820                         17.472
# 106821                         18.120
# 106822                         22.182
#
# [106823 rows x 23 columns]

# %% [markdown]
# <br/>
# Vamos remover as colunas criadas nas aulas enteriores
#
# 'sem nocao', 'de uma lista' e a 'PREÇO MÉDIO REVENDA por DOLAR'
# </br>

# %%
del data['sem nocao']
del data['de uma lista']
del data['PREÇO MÉDIO REVENDA por DOLAR']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python312\Envs\pandas_etl_env\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sem nocao'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 del data['sem nocao']
#       2 del data['de uma lista']
#       3 del data['PREÇO MÉDIO REVENDA por DOLAR']
#
# File c:\Python312\Envs\pandas_etl_env\Lib\site-packages\pandas\core\generic.py:4528, in NDFrame.__delitem__(self, key)
#    4523             deleted = True
#    4524 if not deleted:
#    4525     # If the above loop ran and didn't delete anything because
#    4526     # there was no match, this call should raise the appropriate
#    4527     # exception:
# -> 4528     loc = self.axes[-1].get_loc(key)
#    4529     self._mgr = self._mgr.idelete(loc)
#    4531 # delete from the caches
#
# File c:\Python312\Envs\pandas_etl_env\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'sem nocao'

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# 1                1.162                  0.114                  0.89
# 2                1.389                  0.097                  1.18
# 3                1.262                  0.070                  1.09
# 4                1.181                  0.078                  1.05
#
#    PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                 1.350                0.463                     0.012
# 1                 1.449                0.399                     0.098
# 2                 1.760                0.419                     0.070
# 3                 1.509                0.432                     0.055
# 4                 1.400                 0.24                     0.066
#
#   PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                    0.825                       0.11
# 1                    0.763                      0.088
# 2                     0.97                      0.095
# 3                     0.83                      0.119
# 4                    0.941                      0.077
#
#   PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                    0.4201                    0.9666
# 1                    0.5013                      1.05
# 2                    0.5614                     1.161
# 3                    0.5991                   1.22242
# 4                    0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                         0.133    5  2004
# 1                         0.115    5  2004
# 2                         0.098    5  2004
# 3                         0.143    5  2004
# 4                         0.082    5  2004

# %% [markdown]
# ### 1.7 Salvando um Data Frame

# %% [markdown]
# Para salvarmos um Data Frame para um **arquivo CSV**, basta usarmos o método `.to_csv`. <br/>
# Por padrão, esse método **salva os índices da tabela como uma coluna no CSV**.<br/>
# Como no geral tais índices são números de 0 a n-1, não há necessidade para isso (veja que removemos anteriormente a coluna 'Unnamed: 0' que foi justamente esse caso).<br/>
# Desta forma, utilize o parâmetro: `index=False`.
#
# Por padrão, o método utilizará a ',' como separador das colunas. Caso queira alterá-lo, utilize o parâmetro `sep`.

# %%
data.to_csv('./datasets/GasPricesinBrazil_2004-2019_preprocessado.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data.to_csv('./datasets/GasPricesinBrazil_2004-2019_preprocessado.csv', index=False)
#
# NameError: name 'data' is not defined

# %% [markdown]
# ### 1.8 Seleção Condicional: Filtrando amostras

# %% [markdown]
# Durante nossas análise exploratórias, frequentemente filtraremos nossas amostras, a partir de certas **condições**, para fins de análise mais específica. <br/>
# Existem algumas maneiras de fazermos tal filtragem. Antes disso, vamos carregar nosso dataset pré-processado que salvamos no item anterior.

# %%
data = pd.read_csv('./datasets/GasPricesinBrazil_2004-2019_preprocessado.csv')

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# 1                1.162                  0.114                  0.89
# 2                1.389                  0.097                  1.18
# 3                1.262                  0.070                  1.09
# 4                1.181                  0.078                  1.05
#
#    PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                 1.350                0.463                     0.012
# 1                 1.449                0.399                     0.098
# 2                 1.760                0.419                     0.070
# 3                 1.509                0.432                     0.055
# 4                 1.400                 0.24                     0.066
#
#   PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                    0.825                       0.11
# 1                    0.763                      0.088
# 2                     0.97                      0.095
# 3                     0.83                      0.119
# 4                    0.941                      0.077
#
#   PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                    0.4201                    0.9666
# 1                    0.5013                      1.05
# 2                    0.5614                     1.161
# 3                    0.5991                   1.22242
# 4                    0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                         0.133    5  2004
# 1                         0.115    5  2004
# 2                         0.098    5  2004
# 3                         0.143    5  2004
# 4                         0.082    5  2004

# %%
data.ESTADO
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %% [markdown]
# #### **Selecionando apenas os preços dos Postos de Ceará**

# %% [markdown]
# ##### **==> Alternativa 1: Seleção Condicional (Comparações diretas)**

# %% [markdown]
# O código abaixo retorna uma ***Series ('array') de booleans***, com o número de linhas (amostras) do Data Frame, que informa os registros de preços dos postos do _estado de Ceará_ (True).

# %%
# agrupa por estado
data.ESTADO.unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
data.ESTADO == 'CEARA'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
# guarda essa Series na variavel
selecao = data.ESTADO == 'CEARA'

# %%
type(selecao)
# Out:
# pandas.core.series.Series

# %%
selecao.shape
# Out:
# (106823,)

# %%
data.shape
# Out:
# (106823, 20)

# %% [markdown]
# Para **filtrarmos** os registros de postos do estado de Ceará:

# %%
# voce pode usar a selecao dentro do dataframe [], desde que seja respectivamente iguais
# retornando exatamente os filtro no caso 'data.ESTADO == 'CEARA'
data[selecao]
# Out:
#        DATA INICIAL  DATA FINAL    REGIÃO ESTADO           PRODUTO  \
# 6        2004-05-09  2004-05-15  NORDESTE  CEARA  ETANOL HIDRATADO
# 33       2004-05-16  2004-05-22  NORDESTE  CEARA  ETANOL HIDRATADO
# 60       2004-05-23  2004-05-29  NORDESTE  CEARA  ETANOL HIDRATADO
# 87       2004-05-30  2004-06-05  NORDESTE  CEARA  ETANOL HIDRATADO
# 114      2004-06-06  2004-06-12  NORDESTE  CEARA  ETANOL HIDRATADO
# ...             ...         ...       ...    ...               ...
# 106705   2019-06-23  2019-06-29  NORDESTE  CEARA       ÓLEO DIESEL
# 106732   2019-06-23  2019-06-29  NORDESTE  CEARA   ÓLEO DIESEL S10
# 106759   2019-06-23  2019-06-29  NORDESTE  CEARA    GASOLINA COMUM
# 106786   2019-06-23  2019-06-29  NORDESTE  CEARA               GLP
# 106810   2019-06-23  2019-06-29  NORDESTE  CEARA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 6                                278              R$/l                1.453
# 33                               277              R$/l                1.451
# 60                               279              R$/l                1.443
# 87                               269              R$/l                1.442
# 114                              277              R$/l                1.445
# ...                              ...               ...                  ...
# 106705                            64              R$/l                3.802
# 106732                           214              R$/l                3.801
# 106759                           221              R$/l                4.461
# 106786                           131           R$/13Kg               74.659
# 106810                            16             R$/m3                3.656
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 6                       0.218                  1.03                  1.95
# 33                      0.219                  1.03                  1.95
# 60                      0.212                  1.03                  1.95
# 87                      0.206                  1.03                  1.95
# 114                     0.198                  1.05                  1.95
# ...                       ...                   ...                   ...
# 106705                  0.071                  3.64                  3.95
# 106732                  0.085                  3.59                  3.99
# 106759                  0.164                  4.30                  4.87
# 106786                  4.981                 65.00                 85.00
# 106810                  0.034                  3.58                  3.69
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 6                     0.353                     0.150
# 33                    0.347                     0.151
# 60                     0.33                     0.147
# 87                    0.333                     0.143
# 114                   0.322                     0.137
# ...                     ...                       ...
# 106705                0.456                     0.019
# 106732                0.428                     0.022
# 106759                0.426                     0.037
# 106786               21.951                     0.067
# 106810                0.876                     0.009
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 6                           1.1                      0.068
# 33                        1.104                       0.06
# 60                        1.113                      0.065
# 87                        1.109                       0.07
# 114                       1.123                      0.082
# ...                         ...                        ...
# 106705                    3.346                      0.096
# 106732                    3.373                      0.087
# 106759                    4.035                      0.102
# 106786                   52.708                      1.957
# 106810                     2.78                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 6                         0.7332                     1.294
# 33                          0.92                      1.27
# 60                         0.849                      1.27
# 87                       0.85727                      1.27
# 114                      0.85727                    1.3021
# ...                          ...                       ...
# 106705                      3.16                    3.4781
# 106732                      3.15                    3.6134
# 106759                    3.8754                    4.3276
# 106786                     46.97                        55
# 106810                    2.7802                    2.7802
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 6                              0.062    5  2004
# 33                             0.054    5  2004
# 60                             0.058    5  2004
# 87                             0.063    5  2004
# 114                            0.073    6  2004
# ...                              ...  ...   ...
# 106705                         0.029    6  2019
# 106732                         0.026    6  2019
# 106759                         0.025    6  2019
# 106786                         0.037    6  2019
# 106810                             0    6  2019
#
# [4263 rows x 20 columns]

# %% [markdown]
# O resultado é um Data Frame com _apenas_ os registros desejados após a **filtragem**.<br/>
# Podemos ainda utilizar o método `loc` para o mesmo fim:

# %%
# pode se usar a Series 'selecao' no loc também, mas verbo
data.loc[selecao]
# Out:
#        DATA INICIAL  DATA FINAL    REGIÃO ESTADO           PRODUTO  \
# 6        2004-05-09  2004-05-15  NORDESTE  CEARA  ETANOL HIDRATADO
# 33       2004-05-16  2004-05-22  NORDESTE  CEARA  ETANOL HIDRATADO
# 60       2004-05-23  2004-05-29  NORDESTE  CEARA  ETANOL HIDRATADO
# 87       2004-05-30  2004-06-05  NORDESTE  CEARA  ETANOL HIDRATADO
# 114      2004-06-06  2004-06-12  NORDESTE  CEARA  ETANOL HIDRATADO
# ...             ...         ...       ...    ...               ...
# 106705   2019-06-23  2019-06-29  NORDESTE  CEARA       ÓLEO DIESEL
# 106732   2019-06-23  2019-06-29  NORDESTE  CEARA   ÓLEO DIESEL S10
# 106759   2019-06-23  2019-06-29  NORDESTE  CEARA    GASOLINA COMUM
# 106786   2019-06-23  2019-06-29  NORDESTE  CEARA               GLP
# 106810   2019-06-23  2019-06-29  NORDESTE  CEARA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 6                                278              R$/l                1.453
# 33                               277              R$/l                1.451
# 60                               279              R$/l                1.443
# 87                               269              R$/l                1.442
# 114                              277              R$/l                1.445
# ...                              ...               ...                  ...
# 106705                            64              R$/l                3.802
# 106732                           214              R$/l                3.801
# 106759                           221              R$/l                4.461
# 106786                           131           R$/13Kg               74.659
# 106810                            16             R$/m3                3.656
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 6                       0.218                  1.03                  1.95
# 33                      0.219                  1.03                  1.95
# 60                      0.212                  1.03                  1.95
# 87                      0.206                  1.03                  1.95
# 114                     0.198                  1.05                  1.95
# ...                       ...                   ...                   ...
# 106705                  0.071                  3.64                  3.95
# 106732                  0.085                  3.59                  3.99
# 106759                  0.164                  4.30                  4.87
# 106786                  4.981                 65.00                 85.00
# 106810                  0.034                  3.58                  3.69
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 6                     0.353                     0.150
# 33                    0.347                     0.151
# 60                     0.33                     0.147
# 87                    0.333                     0.143
# 114                   0.322                     0.137
# ...                     ...                       ...
# 106705                0.456                     0.019
# 106732                0.428                     0.022
# 106759                0.426                     0.037
# 106786               21.951                     0.067
# 106810                0.876                     0.009
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 6                           1.1                      0.068
# 33                        1.104                       0.06
# 60                        1.113                      0.065
# 87                        1.109                       0.07
# 114                       1.123                      0.082
# ...                         ...                        ...
# 106705                    3.346                      0.096
# 106732                    3.373                      0.087
# 106759                    4.035                      0.102
# 106786                   52.708                      1.957
# 106810                     2.78                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 6                         0.7332                     1.294
# 33                          0.92                      1.27
# 60                         0.849                      1.27
# 87                       0.85727                      1.27
# 114                      0.85727                    1.3021
# ...                          ...                       ...
# 106705                      3.16                    3.4781
# 106732                      3.15                    3.6134
# 106759                    3.8754                    4.3276
# 106786                     46.97                        55
# 106810                    2.7802                    2.7802
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 6                              0.062    5  2004
# 33                             0.054    5  2004
# 60                             0.058    5  2004
# 87                             0.063    5  2004
# 114                            0.073    6  2004
# ...                              ...  ...   ...
# 106705                         0.029    6  2019
# 106732                         0.026    6  2019
# 106759                         0.025    6  2019
# 106786                         0.037    6  2019
# 106810                             0    6  2019
#
# [4263 rows x 20 columns]

# %% [markdown]
# ##### **==> Alternativa 2: Utilizando o método `query`**

# %% [markdown]
# `query` filtra linhas de um DataFrame baseado em uma **query (pergunta)**.

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# 1                1.162                  0.114                  0.89
# 2                1.389                  0.097                  1.18
# 3                1.262                  0.070                  1.09
# 4                1.181                  0.078                  1.05
#
#    PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                 1.350                0.463                     0.012
# 1                 1.449                0.399                     0.098
# 2                 1.760                0.419                     0.070
# 3                 1.509                0.432                     0.055
# 4                 1.400                 0.24                     0.066
#
#   PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                    0.825                       0.11
# 1                    0.763                      0.088
# 2                     0.97                      0.095
# 3                     0.83                      0.119
# 4                    0.941                      0.077
#
#   PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                    0.4201                    0.9666
# 1                    0.5013                      1.05
# 2                    0.5614                     1.161
# 3                    0.5991                   1.22242
# 4                    0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                         0.133    5  2004
# 1                         0.115    5  2004
# 2                         0.098    5  2004
# 3                         0.143    5  2004
# 4                         0.082    5  2004

# %% [markdown]
# <br/>
#
# Uma boa prática é **salvar o Data Frame filtrado em uma nova variável**. Isso simplifica a complexidade do código para futuras análise feita para os postos de Ceará.

# %%
postos_ce = data.query('ESTADO == "CEARA"')

# %%
postos_ce
# Out:
#        DATA INICIAL  DATA FINAL    REGIÃO ESTADO           PRODUTO  \
# 6        2004-05-09  2004-05-15  NORDESTE  CEARA  ETANOL HIDRATADO
# 33       2004-05-16  2004-05-22  NORDESTE  CEARA  ETANOL HIDRATADO
# 60       2004-05-23  2004-05-29  NORDESTE  CEARA  ETANOL HIDRATADO
# 87       2004-05-30  2004-06-05  NORDESTE  CEARA  ETANOL HIDRATADO
# 114      2004-06-06  2004-06-12  NORDESTE  CEARA  ETANOL HIDRATADO
# ...             ...         ...       ...    ...               ...
# 106705   2019-06-23  2019-06-29  NORDESTE  CEARA       ÓLEO DIESEL
# 106732   2019-06-23  2019-06-29  NORDESTE  CEARA   ÓLEO DIESEL S10
# 106759   2019-06-23  2019-06-29  NORDESTE  CEARA    GASOLINA COMUM
# 106786   2019-06-23  2019-06-29  NORDESTE  CEARA               GLP
# 106810   2019-06-23  2019-06-29  NORDESTE  CEARA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 6                                278              R$/l                1.453
# 33                               277              R$/l                1.451
# 60                               279              R$/l                1.443
# 87                               269              R$/l                1.442
# 114                              277              R$/l                1.445
# ...                              ...               ...                  ...
# 106705                            64              R$/l                3.802
# 106732                           214              R$/l                3.801
# 106759                           221              R$/l                4.461
# 106786                           131           R$/13Kg               74.659
# 106810                            16             R$/m3                3.656
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 6                       0.218                  1.03                  1.95
# 33                      0.219                  1.03                  1.95
# 60                      0.212                  1.03                  1.95
# 87                      0.206                  1.03                  1.95
# 114                     0.198                  1.05                  1.95
# ...                       ...                   ...                   ...
# 106705                  0.071                  3.64                  3.95
# 106732                  0.085                  3.59                  3.99
# 106759                  0.164                  4.30                  4.87
# 106786                  4.981                 65.00                 85.00
# 106810                  0.034                  3.58                  3.69
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 6                     0.353                     0.150
# 33                    0.347                     0.151
# 60                     0.33                     0.147
# 87                    0.333                     0.143
# 114                   0.322                     0.137
# ...                     ...                       ...
# 106705                0.456                     0.019
# 106732                0.428                     0.022
# 106759                0.426                     0.037
# 106786               21.951                     0.067
# 106810                0.876                     0.009
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 6                           1.1                      0.068
# 33                        1.104                       0.06
# 60                        1.113                      0.065
# 87                        1.109                       0.07
# 114                       1.123                      0.082
# ...                         ...                        ...
# 106705                    3.346                      0.096
# 106732                    3.373                      0.087
# 106759                    4.035                      0.102
# 106786                   52.708                      1.957
# 106810                     2.78                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 6                         0.7332                     1.294
# 33                          0.92                      1.27
# 60                         0.849                      1.27
# 87                       0.85727                      1.27
# 114                      0.85727                    1.3021
# ...                          ...                       ...
# 106705                      3.16                    3.4781
# 106732                      3.15                    3.6134
# 106759                    3.8754                    4.3276
# 106786                     46.97                        55
# 106810                    2.7802                    2.7802
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 6                              0.062    5  2004
# 33                             0.054    5  2004
# 60                             0.058    5  2004
# 87                             0.063    5  2004
# 114                            0.073    6  2004
# ...                              ...  ...   ...
# 106705                         0.029    6  2019
# 106732                         0.026    6  2019
# 106759                         0.025    6  2019
# 106786                         0.037    6  2019
# 106810                             0    6  2019
#
# [4263 rows x 20 columns]

# %%
type(postos_ce)  # dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
postos_ce.shape
# Out:
# (4263, 20)

# %%
postos_ce.head()
# Out:
#     DATA INICIAL  DATA FINAL    REGIÃO ESTADO           PRODUTO  \
# 6     2004-05-09  2004-05-15  NORDESTE  CEARA  ETANOL HIDRATADO
# 33    2004-05-16  2004-05-22  NORDESTE  CEARA  ETANOL HIDRATADO
# 60    2004-05-23  2004-05-29  NORDESTE  CEARA  ETANOL HIDRATADO
# 87    2004-05-30  2004-06-05  NORDESTE  CEARA  ETANOL HIDRATADO
# 114   2004-06-06  2004-06-12  NORDESTE  CEARA  ETANOL HIDRATADO
#
#      NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 6                             278              R$/l                1.453
# 33                            277              R$/l                1.451
# 60                            279              R$/l                1.443
# 87                            269              R$/l                1.442
# 114                           277              R$/l                1.445
#
#      DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 6                    0.218                  1.03                  1.95
# 33                   0.219                  1.03                  1.95
# 60                   0.212                  1.03                  1.95
# 87                   0.206                  1.03                  1.95
# 114                  0.198                  1.05                  1.95
#
#     MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 6                  0.353                     0.150                      1.1
# 33                 0.347                     0.151                    1.104
# 60                  0.33                     0.147                    1.113
# 87                 0.333                     0.143                    1.109
# 114                0.322                     0.137                    1.123
#
#     DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 6                        0.068                    0.7332
# 33                        0.06                      0.92
# 60                       0.065                     0.849
# 87                        0.07                   0.85727
# 114                      0.082                   0.85727
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 6                       1.294                         0.062    5  2004
# 33                       1.27                         0.054    5  2004
# 60                       1.27                         0.058    5  2004
# 87                       1.27                         0.063    5  2004
# 114                    1.3021                         0.073    6  2004

# %% [markdown]
# ### Resetar Indices
# Pode ***resetar o indice*** usando `.reset_index`

# %%
postos_ce.reset_index()
# Out:
#        index DATA INICIAL  DATA FINAL    REGIÃO ESTADO           PRODUTO  \
# 0          6   2004-05-09  2004-05-15  NORDESTE  CEARA  ETANOL HIDRATADO
# 1         33   2004-05-16  2004-05-22  NORDESTE  CEARA  ETANOL HIDRATADO
# 2         60   2004-05-23  2004-05-29  NORDESTE  CEARA  ETANOL HIDRATADO
# 3         87   2004-05-30  2004-06-05  NORDESTE  CEARA  ETANOL HIDRATADO
# 4        114   2004-06-06  2004-06-12  NORDESTE  CEARA  ETANOL HIDRATADO
# ...      ...          ...         ...       ...    ...               ...
# 4258  106705   2019-06-23  2019-06-29  NORDESTE  CEARA       ÓLEO DIESEL
# 4259  106732   2019-06-23  2019-06-29  NORDESTE  CEARA   ÓLEO DIESEL S10
# 4260  106759   2019-06-23  2019-06-29  NORDESTE  CEARA    GASOLINA COMUM
# 4261  106786   2019-06-23  2019-06-29  NORDESTE  CEARA               GLP
# 4262  106810   2019-06-23  2019-06-29  NORDESTE  CEARA               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                              278              R$/l                1.453
# 1                              277              R$/l                1.451
# 2                              279              R$/l                1.443
# 3                              269              R$/l                1.442
# 4                              277              R$/l                1.445
# ...                            ...               ...                  ...
# 4258                            64              R$/l                3.802
# 4259                           214              R$/l                3.801
# 4260                           221              R$/l                4.461
# 4261                           131           R$/13Kg               74.659
# 4262                            16             R$/m3                3.656
#
#       DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# 0                     0.218  ...                  1.95                 0.353
# 1                     0.219  ...                  1.95                 0.347
# 2                     0.212  ...                  1.95                  0.33
# 3                     0.206  ...                  1.95                 0.333
# 4                     0.198  ...                  1.95                 0.322
# ...                     ...  ...                   ...                   ...
# 4258                  0.071  ...                  3.95                 0.456
# 4259                  0.085  ...                  3.99                 0.428
# 4260                  0.164  ...                  4.87                 0.426
# 4261                  4.981  ...                 85.00                21.951
# 4262                  0.034  ...                  3.69                 0.876
#
#      COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                       0.150                       1.1
# 1                       0.151                     1.104
# 2                       0.147                     1.113
# 3                       0.143                     1.109
# 4                       0.137                     1.123
# ...                       ...                       ...
# 4258                    0.019                     3.346
# 4259                    0.022                     3.373
# 4260                    0.037                     4.035
# 4261                    0.067                    52.708
# 4262                    0.009                      2.78
#
#      DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                         0.068                    0.7332
# 1                          0.06                      0.92
# 2                         0.065                     0.849
# 3                          0.07                   0.85727
# 4                         0.082                   0.85727
# ...                         ...                       ...
# 4258                      0.096                      3.16
# 4259                      0.087                      3.15
# 4260                      0.102                    3.8754
# 4261                      1.957                     46.97
# 4262                          0                    2.7802
#
#      PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                        1.294                         0.062   5  2004
# 1                         1.27                         0.054   5  2004
# 2                         1.27                         0.058   5  2004
# 3                         1.27                         0.063   5  2004
# 4                       1.3021                         0.073   6  2004
# ...                        ...                           ...  ..   ...
# 4258                    3.4781                         0.029   6  2019
# 4259                    3.6134                         0.026   6  2019
# 4260                    4.3276                         0.025   6  2019
# 4261                        55                         0.037   6  2019
# 4262                    2.7802                             0   6  2019
#
# [4263 rows x 21 columns]

# %%
# remove o index backup criado, e ele é uma cópia
postos_ce.reset_index(drop=True)
# Out:
#      DATA INICIAL  DATA FINAL    REGIÃO ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  NORDESTE  CEARA  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  NORDESTE  CEARA  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  NORDESTE  CEARA  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  NORDESTE  CEARA  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  NORDESTE  CEARA  ETANOL HIDRATADO
# ...           ...         ...       ...    ...               ...
# 4258   2019-06-23  2019-06-29  NORDESTE  CEARA       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  NORDESTE  CEARA   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  NORDESTE  CEARA    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  NORDESTE  CEARA               GLP
# 4262   2019-06-23  2019-06-29  NORDESTE  CEARA               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                              278              R$/l                1.453
# 1                              277              R$/l                1.451
# 2                              279              R$/l                1.443
# 3                              269              R$/l                1.442
# 4                              277              R$/l                1.445
# ...                            ...               ...                  ...
# 4258                            64              R$/l                3.802
# 4259                           214              R$/l                3.801
# 4260                           221              R$/l                4.461
# 4261                           131           R$/13Kg               74.659
# 4262                            16             R$/m3                3.656
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                     0.218                  1.03                  1.95
# 1                     0.219                  1.03                  1.95
# 2                     0.212                  1.03                  1.95
# 3                     0.206                  1.03                  1.95
# 4                     0.198                  1.05                  1.95
# ...                     ...                   ...                   ...
# 4258                  0.071                  3.64                  3.95
# 4259                  0.085                  3.59                  3.99
# 4260                  0.164                  4.30                  4.87
# 4261                  4.981                 65.00                 85.00
# 4262                  0.034                  3.58                  3.69
#
#      MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                   0.353                     0.150                      1.1
# 1                   0.347                     0.151                    1.104
# 2                    0.33                     0.147                    1.113
# 3                   0.333                     0.143                    1.109
# 4                   0.322                     0.137                    1.123
# ...                   ...                       ...                      ...
# 4258                0.456                     0.019                    3.346
# 4259                0.428                     0.022                    3.373
# 4260                0.426                     0.037                    4.035
# 4261               21.951                     0.067                   52.708
# 4262                0.876                     0.009                     2.78
#
#      DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                         0.068                    0.7332
# 1                          0.06                      0.92
# 2                         0.065                     0.849
# 3                          0.07                   0.85727
# 4                         0.082                   0.85727
# ...                         ...                       ...
# 4258                      0.096                      3.16
# 4259                      0.087                      3.15
# 4260                      0.102                    3.8754
# 4261                      1.957                     46.97
# 4262                          0                    2.7802
#
#      PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                        1.294                         0.062    5  2004
# 1                         1.27                         0.054    5  2004
# 2                         1.27                         0.058    5  2004
# 3                         1.27                         0.063    5  2004
# 4                       1.3021                         0.073    6  2004
# ...                        ...                           ...  ...   ...
# 4258                    3.4781                         0.029    6  2019
# 4259                    3.6134                         0.026    6  2019
# 4260                    4.3276                         0.025    6  2019
# 4261                        55                         0.037    6  2019
# 4262                    2.7802                             0    6  2019
#
# [4263 rows x 20 columns]

# %%
# continua pois foi uma copia, precisa usar o inplace
postos_ce
# Out:
#        DATA INICIAL  DATA FINAL    REGIÃO ESTADO           PRODUTO  \
# 6        2004-05-09  2004-05-15  NORDESTE  CEARA  ETANOL HIDRATADO
# 33       2004-05-16  2004-05-22  NORDESTE  CEARA  ETANOL HIDRATADO
# 60       2004-05-23  2004-05-29  NORDESTE  CEARA  ETANOL HIDRATADO
# 87       2004-05-30  2004-06-05  NORDESTE  CEARA  ETANOL HIDRATADO
# 114      2004-06-06  2004-06-12  NORDESTE  CEARA  ETANOL HIDRATADO
# ...             ...         ...       ...    ...               ...
# 106705   2019-06-23  2019-06-29  NORDESTE  CEARA       ÓLEO DIESEL
# 106732   2019-06-23  2019-06-29  NORDESTE  CEARA   ÓLEO DIESEL S10
# 106759   2019-06-23  2019-06-29  NORDESTE  CEARA    GASOLINA COMUM
# 106786   2019-06-23  2019-06-29  NORDESTE  CEARA               GLP
# 106810   2019-06-23  2019-06-29  NORDESTE  CEARA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 6                                278              R$/l                1.453
# 33                               277              R$/l                1.451
# 60                               279              R$/l                1.443
# 87                               269              R$/l                1.442
# 114                              277              R$/l                1.445
# ...                              ...               ...                  ...
# 106705                            64              R$/l                3.802
# 106732                           214              R$/l                3.801
# 106759                           221              R$/l                4.461
# 106786                           131           R$/13Kg               74.659
# 106810                            16             R$/m3                3.656
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 6                       0.218                  1.03                  1.95
# 33                      0.219                  1.03                  1.95
# 60                      0.212                  1.03                  1.95
# 87                      0.206                  1.03                  1.95
# 114                     0.198                  1.05                  1.95
# ...                       ...                   ...                   ...
# 106705                  0.071                  3.64                  3.95
# 106732                  0.085                  3.59                  3.99
# 106759                  0.164                  4.30                  4.87
# 106786                  4.981                 65.00                 85.00
# 106810                  0.034                  3.58                  3.69
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 6                     0.353                     0.150
# 33                    0.347                     0.151
# 60                     0.33                     0.147
# 87                    0.333                     0.143
# 114                   0.322                     0.137
# ...                     ...                       ...
# 106705                0.456                     0.019
# 106732                0.428                     0.022
# 106759                0.426                     0.037
# 106786               21.951                     0.067
# 106810                0.876                     0.009
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 6                           1.1                      0.068
# 33                        1.104                       0.06
# 60                        1.113                      0.065
# 87                        1.109                       0.07
# 114                       1.123                      0.082
# ...                         ...                        ...
# 106705                    3.346                      0.096
# 106732                    3.373                      0.087
# 106759                    4.035                      0.102
# 106786                   52.708                      1.957
# 106810                     2.78                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 6                         0.7332                     1.294
# 33                          0.92                      1.27
# 60                         0.849                      1.27
# 87                       0.85727                      1.27
# 114                      0.85727                    1.3021
# ...                          ...                       ...
# 106705                      3.16                    3.4781
# 106732                      3.15                    3.6134
# 106759                    3.8754                    4.3276
# 106786                     46.97                        55
# 106810                    2.7802                    2.7802
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 6                              0.062    5  2004
# 33                             0.054    5  2004
# 60                             0.058    5  2004
# 87                             0.063    5  2004
# 114                            0.073    6  2004
# ...                              ...  ...   ...
# 106705                         0.029    6  2019
# 106732                         0.026    6  2019
# 106759                         0.025    6  2019
# 106786                         0.037    6  2019
# 106810                             0    6  2019
#
# [4263 rows x 20 columns]

# %%
# agora alterado
postos_ce.reset_index(drop=True, inplace=True)

# %%
postos_ce
# Out:
#      DATA INICIAL  DATA FINAL    REGIÃO ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  NORDESTE  CEARA  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  NORDESTE  CEARA  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  NORDESTE  CEARA  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  NORDESTE  CEARA  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  NORDESTE  CEARA  ETANOL HIDRATADO
# ...           ...         ...       ...    ...               ...
# 4258   2019-06-23  2019-06-29  NORDESTE  CEARA       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  NORDESTE  CEARA   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  NORDESTE  CEARA    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  NORDESTE  CEARA               GLP
# 4262   2019-06-23  2019-06-29  NORDESTE  CEARA               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                              278              R$/l                1.453
# 1                              277              R$/l                1.451
# 2                              279              R$/l                1.443
# 3                              269              R$/l                1.442
# 4                              277              R$/l                1.445
# ...                            ...               ...                  ...
# 4258                            64              R$/l                3.802
# 4259                           214              R$/l                3.801
# 4260                           221              R$/l                4.461
# 4261                           131           R$/13Kg               74.659
# 4262                            16             R$/m3                3.656
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                     0.218                  1.03                  1.95
# 1                     0.219                  1.03                  1.95
# 2                     0.212                  1.03                  1.95
# 3                     0.206                  1.03                  1.95
# 4                     0.198                  1.05                  1.95
# ...                     ...                   ...                   ...
# 4258                  0.071                  3.64                  3.95
# 4259                  0.085                  3.59                  3.99
# 4260                  0.164                  4.30                  4.87
# 4261                  4.981                 65.00                 85.00
# 4262                  0.034                  3.58                  3.69
#
#      MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                   0.353                     0.150                      1.1
# 1                   0.347                     0.151                    1.104
# 2                    0.33                     0.147                    1.113
# 3                   0.333                     0.143                    1.109
# 4                   0.322                     0.137                    1.123
# ...                   ...                       ...                      ...
# 4258                0.456                     0.019                    3.346
# 4259                0.428                     0.022                    3.373
# 4260                0.426                     0.037                    4.035
# 4261               21.951                     0.067                   52.708
# 4262                0.876                     0.009                     2.78
#
#      DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                         0.068                    0.7332
# 1                          0.06                      0.92
# 2                         0.065                     0.849
# 3                          0.07                   0.85727
# 4                         0.082                   0.85727
# ...                         ...                       ...
# 4258                      0.096                      3.16
# 4259                      0.087                      3.15
# 4260                      0.102                    3.8754
# 4261                      1.957                     46.97
# 4262                          0                    2.7802
#
#      PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                        1.294                         0.062    5  2004
# 1                         1.27                         0.054    5  2004
# 2                         1.27                         0.058    5  2004
# 3                         1.27                         0.063    5  2004
# 4                       1.3021                         0.073    6  2004
# ...                        ...                           ...  ...   ...
# 4258                    3.4781                         0.029    6  2019
# 4259                    3.6134                         0.026    6  2019
# 4260                    4.3276                         0.025    6  2019
# 4261                        55                         0.037    6  2019
# 4262                    2.7802                             0    6  2019
#
# [4263 rows x 20 columns]

# %%
# ALTERNATIVA MAIS USADA HOJE
postos_ce = data.query('ESTADO == "CEARA"').reset_index(drop=True)

# %%
postos_ce
# Out:
#      DATA INICIAL  DATA FINAL    REGIÃO ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  NORDESTE  CEARA  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  NORDESTE  CEARA  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  NORDESTE  CEARA  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  NORDESTE  CEARA  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  NORDESTE  CEARA  ETANOL HIDRATADO
# ...           ...         ...       ...    ...               ...
# 4258   2019-06-23  2019-06-29  NORDESTE  CEARA       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  NORDESTE  CEARA   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  NORDESTE  CEARA    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  NORDESTE  CEARA               GLP
# 4262   2019-06-23  2019-06-29  NORDESTE  CEARA               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                              278              R$/l                1.453
# 1                              277              R$/l                1.451
# 2                              279              R$/l                1.443
# 3                              269              R$/l                1.442
# 4                              277              R$/l                1.445
# ...                            ...               ...                  ...
# 4258                            64              R$/l                3.802
# 4259                           214              R$/l                3.801
# 4260                           221              R$/l                4.461
# 4261                           131           R$/13Kg               74.659
# 4262                            16             R$/m3                3.656
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                     0.218                  1.03                  1.95
# 1                     0.219                  1.03                  1.95
# 2                     0.212                  1.03                  1.95
# 3                     0.206                  1.03                  1.95
# 4                     0.198                  1.05                  1.95
# ...                     ...                   ...                   ...
# 4258                  0.071                  3.64                  3.95
# 4259                  0.085                  3.59                  3.99
# 4260                  0.164                  4.30                  4.87
# 4261                  4.981                 65.00                 85.00
# 4262                  0.034                  3.58                  3.69
#
#      MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                   0.353                     0.150                      1.1
# 1                   0.347                     0.151                    1.104
# 2                    0.33                     0.147                    1.113
# 3                   0.333                     0.143                    1.109
# 4                   0.322                     0.137                    1.123
# ...                   ...                       ...                      ...
# 4258                0.456                     0.019                    3.346
# 4259                0.428                     0.022                    3.373
# 4260                0.426                     0.037                    4.035
# 4261               21.951                     0.067                   52.708
# 4262                0.876                     0.009                     2.78
#
#      DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                         0.068                    0.7332
# 1                          0.06                      0.92
# 2                         0.065                     0.849
# 3                          0.07                   0.85727
# 4                         0.082                   0.85727
# ...                         ...                       ...
# 4258                      0.096                      3.16
# 4259                      0.087                      3.15
# 4260                      0.102                    3.8754
# 4261                      1.957                     46.97
# 4262                          0                    2.7802
#
#      PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                        1.294                         0.062    5  2004
# 1                         1.27                         0.054    5  2004
# 2                         1.27                         0.058    5  2004
# 3                         1.27                         0.063    5  2004
# 4                       1.3021                         0.073    6  2004
# ...                        ...                           ...  ...   ...
# 4258                    3.4781                         0.029    6  2019
# 4259                    3.6134                         0.026    6  2019
# 4260                    4.3276                         0.025    6  2019
# 4261                        55                         0.037    6  2019
# 4262                    2.7802                             0    6  2019
#
# [4263 rows x 20 columns]

# %% [markdown]
# #### **Selecionando registros de postos do Rio de Janeiro com Preços acima de 2 reais**

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# 1                1.162                  0.114                  0.89
# 2                1.389                  0.097                  1.18
# 3                1.262                  0.070                  1.09
# 4                1.181                  0.078                  1.05
#
#    PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                 1.350                0.463                     0.012
# 1                 1.449                0.399                     0.098
# 2                 1.760                0.419                     0.070
# 3                 1.509                0.432                     0.055
# 4                 1.400                 0.24                     0.066
#
#   PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                    0.825                       0.11
# 1                    0.763                      0.088
# 2                     0.97                      0.095
# 3                     0.83                      0.119
# 4                    0.941                      0.077
#
#   PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                    0.4201                    0.9666
# 1                    0.5013                      1.05
# 2                    0.5614                     1.161
# 3                    0.5991                   1.22242
# 4                    0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                         0.133    5  2004
# 1                         0.115    5  2004
# 2                         0.098    5  2004
# 3                         0.143    5  2004
# 4                         0.082    5  2004

# %%
data['ESTADO'] == 'RIO DE JANEIRO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
data['PREÇO MÉDIO REVENDA'] > 2.0
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818     True
# 106819     True
# 106820     True
# 106821     True
# 106822     True
# Name: PREÇO MÉDIO REVENDA, Length: 106823, dtype: bool

# %%
selecao = (data['ESTADO'] == 'RIO DE JANEIRO') & (data['PREÇO MÉDIO REVENDA'] > 2.0)

# %%
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Length: 106823, dtype: bool

# %% [markdown]
# Note que o resultado da seleção continua sendo uma _Series de booleans_ com o _mesmo número de linhas/amostras do DataFrame_, de modo que cada linha possuirá um valor booleano indicando se o posto é do Rio de Janeiro e o preço aferido do combustível é maior que 2 reais (True) ou não.
#
# O símbolo **&** significa **AND** na comparação. Essa nomenclatura do python/pandas é diferente das nomenclaturas tradicionais (&&). <br/>
# Similarmente:
# - **|** representa o **OR** (não é ||)
# - **~** representa o **NOT** (não é !)

# %%
data[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 2501     2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2528     2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2555     2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2582     2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2609     2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 2501                             881              R$/l                2.028
# 2528                             889              R$/l                2.125
# 2555                             902              R$/l                2.163
# 2582                             898              R$/l                2.166
# 2609                             890              R$/l                2.172
# ...                              ...               ...                  ...
# 106718                           212              R$/l                3.569
# 106745                           335              R$/l                3.697
# 106772                           422              R$/l                4.928
# 106799                           221           R$/13Kg               65.010
# 106817                           124             R$/m3                3.111
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 2501                    0.148                 1.589                 2.550
# 2528                    0.149                 1.779                 2.550
# 2555                    0.138                 1.799                 2.599
# 2582                    0.146                 1.760                 2.568
# 2609                    0.143                 1.789                 2.550
# ...                       ...                   ...                   ...
# 106718                  0.166                 3.179                 4.059
# 106745                  0.187                 3.279                 4.389
# 106772                  0.165                 4.599                 5.859
# 106799                  5.812                50.000                79.000
# 106817                  0.260                 2.799                 3.799
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 2501                  0.222                     0.073
# 2528                  0.286                     0.070
# 2555                  0.268                     0.064
# 2582                  0.231                     0.067
# 2609                  0.209                     0.066
# ...                     ...                       ...
# 106718                0.467                     0.047
# 106745                  0.5                     0.051
# 106772                0.538                     0.033
# 106799               17.475                     0.089
# 106817                0.707                     0.084
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 2501                      1.806                       0.11
# 2528                      1.839                      0.117
# 2555                      1.895                      0.134
# 2582                      1.935                       0.14
# 2609                      1.963                      0.133
# ...                         ...                        ...
# 106718                    3.102                      0.119
# 106745                    3.197                      0.127
# 106772                     4.39                      0.097
# 106799                   47.535                      3.934
# 106817                    2.404                      0.174
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 2501                        1.31                    2.1358
# 2528                       1.438                    2.2801
# 2555                        1.43                    2.3454
# 2582                       1.438                    2.2925
# 2609                       1.438                    2.2513
# ...                          ...                       ...
# 106718                     2.886                    3.5162
# 106745                    2.9772                    3.5388
# 106772                       4.2                     4.618
# 106799                        39                      58.2
# 106817                     2.126                    2.7909
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 2501                           0.061    2  2006
# 2528                           0.064    3  2006
# 2555                           0.071    3  2006
# 2582                           0.072    3  2006
# 2609                           0.068    3  2006
# ...                              ...  ...   ...
# 106718                         0.038    6  2019
# 106745                          0.04    6  2019
# 106772                         0.022    6  2019
# 106799                         0.083    6  2019
# 106817                         0.072    6  2019
#
# [3054 rows x 20 columns]

# %% [markdown]
# Alternativamente, poderíamos usar o método `query` para fazermos tal seleção. Porém, isso não é possível especificamente para esse caso, pois o rótulo da coluna 'PREÇO MÉDIO REVENDA' possui caracteres inválidos para o método (cedilha, acentos)

# %%
# Não funciona
# data.query('ESTADO=="RIO DE JANEIRO" and PREÇO MÉDIO REVENDA > 2')

# %%
data.query('ESTADO == "RIO DE JANEIRO" or ESTADO == "SAO PAULO"')
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 22       2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 23       2004-05-09  2004-05-15  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 49       2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 76       2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106805   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
# 106821   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 22                               952              R$/l                1.098
# 23                              4047              R$/l                0.768
# 49                               948              R$/l                1.092
# 50                              4066              R$/l                0.766
# 76                               973              R$/l                1.103
# ...                              ...               ...                  ...
# 106778                          1644              R$/l                4.142
# 106799                           221           R$/13Kg               65.010
# 106805                          1017           R$/13Kg               66.893
# 106817                           124             R$/m3                3.111
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 22                      0.154                 0.740                 1.890
# 23                      0.085                 0.590                 1.150
# 49                      0.157                 0.740                 1.499
# 50                      0.083                 0.590                 1.150
# 76                      0.140                 0.770                 1.589
# ...                       ...                   ...                   ...
# 106778                  0.183                 3.769                 4.999
# 106799                  5.812                50.000                79.000
# 106805                  6.100                50.000                89.900
# 106817                  0.260                 2.799                 3.799
# 106821                  0.229                 2.699                 3.490
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 22                    0.312                     0.140
# 23                    0.198                     0.111
# 49                    0.284                     0.144
# 50                     0.19                     0.108
# 76                    0.281                     0.127
# ...                     ...                       ...
# 106778                0.429                     0.044
# 106799               17.475                     0.089
# 106805               17.679                     0.091
# 106817                0.707                     0.084
# 106821                0.646                     0.076
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 22                        0.786                      0.173
# 23                         0.57                      0.056
# 49                        0.808                      0.175
# 50                        0.576                       0.05
# 76                        0.822                      0.166
# ...                         ...                        ...
# 106778                    3.713                      0.097
# 106799                   47.535                      3.934
# 106805                   49.214                      5.071
# 106817                    2.404                      0.174
# 106821                    2.374                      0.165
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 22                         0.326                     1.263
# 23                        0.4271                    1.4123
# 49                        0.3257                    1.2921
# 50                       0.43204                    0.9724
# 76                       0.38909                    1.1859
# ...                          ...                       ...
# 106778                      3.52                    4.0892
# 106799                        39                      58.2
# 106805                     40.19                        72
# 106817                     2.126                    2.7909
# 106821                    2.0179                    2.5093
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 22                              0.22    5  2004
# 23                             0.098    5  2004
# 49                             0.217    5  2004
# 50                             0.087    5  2004
# 76                             0.202    5  2004
# ...                              ...  ...   ...
# 106778                         0.026    6  2019
# 106799                         0.083    6  2019
# 106805                         0.103    6  2019
# 106817                         0.072    6  2019
# 106821                          0.07    6  2019
#
# [8526 rows x 20 columns]

# %% [markdown]
# **Aprofundando mais ainda**
#
# A primeira comparação `(data['ESTADO'] == 'RIO DE JANEIRO')` checa, linha a linha (amostra a amostra) do DataFrame, quais são aquelas cujo o estado é RIO DE JANEIRO. Nenhuma averiguação de preços é feita nesse momento. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# A segunda comparação `(data['PREÇO MÉDIO REVENDA'] > 2)` checa, linha a linha (amostra a amostra) do DataFrame, quais são os registro cujo preço do combustível é maior que 2 reais. Note que essa comparação checará os postos de **TODOS os estados**. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# Por fim, as duas "perguntas" são unidas pelo AND (&) que retorna a "pergunta completa" que fizemos.

# %% [markdown]
# Alguns podem argumentar que tal abordagem é **ineficiente**, uma vez que, para cada condição ("pergunta"), estamos varrendo todas as linhas do DataFrame. <br/>
# O Pandas _tenta otimizar_ isso ao máximo por de trás dos panos. Mas, de fato, de tivermos um dataset **muito grande** (centenas de milhares de linhas), tal abordagem se tornará _lenta_.

# %% [markdown]
# Assim, poderíamos fazer filtragem com múltiplos condicionais em partes:

# %%
selecao_1 = data['ESTADO'] == 'RIO DE JANEIRO'
selecao_1
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
posto_rj = data[selecao_1]
posto_rj
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 22       2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 49       2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 76       2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 103      2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 130      2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 22                               952              R$/l                1.098
# 49                               948              R$/l                1.092
# 76                               973              R$/l                1.103
# 103                              955              R$/l                1.149
# 130                              966              R$/l                1.165
# ...                              ...               ...                  ...
# 106718                           212              R$/l                3.569
# 106745                           335              R$/l                3.697
# 106772                           422              R$/l                4.928
# 106799                           221           R$/13Kg               65.010
# 106817                           124             R$/m3                3.111
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 22                      0.154                 0.740                 1.890
# 49                      0.157                 0.740                 1.499
# 76                      0.140                 0.770                 1.589
# 103                     0.156                 0.799                 1.599
# 130                     0.154                 0.830                 1.599
# ...                       ...                   ...                   ...
# 106718                  0.166                 3.179                 4.059
# 106745                  0.187                 3.279                 4.389
# 106772                  0.165                 4.599                 5.859
# 106799                  5.812                50.000                79.000
# 106817                  0.260                 2.799                 3.799
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 22                    0.312                     0.140
# 49                    0.284                     0.144
# 76                    0.281                     0.127
# 103                     0.3                     0.136
# 130                   0.254                     0.132
# ...                     ...                       ...
# 106718                0.467                     0.047
# 106745                  0.5                     0.051
# 106772                0.538                     0.033
# 106799               17.475                     0.089
# 106817                0.707                     0.084
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 22                        0.786                      0.173
# 49                        0.808                      0.175
# 76                        0.822                      0.166
# 103                       0.849                      0.188
# 130                       0.911                      0.198
# ...                         ...                        ...
# 106718                    3.102                      0.119
# 106745                    3.197                      0.127
# 106772                     4.39                      0.097
# 106799                   47.535                      3.934
# 106817                    2.404                      0.174
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 22                         0.326                     1.263
# 49                        0.3257                    1.2921
# 76                       0.38909                    1.1859
# 103                       0.3453                    1.3667
# 130                          0.4                    1.3667
# ...                          ...                       ...
# 106718                     2.886                    3.5162
# 106745                    2.9772                    3.5388
# 106772                       4.2                     4.618
# 106799                        39                      58.2
# 106817                     2.126                    2.7909
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 22                              0.22    5  2004
# 49                             0.217    5  2004
# 76                             0.202    5  2004
# 103                            0.221    5  2004
# 130                            0.217    6  2004
# ...                              ...  ...   ...
# 106718                         0.038    6  2019
# 106745                          0.04    6  2019
# 106772                         0.022    6  2019
# 106799                         0.083    6  2019
# 106817                         0.072    6  2019
#
# [4263 rows x 20 columns]

# %%
selecao_2 = posto_rj['PREÇO MÉDIO REVENDA'] > 2.0
selecao_2
# Out:
# 22        False
# 49        False
# 76        False
# 103       False
# 130       False
#           ...
# 106718     True
# 106745     True
# 106772     True
# 106799     True
# 106817     True
# Name: PREÇO MÉDIO REVENDA, Length: 4263, dtype: bool

# %%
posto_rj_preco_maior_2 = posto_rj[selecao_2]
posto_rj_preco_maior_2
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 2501     2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2528     2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2555     2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2582     2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2609     2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 2501                             881              R$/l                2.028
# 2528                             889              R$/l                2.125
# 2555                             902              R$/l                2.163
# 2582                             898              R$/l                2.166
# 2609                             890              R$/l                2.172
# ...                              ...               ...                  ...
# 106718                           212              R$/l                3.569
# 106745                           335              R$/l                3.697
# 106772                           422              R$/l                4.928
# 106799                           221           R$/13Kg               65.010
# 106817                           124             R$/m3                3.111
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 2501                    0.148                 1.589                 2.550
# 2528                    0.149                 1.779                 2.550
# 2555                    0.138                 1.799                 2.599
# 2582                    0.146                 1.760                 2.568
# 2609                    0.143                 1.789                 2.550
# ...                       ...                   ...                   ...
# 106718                  0.166                 3.179                 4.059
# 106745                  0.187                 3.279                 4.389
# 106772                  0.165                 4.599                 5.859
# 106799                  5.812                50.000                79.000
# 106817                  0.260                 2.799                 3.799
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 2501                  0.222                     0.073
# 2528                  0.286                     0.070
# 2555                  0.268                     0.064
# 2582                  0.231                     0.067
# 2609                  0.209                     0.066
# ...                     ...                       ...
# 106718                0.467                     0.047
# 106745                  0.5                     0.051
# 106772                0.538                     0.033
# 106799               17.475                     0.089
# 106817                0.707                     0.084
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 2501                      1.806                       0.11
# 2528                      1.839                      0.117
# 2555                      1.895                      0.134
# 2582                      1.935                       0.14
# 2609                      1.963                      0.133
# ...                         ...                        ...
# 106718                    3.102                      0.119
# 106745                    3.197                      0.127
# 106772                     4.39                      0.097
# 106799                   47.535                      3.934
# 106817                    2.404                      0.174
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 2501                        1.31                    2.1358
# 2528                       1.438                    2.2801
# 2555                        1.43                    2.3454
# 2582                       1.438                    2.2925
# 2609                       1.438                    2.2513
# ...                          ...                       ...
# 106718                     2.886                    3.5162
# 106745                    2.9772                    3.5388
# 106772                       4.2                     4.618
# 106799                        39                      58.2
# 106817                     2.126                    2.7909
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 2501                           0.061    2  2006
# 2528                           0.064    3  2006
# 2555                           0.071    3  2006
# 2582                           0.072    3  2006
# 2609                           0.068    3  2006
# ...                              ...  ...   ...
# 106718                         0.038    6  2019
# 106745                          0.04    6  2019
# 106772                         0.022    6  2019
# 106799                         0.083    6  2019
# 106817                         0.072    6  2019
#
# [3054 rows x 20 columns]

# %% [markdown]
# #### **Selecionando registros de postos de São Paulo ou do Rio de Janeiro com Gasolina Comum acima de 2 reais**

# %% [markdown]
# Podemos fazer a solução do "jeito mais lento", percorrendo o DataFrame inteiro _múltiplas vezes_:

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# 1                1.162                  0.114                  0.89
# 2                1.389                  0.097                  1.18
# 3                1.262                  0.070                  1.09
# 4                1.181                  0.078                  1.05
#
#    PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                 1.350                0.463                     0.012
# 1                 1.449                0.399                     0.098
# 2                 1.760                0.419                     0.070
# 3                 1.509                0.432                     0.055
# 4                 1.400                 0.24                     0.066
#
#   PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                    0.825                       0.11
# 1                    0.763                      0.088
# 2                     0.97                      0.095
# 3                     0.83                      0.119
# 4                    0.941                      0.077
#
#   PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                    0.4201                    0.9666
# 1                    0.5013                      1.05
# 2                    0.5614                     1.161
# 3                    0.5991                   1.22242
# 4                    0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                         0.133    5  2004
# 1                         0.115    5  2004
# 2                         0.098    5  2004
# 3                         0.143    5  2004
# 4                         0.082    5  2004

# %%
selecao_1 = (data.ESTADO == 'SAO PAULO') | (data.ESTADO == 'RIO DE JANEIRO')
selecao_2 = data['PRODUTO'] == 'GASOLINA COMUM'
selecao_3 = data['PREÇO MÉDIO REVENDA'] > 2.0

selecao_final = selecao_1 & selecao_2 & selecao_3

# %%
data_filtrados = data[selecao_final]
data_filtrados
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12167    2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12194    2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 12086                           1071              R$/l                2.045
# 12113                           1055              R$/l                2.040
# 12140                           1091              R$/l                2.042
# 12167                           1055              R$/l                2.053
# 12194                           1091              R$/l                2.063
# ...                              ...               ...                  ...
# 106479                          1643              R$/l                4.210
# 106623                           418              R$/l                4.927
# 106629                          1635              R$/l                4.168
# 106772                           422              R$/l                4.928
# 106778                          1644              R$/l                4.142
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 12086                   0.109                 1.700                 2.599
# 12113                   0.113                 1.700                 2.599
# 12140                   0.108                 1.700                 2.599
# 12167                   0.111                 1.730                 2.599
# 12194                   0.107                 1.760                 2.599
# ...                       ...                   ...                   ...
# 106479                  0.177                 3.759                 4.992
# 106623                  0.160                 4.599                 5.859
# 106629                  0.177                 3.679                 5.199
# 106772                  0.165                 4.599                 5.859
# 106778                  0.183                 3.769                 4.999
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 12086                 0.254                     0.053
# 12113                 0.252                     0.055
# 12140                 0.252                     0.053
# 12167                 0.251                     0.054
# 12194                 0.247                     0.052
# ...                     ...                       ...
# 106479                0.425                     0.042
# 106623                0.544                     0.032
# 106629                0.443                     0.042
# 106772                0.538                     0.033
# 106778                0.429                     0.044
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 12086                     1.791                      0.047
# 12113                     1.788                      0.049
# 12140                      1.79                      0.046
# 12167                     1.802                      0.055
# 12194                     1.816                      0.054
# ...                         ...                        ...
# 106479                    3.785                      0.096
# 106623                    4.383                        0.1
# 106629                    3.725                      0.096
# 106772                     4.39                      0.097
# 106778                    3.713                      0.097
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 12086                     1.6363                    1.9594
# 12113                     1.5943                   1.99651
# 12140                    1.63596                    2.2137
# 12167                       1.64                   2.21425
# 12194                       1.64                   2.32425
# ...                          ...                       ...
# 106479                      3.52                    4.1007
# 106623                    4.1972                    4.6239
# 106629                     3.502                    4.0892
# 106772                       4.2                     4.618
# 106778                      3.52                    4.0892
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 12086                          0.026    5  2004
# 12113                          0.027    5  2004
# 12140                          0.026    5  2004
# 12167                          0.031    5  2004
# 12194                           0.03    6  2004
# ...                              ...  ...   ...
# 106479                         0.025    6  2019
# 106623                         0.023    6  2019
# 106629                         0.026    6  2019
# 106772                         0.022    6  2019
# 106778                         0.026    6  2019
#
# [1564 rows x 20 columns]

# %%
print(data_filtrados.ESTADO.unique(), data_filtrados.PRODUTO.unique())
# Out:
# ['RIO DE JANEIRO' 'SAO PAULO'] ['GASOLINA COMUM']

# %% [markdown]
# <br/>
#
# Alternativamente:

# %%
selecao_1 = (data.ESTADO == 'SAO PAULO') | (data.ESTADO == 'RIO DE JANEIRO')
posto_sp_rj = data[selecao_1]
posto_sp_rj
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 22       2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 23       2004-05-09  2004-05-15  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 49       2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 76       2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106805   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
# 106821   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 22                               952              R$/l                1.098
# 23                              4047              R$/l                0.768
# 49                               948              R$/l                1.092
# 50                              4066              R$/l                0.766
# 76                               973              R$/l                1.103
# ...                              ...               ...                  ...
# 106778                          1644              R$/l                4.142
# 106799                           221           R$/13Kg               65.010
# 106805                          1017           R$/13Kg               66.893
# 106817                           124             R$/m3                3.111
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 22                      0.154                 0.740                 1.890
# 23                      0.085                 0.590                 1.150
# 49                      0.157                 0.740                 1.499
# 50                      0.083                 0.590                 1.150
# 76                      0.140                 0.770                 1.589
# ...                       ...                   ...                   ...
# 106778                  0.183                 3.769                 4.999
# 106799                  5.812                50.000                79.000
# 106805                  6.100                50.000                89.900
# 106817                  0.260                 2.799                 3.799
# 106821                  0.229                 2.699                 3.490
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 22                    0.312                     0.140
# 23                    0.198                     0.111
# 49                    0.284                     0.144
# 50                     0.19                     0.108
# 76                    0.281                     0.127
# ...                     ...                       ...
# 106778                0.429                     0.044
# 106799               17.475                     0.089
# 106805               17.679                     0.091
# 106817                0.707                     0.084
# 106821                0.646                     0.076
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 22                        0.786                      0.173
# 23                         0.57                      0.056
# 49                        0.808                      0.175
# 50                        0.576                       0.05
# 76                        0.822                      0.166
# ...                         ...                        ...
# 106778                    3.713                      0.097
# 106799                   47.535                      3.934
# 106805                   49.214                      5.071
# 106817                    2.404                      0.174
# 106821                    2.374                      0.165
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 22                         0.326                     1.263
# 23                        0.4271                    1.4123
# 49                        0.3257                    1.2921
# 50                       0.43204                    0.9724
# 76                       0.38909                    1.1859
# ...                          ...                       ...
# 106778                      3.52                    4.0892
# 106799                        39                      58.2
# 106805                     40.19                        72
# 106817                     2.126                    2.7909
# 106821                    2.0179                    2.5093
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 22                              0.22    5  2004
# 23                             0.098    5  2004
# 49                             0.217    5  2004
# 50                             0.087    5  2004
# 76                             0.202    5  2004
# ...                              ...  ...   ...
# 106778                         0.026    6  2019
# 106799                         0.083    6  2019
# 106805                         0.103    6  2019
# 106817                         0.072    6  2019
# 106821                          0.07    6  2019
#
# [8526 rows x 20 columns]

# %%
selecao_2 = posto_sp_rj['PRODUTO'] == 'GASOLINA COMUM'
posto_sp_rj_gas = posto_sp_rj[selecao_2]
posto_sp_rj_gas
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12087    2004-05-09  2004-05-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12114    2004-05-16  2004-05-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 12086                           1071              R$/l                2.045
# 12087                           4107              R$/l                1.891
# 12113                           1055              R$/l                2.040
# 12114                           4133              R$/l                1.888
# 12140                           1091              R$/l                2.042
# ...                              ...               ...                  ...
# 106479                          1643              R$/l                4.210
# 106623                           418              R$/l                4.927
# 106629                          1635              R$/l                4.168
# 106772                           422              R$/l                4.928
# 106778                          1644              R$/l                4.142
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 12086                   0.109                 1.700                 2.599
# 12087                   0.101                 1.570                 2.399
# 12113                   0.113                 1.700                 2.599
# 12114                   0.101                 1.540                 2.220
# 12140                   0.108                 1.700                 2.599
# ...                       ...                   ...                   ...
# 106479                  0.177                 3.759                 4.992
# 106623                  0.160                 4.599                 5.859
# 106629                  0.177                 3.679                 5.199
# 106772                  0.165                 4.599                 5.859
# 106778                  0.183                 3.769                 4.999
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 12086                 0.254                     0.053
# 12087                 0.235                     0.053
# 12113                 0.252                     0.055
# 12114                 0.233                     0.053
# 12140                 0.252                     0.053
# ...                     ...                       ...
# 106479                0.425                     0.042
# 106623                0.544                     0.032
# 106629                0.443                     0.042
# 106772                0.538                     0.033
# 106778                0.429                     0.044
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 12086                     1.791                      0.047
# 12087                     1.656                      0.064
# 12113                     1.788                      0.049
# 12114                     1.655                      0.063
# 12140                      1.79                      0.046
# ...                         ...                        ...
# 106479                    3.785                      0.096
# 106623                    4.383                        0.1
# 106629                    3.725                      0.096
# 106772                     4.39                      0.097
# 106778                    3.713                      0.097
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 12086                     1.6363                    1.9594
# 12087                       1.38                     1.944
# 12113                     1.5943                   1.99651
# 12114                       1.38                    1.9319
# 12140                    1.63596                    2.2137
# ...                          ...                       ...
# 106479                      3.52                    4.1007
# 106623                    4.1972                    4.6239
# 106629                     3.502                    4.0892
# 106772                       4.2                     4.618
# 106778                      3.52                    4.0892
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 12086                          0.026    5  2004
# 12087                          0.039    5  2004
# 12113                          0.027    5  2004
# 12114                          0.038    5  2004
# 12140                          0.026    5  2004
# ...                              ...  ...   ...
# 106479                         0.025    6  2019
# 106623                         0.023    6  2019
# 106629                         0.026    6  2019
# 106772                         0.022    6  2019
# 106778                         0.026    6  2019
#
# [1570 rows x 20 columns]

# %%
selecao_3 = posto_sp_rj_gas['PREÇO MÉDIO REVENDA'] > 2.0
posto_sp_rj_gas_maior_2 = posto_sp_rj_gas[selecao_3]
posto_sp_rj_gas_maior_2
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12167    2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12194    2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 12086                           1071              R$/l                2.045
# 12113                           1055              R$/l                2.040
# 12140                           1091              R$/l                2.042
# 12167                           1055              R$/l                2.053
# 12194                           1091              R$/l                2.063
# ...                              ...               ...                  ...
# 106479                          1643              R$/l                4.210
# 106623                           418              R$/l                4.927
# 106629                          1635              R$/l                4.168
# 106772                           422              R$/l                4.928
# 106778                          1644              R$/l                4.142
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 12086                   0.109                 1.700                 2.599
# 12113                   0.113                 1.700                 2.599
# 12140                   0.108                 1.700                 2.599
# 12167                   0.111                 1.730                 2.599
# 12194                   0.107                 1.760                 2.599
# ...                       ...                   ...                   ...
# 106479                  0.177                 3.759                 4.992
# 106623                  0.160                 4.599                 5.859
# 106629                  0.177                 3.679                 5.199
# 106772                  0.165                 4.599                 5.859
# 106778                  0.183                 3.769                 4.999
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 12086                 0.254                     0.053
# 12113                 0.252                     0.055
# 12140                 0.252                     0.053
# 12167                 0.251                     0.054
# 12194                 0.247                     0.052
# ...                     ...                       ...
# 106479                0.425                     0.042
# 106623                0.544                     0.032
# 106629                0.443                     0.042
# 106772                0.538                     0.033
# 106778                0.429                     0.044
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 12086                     1.791                      0.047
# 12113                     1.788                      0.049
# 12140                      1.79                      0.046
# 12167                     1.802                      0.055
# 12194                     1.816                      0.054
# ...                         ...                        ...
# 106479                    3.785                      0.096
# 106623                    4.383                        0.1
# 106629                    3.725                      0.096
# 106772                     4.39                      0.097
# 106778                    3.713                      0.097
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 12086                     1.6363                    1.9594
# 12113                     1.5943                   1.99651
# 12140                    1.63596                    2.2137
# 12167                       1.64                   2.21425
# 12194                       1.64                   2.32425
# ...                          ...                       ...
# 106479                      3.52                    4.1007
# 106623                    4.1972                    4.6239
# 106629                     3.502                    4.0892
# 106772                       4.2                     4.618
# 106778                      3.52                    4.0892
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 12086                          0.026    5  2004
# 12113                          0.027    5  2004
# 12140                          0.026    5  2004
# 12167                          0.031    5  2004
# 12194                           0.03    6  2004
# ...                              ...  ...   ...
# 106479                         0.025    6  2019
# 106623                         0.023    6  2019
# 106629                         0.026    6  2019
# 106772                         0.022    6  2019
# 106778                         0.026    6  2019
#
# [1564 rows x 20 columns]

# %% [markdown]
# #### **Selecionando registros dos anos de 2008, 2010 e 2012**

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# 1                1.162                  0.114                  0.89
# 2                1.389                  0.097                  1.18
# 3                1.262                  0.070                  1.09
# 4                1.181                  0.078                  1.05
#
#    PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                 1.350                0.463                     0.012
# 1                 1.449                0.399                     0.098
# 2                 1.760                0.419                     0.070
# 3                 1.509                0.432                     0.055
# 4                 1.400                 0.24                     0.066
#
#   PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                    0.825                       0.11
# 1                    0.763                      0.088
# 2                     0.97                      0.095
# 3                     0.83                      0.119
# 4                    0.941                      0.077
#
#   PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                    0.4201                    0.9666
# 1                    0.5013                      1.05
# 2                    0.5614                     1.161
# 3                    0.5991                   1.22242
# 4                    0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                         0.133    5  2004
# 1                         0.115    5  2004
# 2                         0.098    5  2004
# 3                         0.143    5  2004
# 4                         0.082    5  2004

# %% [markdown]
# **ALTERNATIVA 1**

# %%
selecao = (data.ANO == 2008) | (data.ANO == 2010) | (data.ANO == 2012)
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ANO, Length: 106823, dtype: bool

# %%
data[selecao]
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# 5099   ETANOL HIDRATADO                           255              R$/l
# 5100   ETANOL HIDRATADO                           142              R$/l
# 5101   ETANOL HIDRATADO                           133              R$/l
# 5102   ETANOL HIDRATADO                            97              R$/l
# ...                 ...                           ...               ...
# 55754               GNV                            17             R$/m3
# 55755               GNV                            34             R$/m3
# 55756               GNV                            41             R$/m3
# 55757               GNV                            82             R$/m3
# 55758               GNV                            11             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 5098                 1.806                  0.082                 1.709
# 5099                 1.616                  0.100                 1.470
# 5100                 1.581                  0.095                 1.390
# 5101                 1.831                  0.046                 1.680
# 5102                 1.699                  0.098                 1.530
# ...                    ...                    ...                   ...
# 55754                1.891                  0.015                 1.860
# 55755                1.980                  0.040                 1.919
# 55756                2.003                  0.034                 1.879
# 55757                1.598                  0.199                 1.399
# 55758                1.847                  0.033                 1.790
#
#        PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 5098                  1.950                 0.29                     0.045
# 5099                  1.899                0.293                     0.062
# 5100                  1.850                0.278                     0.060
# 5101                  1.910                0.382                     0.025
# 5102                  1.999                0.199                     0.058
# ...                     ...                  ...                       ...
# 55754                 1.900                0.466                     0.008
# 55755                 2.140                0.566                     0.020
# 55756                 2.099                    -                     0.017
# 55757                 2.599                0.397                     0.125
# 55758                 1.899                0.504                     0.018
#
#       PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 5098                     1.516                      0.061
# 5099                     1.323                       0.05
# 5100                     1.303                      0.073
# 5101                     1.449                      0.044
# 5102                       1.5                      0.062
# ...                        ...                        ...
# 55754                    1.425                      0.098
# 55755                    1.414                      0.028
# 55756                        -                          -
# 55757                    1.201                      0.182
# 55758                    1.343                      0.178
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 5098                     1.3892                    1.6157
# 5099                     1.2242                    1.6173
# 5100                       1.14                      1.45
# 5101                     1.3247                    1.5514
# 5102                       1.39                    1.7689
# ...                         ...                       ...
# 55754                    1.2657                    1.4789
# 55755                    1.3997                    1.4608
# 55756                         -                         -
# 55757                    0.8354                     1.535
# 55758                    1.1253                     1.543
#
#       COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 5098                           0.04    1  2008
# 5099                          0.038    1  2008
# 5100                          0.056    1  2008
# 5101                           0.03    1  2008
# 5102                          0.041    1  2008
# ...                             ...  ...   ...
# 55754                         0.069   12  2012
# 55755                          0.02   12  2012
# 55756                             -   12  2012
# 55757                         0.152   12  2012
# 55758                         0.133   12  2012
#
# [19576 rows x 20 columns]

# %%
data[selecao]['ANO'].unique()
# Out:
# array([2008, 2010, 2012])

# %% [markdown]
# **ALTERNATIVA 2**

# %%
# usando lista do Python msm
lista_anos = [2008, 2010, 2012]

# %%
selecao = data['ANO'].isin(lista_anos)
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ANO, Length: 106823, dtype: bool

# %%
data[selecao]
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# 5099   ETANOL HIDRATADO                           255              R$/l
# 5100   ETANOL HIDRATADO                           142              R$/l
# 5101   ETANOL HIDRATADO                           133              R$/l
# 5102   ETANOL HIDRATADO                            97              R$/l
# ...                 ...                           ...               ...
# 55754               GNV                            17             R$/m3
# 55755               GNV                            34             R$/m3
# 55756               GNV                            41             R$/m3
# 55757               GNV                            82             R$/m3
# 55758               GNV                            11             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 5098                 1.806                  0.082                 1.709
# 5099                 1.616                  0.100                 1.470
# 5100                 1.581                  0.095                 1.390
# 5101                 1.831                  0.046                 1.680
# 5102                 1.699                  0.098                 1.530
# ...                    ...                    ...                   ...
# 55754                1.891                  0.015                 1.860
# 55755                1.980                  0.040                 1.919
# 55756                2.003                  0.034                 1.879
# 55757                1.598                  0.199                 1.399
# 55758                1.847                  0.033                 1.790
#
#        PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 5098                  1.950                 0.29                     0.045
# 5099                  1.899                0.293                     0.062
# 5100                  1.850                0.278                     0.060
# 5101                  1.910                0.382                     0.025
# 5102                  1.999                0.199                     0.058
# ...                     ...                  ...                       ...
# 55754                 1.900                0.466                     0.008
# 55755                 2.140                0.566                     0.020
# 55756                 2.099                    -                     0.017
# 55757                 2.599                0.397                     0.125
# 55758                 1.899                0.504                     0.018
#
#       PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 5098                     1.516                      0.061
# 5099                     1.323                       0.05
# 5100                     1.303                      0.073
# 5101                     1.449                      0.044
# 5102                       1.5                      0.062
# ...                        ...                        ...
# 55754                    1.425                      0.098
# 55755                    1.414                      0.028
# 55756                        -                          -
# 55757                    1.201                      0.182
# 55758                    1.343                      0.178
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 5098                     1.3892                    1.6157
# 5099                     1.2242                    1.6173
# 5100                       1.14                      1.45
# 5101                     1.3247                    1.5514
# 5102                       1.39                    1.7689
# ...                         ...                       ...
# 55754                    1.2657                    1.4789
# 55755                    1.3997                    1.4608
# 55756                         -                         -
# 55757                    0.8354                     1.535
# 55758                    1.1253                     1.543
#
#       COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 5098                           0.04    1  2008
# 5099                          0.038    1  2008
# 5100                          0.056    1  2008
# 5101                           0.03    1  2008
# 5102                          0.041    1  2008
# ...                             ...  ...   ...
# 55754                         0.069   12  2012
# 55755                          0.02   12  2012
# 55756                             -   12  2012
# 55757                         0.152   12  2012
# 55758                         0.133   12  2012
#
# [19576 rows x 20 columns]

# %% [markdown]
# **ALTERNATIVA 3**

# %%
lista_anos
# Out:
# [2008, 2010, 2012]

# %%
# O arroba @ ele acessa a varivel no caso 'lista_anos'
data.query('ANO in @lista_anos')
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# 5099   ETANOL HIDRATADO                           255              R$/l
# 5100   ETANOL HIDRATADO                           142              R$/l
# 5101   ETANOL HIDRATADO                           133              R$/l
# 5102   ETANOL HIDRATADO                            97              R$/l
# ...                 ...                           ...               ...
# 55754               GNV                            17             R$/m3
# 55755               GNV                            34             R$/m3
# 55756               GNV                            41             R$/m3
# 55757               GNV                            82             R$/m3
# 55758               GNV                            11             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 5098                 1.806                  0.082                 1.709
# 5099                 1.616                  0.100                 1.470
# 5100                 1.581                  0.095                 1.390
# 5101                 1.831                  0.046                 1.680
# 5102                 1.699                  0.098                 1.530
# ...                    ...                    ...                   ...
# 55754                1.891                  0.015                 1.860
# 55755                1.980                  0.040                 1.919
# 55756                2.003                  0.034                 1.879
# 55757                1.598                  0.199                 1.399
# 55758                1.847                  0.033                 1.790
#
#        PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 5098                  1.950                 0.29                     0.045
# 5099                  1.899                0.293                     0.062
# 5100                  1.850                0.278                     0.060
# 5101                  1.910                0.382                     0.025
# 5102                  1.999                0.199                     0.058
# ...                     ...                  ...                       ...
# 55754                 1.900                0.466                     0.008
# 55755                 2.140                0.566                     0.020
# 55756                 2.099                    -                     0.017
# 55757                 2.599                0.397                     0.125
# 55758                 1.899                0.504                     0.018
#
#       PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 5098                     1.516                      0.061
# 5099                     1.323                       0.05
# 5100                     1.303                      0.073
# 5101                     1.449                      0.044
# 5102                       1.5                      0.062
# ...                        ...                        ...
# 55754                    1.425                      0.098
# 55755                    1.414                      0.028
# 55756                        -                          -
# 55757                    1.201                      0.182
# 55758                    1.343                      0.178
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 5098                     1.3892                    1.6157
# 5099                     1.2242                    1.6173
# 5100                       1.14                      1.45
# 5101                     1.3247                    1.5514
# 5102                       1.39                    1.7689
# ...                         ...                       ...
# 55754                    1.2657                    1.4789
# 55755                    1.3997                    1.4608
# 55756                         -                         -
# 55757                    0.8354                     1.535
# 55758                    1.1253                     1.543
#
#       COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 5098                           0.04    1  2008
# 5099                          0.038    1  2008
# 5100                          0.056    1  2008
# 5101                           0.03    1  2008
# 5102                          0.041    1  2008
# ...                             ...  ...   ...
# 55754                         0.069   12  2012
# 55755                          0.02   12  2012
# 55756                             -   12  2012
# 55757                         0.152   12  2012
# 55758                         0.133   12  2012
#
# [19576 rows x 20 columns]

# %% [markdown]
# ### **Iterando com DataFrames**

# %% [markdown]
# #### For-each `DataFrame.iterrows()` (LENTO ==> apenas indicado para iterar pequenos conjunto de dados)

# %%
for idx, row in data.head(7).iterrows():
    print(f'{idx} > {row["ESTADO"]}')
# Out:
# 0 > DISTRITO FEDERAL
# 1 > GOIAS
# 2 > MATO GROSSO
# 3 > MATO GROSSO DO SUL
# 4 > ALAGOAS
# 5 > BAHIA
# 6 > CEARA

# %% [markdown]
# <h2>2. Preparação dos dados</h2>
# <hr/>

# %%
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 106818               GNV                             7             R$/m3
# 106819               GNV                            23             R$/m3
# 106820               GNV                            24             R$/m3
# 106821               GNV                            52             R$/m3
# 106822               GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                     1.288                  0.016                 1.190
# 1                     1.162                  0.114                 0.890
# 2                     1.389                  0.097                 1.180
# 3                     1.262                  0.070                 1.090
# 4                     1.181                  0.078                 1.050
# ...                     ...                    ...                   ...
# 106818                3.574                  0.065                 3.499
# 106819                3.401                  0.129                 3.230
# 106820                2.912                  0.190                 2.699
# 106821                3.020                  0.229                 2.699
# 106822                3.697                  0.005                 3.689
#
#         PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                0.463                     0.012
# 1                      1.449                0.399                     0.098
# 2                      1.760                0.419                     0.070
# 3                      1.509                0.432                     0.055
# 4                      1.400                 0.24                     0.066
# ...                      ...                  ...                       ...
# 106818                 3.690                0.818                     0.018
# 106819                 3.789                 0.95                     0.038
# 106820                 3.499                0.914                     0.065
# 106821                 3.490                0.646                     0.076
# 106822                 3.699                1.179                     0.001
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.11
# 1                         0.763                      0.088
# 2                          0.97                      0.095
# 3                          0.83                      0.119
# 4                         0.941                      0.077
# ...                         ...                        ...
# 106818                    2.756                          0
# 106819                    2.451                      0.402
# 106820                    1.998                          0
# 106821                    2.374                      0.165
# 106822                    2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                              0.133    5  2004
# 1                              0.115    5  2004
# 2                              0.098    5  2004
# 3                              0.143    5  2004
# 4                              0.082    5  2004
# ...                              ...  ...   ...
# 106818                             0    6  2019
# 106819                         0.164    6  2019
# 106820                             0    6  2019
# 106821                          0.07    6  2019
# 106822                             0    6  2019
#
# [106823 rows x 20 columns]

# %% [markdown]
# ### 2.1 Removendo amostras com valores vazios (null / nan) no dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  object
#  1   DATA FINAL                     106823 non-null  object
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           106823 non-null  object
#  12  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  object
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  object
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  object
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  object
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  object
#  18  MÊS                            106823 non-null  int64
#  19  ANO                            106823 non-null  int64
# dtypes: float64(5), int64(3), object(12)
# memory usage: 16.3+ MB

# %% [markdown]
# De um total de 106823 observações, **não há valores null** / nan para nenhum atributo. Mas, veremos que não é bem assim neste caso específico.<br/><br/>

# %% [markdown]
# ### 2.2 Conversão de tipos de atributos

# %% [markdown]
# O pandas automaticamente reconhece os tipos de dados de cada coluna. <br/>
# Porém, existem alguns atributos que estão com seus tipos errados: P. ex., "PREÇO MÉDIO DISTRIBUIÇÃO" deveria ser ```float64``` e não ```object```.<br/>
# Nestes casos, muito provavelmente algumas amostras têm um string ao invés de um número para tais atributos. <br/>
#
# Os atributos *"DATA INICIAL"* e *"DATA FINAL"* deveriam ser do tipo `datetime`.
#
# Em outros casos, alguns **atributos categóricos** são ```objects```, mas poderiam ter o tipo ```category```, que é um tipo especial do pandas. <br/>
# Este tipo é necessário para se utilizar algumas funções específicas do pandas. <br/>
# **Não** converteremos para este tipo por ora.

# %%
# trabalharemos com uma cópia
data_pre = data.copy()

# %% [markdown]
# #### **Datas**
# Como os atributos de data do datset já estão em um formato de data aceitável (YYYY-MM-DD), não precisamos forçar nenhuma conversão nesse sentido.

# %%
data_pre['DATA INICIAL'] = pd.to_datetime(data_pre['DATA INICIAL'])
data_pre['DATA FINAL'] = pd.to_datetime(data_pre['DATA FINAL'])

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  datetime64[ns]
#  1   DATA FINAL                     106823 non-null  datetime64[ns]
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           106823 non-null  object
#  12  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  object
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  object
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  object
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  object
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  object
#  18  MÊS                            106823 non-null  int64
#  19  ANO                            106823 non-null  int64
# dtypes: datetime64[ns](2), float64(5), int64(3), object(10)
# memory usage: 16.3+ MB

# %% [markdown]
# #### **Dados Numéricos**

# %%
for atributo in [
    'MARGEM MÉDIA REVENDA',
    'PREÇO MÉDIO DISTRIBUIÇÃO',
    'DESVIO PADRÃO DISTRIBUIÇÃO',
    'PREÇO MÍNIMO DISTRIBUIÇÃO',
    'PREÇO MÁXIMO DISTRIBUIÇÃO',
    'COEF DE VARIAÇÃO DISTRIBUIÇÃO',
]:
    # converte string para numerico
    # em caso de nao conversao retorna (null/NaN)
    data_pre[atributo] = pd.to_numeric(data_pre[atributo], errors='coerce')

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  datetime64[ns]
#  1   DATA FINAL                     106823 non-null  datetime64[ns]
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           103392 non-null  float64
#  12  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       103423 non-null  float64
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     103423 non-null  float64
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      103423 non-null  float64
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      103423 non-null  float64
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  103423 non-null  float64
#  18  MÊS                            106823 non-null  int64
#  19  ANO                            106823 non-null  int64
# dtypes: datetime64[ns](2), float64(11), int64(3), object(4)
# memory usage: 16.3+ MB

# %% [markdown]
# <br/>
#
# Note que temos vários valores ***null*** agora **após a *conversão de tipos***. Vamos checá-los com mais cuidado nos dados originais e preprocessados.

# %% [markdown]
# ### 2.3 Limpeza de dados

# %%
mask = data_pre['PREÇO MÉDIO DISTRIBUIÇÃO'].isnull()

# %%
data_pre[mask]  # uma cópia
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                               2              R$/l                1.694
# 1958                               3              R$/l                2.000
# 2012                               3              R$/l                2.277
# 2497                              11              R$/l                2.182
# 3199                              22              R$/l                2.285
# ...                              ...               ...                  ...
# 106664                             5             R$/m3                3.445
# 106666                             7             R$/m3                3.132
# 106811                             4             R$/m3                3.299
# 106813                             6             R$/m3                3.548
# 106815                             1             R$/m3                3.290
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 1903                    0.283                 1.690                 2.090
# 1958                    0.000                 2.000                 2.000
# 2012                    0.023                 2.250                 2.290
# 2497                    0.040                 2.100                 2.200
# 3199                    0.068                 1.980                 2.300
# ...                       ...                   ...                   ...
# 106664                  0.147                 3.347                 3.699
# 106666                  0.295                 3.049                 3.890
# 106811                  0.005                 3.290                 3.299
# 106813                  0.100                 3.495                 3.699
# 106815                  0.000                 3.290                 3.290
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 1903                     NaN                     0.167
# 1958                     NaN                     0.000
# 2012                     NaN                     0.010
# 2497                     NaN                     0.018
# 3199                     NaN                     0.030
# ...                      ...                       ...
# 106664                   NaN                     0.043
# 106666                   NaN                     0.094
# 106811                   NaN                     0.002
# 106813                   NaN                     0.028
# 106815                   NaN                     0.000
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 1903                         NaN                         NaN
# 1958                         NaN                         NaN
# 2012                         NaN                         NaN
# 2497                         NaN                         NaN
# 3199                         NaN                         NaN
# ...                          ...                         ...
# 106664                       NaN                         NaN
# 106666                       NaN                         NaN
# 106811                       NaN                         NaN
# 106813                       NaN                         NaN
# 106815                       NaN                         NaN
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 1903                          NaN                        NaN
# 1958                          NaN                        NaN
# 2012                          NaN                        NaN
# 2497                          NaN                        NaN
# 3199                          NaN                        NaN
# ...                           ...                        ...
# 106664                        NaN                        NaN
# 106666                        NaN                        NaN
# 106811                        NaN                        NaN
# 106813                        NaN                        NaN
# 106815                        NaN                        NaN
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 1903                              NaN    9  2005
# 1958                              NaN   10  2005
# 2012                              NaN   10  2005
# 2497                              NaN    2  2006
# 3199                              NaN    8  2006
# ...                               ...  ...   ...
# 106664                            NaN    6  2019
# 106666                            NaN    6  2019
# 106811                            NaN    6  2019
# 106813                            NaN    6  2019
# 106815                            NaN    6  2019
#
# [3400 rows x 20 columns]

# %%
data[mask]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25  2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09  2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23  2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26  2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27  2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106664   2019-06-16  2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16  2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23  2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23  2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23  2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                               2              R$/l                1.694
# 1958                               3              R$/l                2.000
# 2012                               3              R$/l                2.277
# 2497                              11              R$/l                2.182
# 3199                              22              R$/l                2.285
# ...                              ...               ...                  ...
# 106664                             5             R$/m3                3.445
# 106666                             7             R$/m3                3.132
# 106811                             4             R$/m3                3.299
# 106813                             6             R$/m3                3.548
# 106815                             1             R$/m3                3.290
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 1903                    0.283                 1.690                 2.090
# 1958                    0.000                 2.000                 2.000
# 2012                    0.023                 2.250                 2.290
# 2497                    0.040                 2.100                 2.200
# 3199                    0.068                 1.980                 2.300
# ...                       ...                   ...                   ...
# 106664                  0.147                 3.347                 3.699
# 106666                  0.295                 3.049                 3.890
# 106811                  0.005                 3.290                 3.299
# 106813                  0.100                 3.495                 3.699
# 106815                  0.000                 3.290                 3.290
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 1903                      -                     0.167
# 1958                      -                     0.000
# 2012                      -                     0.010
# 2497                      -                     0.018
# 3199                      -                     0.030
# ...                     ...                       ...
# 106664                    -                     0.043
# 106666                    -                     0.094
# 106811                    -                     0.002
# 106813                    -                     0.028
# 106815                    -                     0.000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 1903                          -                          -
# 1958                          -                          -
# 2012                          -                          -
# 2497                          -                          -
# 3199                          -                          -
# ...                         ...                        ...
# 106664                        -                          -
# 106666                        -                          -
# 106811                        -                          -
# 106813                        -                          -
# 106815                        -                          -
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 1903                           -                         -
# 1958                           -                         -
# 2012                           -                         -
# 2497                           -                         -
# 3199                           -                         -
# ...                          ...                       ...
# 106664                         -                         -
# 106666                         -                         -
# 106811                         -                         -
# 106813                         -                         -
# 106815                         -                         -
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 1903                               -    9  2005
# 1958                               -   10  2005
# 2012                               -   10  2005
# 2497                               -    2  2006
# 3199                               -    8  2006
# ...                              ...  ...   ...
# 106664                             -    6  2019
# 106666                             -    6  2019
# 106811                             -    6  2019
# 106813                             -    6  2019
# 106815                             -    6  2019
#
# [3400 rows x 20 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  object
#  1   DATA FINAL                     106823 non-null  object
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           106823 non-null  object
#  12  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  object
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  object
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  object
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  object
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  object
#  18  MÊS                            106823 non-null  int64
#  19  ANO                            106823 non-null  int64
# dtypes: float64(5), int64(3), object(12)
# memory usage: 16.3+ MB

# %% [markdown]
# Várias amostras possuem a _string '-'_ em algumas colunas ao invés de um número de fato. Ou seja, não há aferições destes atributos para estas amostras. <br/>
#
# <br/>
#
# Poderíamos **preencher os valores NaN com um valor padrão**. Para isso, basta usar o método `.fillna`.

# %%
# retorna uma cópia, para todos NaN das colunas passa a ser 0
# para altera no proprio dataframe usar in-place=True
data_pre_fill = data_pre.fillna(0)
data_pre_fill
# Out:
#        DATA INICIAL DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09 2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09 2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09 2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09 2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09 2004-05-15      NORDESTE              ALAGOAS
# ...             ...        ...           ...                  ...
# 106818   2019-06-23 2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23 2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23 2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23 2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23 2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 106818               GNV                             7             R$/m3
# 106819               GNV                            23             R$/m3
# 106820               GNV                            24             R$/m3
# 106821               GNV                            52             R$/m3
# 106822               GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                     1.288                  0.016                 1.190
# 1                     1.162                  0.114                 0.890
# 2                     1.389                  0.097                 1.180
# 3                     1.262                  0.070                 1.090
# 4                     1.181                  0.078                 1.050
# ...                     ...                    ...                   ...
# 106818                3.574                  0.065                 3.499
# 106819                3.401                  0.129                 3.230
# 106820                2.912                  0.190                 2.699
# 106821                3.020                  0.229                 2.699
# 106822                3.697                  0.005                 3.689
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                     0.012
# 1                      1.449                 0.399                     0.098
# 2                      1.760                 0.419                     0.070
# 3                      1.509                 0.432                     0.055
# 4                      1.400                 0.240                     0.066
# ...                      ...                   ...                       ...
# 106818                 3.690                 0.818                     0.018
# 106819                 3.789                 0.950                     0.038
# 106820                 3.499                 0.914                     0.065
# 106821                 3.490                 0.646                     0.076
# 106822                 3.699                 1.179                     0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 106818                     2.756                       0.000
# 106819                     2.451                       0.402
# 106820                     1.998                       0.000
# 106821                     2.374                       0.165
# 106822                     2.518                       0.000
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.96660
# 1                          0.5013                    1.05000
# 2                          0.5614                    1.16100
# 3                          0.5991                    1.22242
# 4                          0.7441                    1.03170
# ...                           ...                        ...
# 106818                     2.7560                    2.75600
# 106819                     1.9842                    2.86610
# 106820                     1.9981                    1.99810
# 106821                     2.0179                    2.50930
# 106822                     2.5175                    2.51750
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                               0.133    5  2004
# 1                               0.115    5  2004
# 2                               0.098    5  2004
# 3                               0.143    5  2004
# 4                               0.082    5  2004
# ...                               ...  ...   ...
# 106818                          0.000    6  2019
# 106819                          0.164    6  2019
# 106820                          0.000    6  2019
# 106821                          0.070    6  2019
# 106822                          0.000    6  2019
#
# [106823 rows x 20 columns]

# %%
data_pre_fill[mask]  # valores antes NaN, agora 0
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                               2              R$/l                1.694
# 1958                               3              R$/l                2.000
# 2012                               3              R$/l                2.277
# 2497                              11              R$/l                2.182
# 3199                              22              R$/l                2.285
# ...                              ...               ...                  ...
# 106664                             5             R$/m3                3.445
# 106666                             7             R$/m3                3.132
# 106811                             4             R$/m3                3.299
# 106813                             6             R$/m3                3.548
# 106815                             1             R$/m3                3.290
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 1903                    0.283                 1.690                 2.090
# 1958                    0.000                 2.000                 2.000
# 2012                    0.023                 2.250                 2.290
# 2497                    0.040                 2.100                 2.200
# 3199                    0.068                 1.980                 2.300
# ...                       ...                   ...                   ...
# 106664                  0.147                 3.347                 3.699
# 106666                  0.295                 3.049                 3.890
# 106811                  0.005                 3.290                 3.299
# 106813                  0.100                 3.495                 3.699
# 106815                  0.000                 3.290                 3.290
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 1903                     0.0                     0.167
# 1958                     0.0                     0.000
# 2012                     0.0                     0.010
# 2497                     0.0                     0.018
# 3199                     0.0                     0.030
# ...                      ...                       ...
# 106664                   0.0                     0.043
# 106666                   0.0                     0.094
# 106811                   0.0                     0.002
# 106813                   0.0                     0.028
# 106815                   0.0                     0.000
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 1903                         0.0                         0.0
# 1958                         0.0                         0.0
# 2012                         0.0                         0.0
# 2497                         0.0                         0.0
# 3199                         0.0                         0.0
# ...                          ...                         ...
# 106664                       0.0                         0.0
# 106666                       0.0                         0.0
# 106811                       0.0                         0.0
# 106813                       0.0                         0.0
# 106815                       0.0                         0.0
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 1903                          0.0                        0.0
# 1958                          0.0                        0.0
# 2012                          0.0                        0.0
# 2497                          0.0                        0.0
# 3199                          0.0                        0.0
# ...                           ...                        ...
# 106664                        0.0                        0.0
# 106666                        0.0                        0.0
# 106811                        0.0                        0.0
# 106813                        0.0                        0.0
# 106815                        0.0                        0.0
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 1903                              0.0    9  2005
# 1958                              0.0   10  2005
# 2012                              0.0   10  2005
# 2497                              0.0    2  2006
# 3199                              0.0    8  2006
# ...                               ...  ...   ...
# 106664                            0.0    6  2019
# 106666                            0.0    6  2019
# 106811                            0.0    6  2019
# 106813                            0.0    6  2019
# 106815                            0.0    6  2019
#
# [3400 rows x 20 columns]

# %%
data_pre[mask]  # não foi alterado
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                               2              R$/l                1.694
# 1958                               3              R$/l                2.000
# 2012                               3              R$/l                2.277
# 2497                              11              R$/l                2.182
# 3199                              22              R$/l                2.285
# ...                              ...               ...                  ...
# 106664                             5             R$/m3                3.445
# 106666                             7             R$/m3                3.132
# 106811                             4             R$/m3                3.299
# 106813                             6             R$/m3                3.548
# 106815                             1             R$/m3                3.290
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 1903                    0.283                 1.690                 2.090
# 1958                    0.000                 2.000                 2.000
# 2012                    0.023                 2.250                 2.290
# 2497                    0.040                 2.100                 2.200
# 3199                    0.068                 1.980                 2.300
# ...                       ...                   ...                   ...
# 106664                  0.147                 3.347                 3.699
# 106666                  0.295                 3.049                 3.890
# 106811                  0.005                 3.290                 3.299
# 106813                  0.100                 3.495                 3.699
# 106815                  0.000                 3.290                 3.290
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 1903                     NaN                     0.167
# 1958                     NaN                     0.000
# 2012                     NaN                     0.010
# 2497                     NaN                     0.018
# 3199                     NaN                     0.030
# ...                      ...                       ...
# 106664                   NaN                     0.043
# 106666                   NaN                     0.094
# 106811                   NaN                     0.002
# 106813                   NaN                     0.028
# 106815                   NaN                     0.000
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 1903                         NaN                         NaN
# 1958                         NaN                         NaN
# 2012                         NaN                         NaN
# 2497                         NaN                         NaN
# 3199                         NaN                         NaN
# ...                          ...                         ...
# 106664                       NaN                         NaN
# 106666                       NaN                         NaN
# 106811                       NaN                         NaN
# 106813                       NaN                         NaN
# 106815                       NaN                         NaN
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 1903                          NaN                        NaN
# 1958                          NaN                        NaN
# 2012                          NaN                        NaN
# 2497                          NaN                        NaN
# 3199                          NaN                        NaN
# ...                           ...                        ...
# 106664                        NaN                        NaN
# 106666                        NaN                        NaN
# 106811                        NaN                        NaN
# 106813                        NaN                        NaN
# 106815                        NaN                        NaN
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 1903                              NaN    9  2005
# 1958                              NaN   10  2005
# 2012                              NaN   10  2005
# 2497                              NaN    2  2006
# 3199                              NaN    8  2006
# ...                               ...  ...   ...
# 106664                            NaN    6  2019
# 106666                            NaN    6  2019
# 106811                            NaN    6  2019
# 106813                            NaN    6  2019
# 106815                            NaN    6  2019
#
# [3400 rows x 20 columns]

# %%
# retorna uma copida dataframe personalizado por atributo
data_pre_fill = data_pre.fillna(
    value={
        'PREÇO MÉDIO DISTRIBUIÇÃO': 10,
        'DESVIO PADRÃO DISTRIBUIÇÃO': 20,
        'PREÇO MÍNIMO DISTRIBUIÇÃO': 30,
        'PREÇO MÁXIMO DISTRIBUIÇÃO': 'vazio',
    }
)

# %%
data_pre_fill[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                               2              R$/l                1.694
# 1958                               3              R$/l                2.000
# 2012                               3              R$/l                2.277
# 2497                              11              R$/l                2.182
# 3199                              22              R$/l                2.285
# ...                              ...               ...                  ...
# 106664                             5             R$/m3                3.445
# 106666                             7             R$/m3                3.132
# 106811                             4             R$/m3                3.299
# 106813                             6             R$/m3                3.548
# 106815                             1             R$/m3                3.290
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 1903                    0.283                 1.690                 2.090
# 1958                    0.000                 2.000                 2.000
# 2012                    0.023                 2.250                 2.290
# 2497                    0.040                 2.100                 2.200
# 3199                    0.068                 1.980                 2.300
# ...                       ...                   ...                   ...
# 106664                  0.147                 3.347                 3.699
# 106666                  0.295                 3.049                 3.890
# 106811                  0.005                 3.290                 3.299
# 106813                  0.100                 3.495                 3.699
# 106815                  0.000                 3.290                 3.290
#
#         MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 1903                     NaN                     0.167
# 1958                     NaN                     0.000
# 2012                     NaN                     0.010
# 2497                     NaN                     0.018
# 3199                     NaN                     0.030
# ...                      ...                       ...
# 106664                   NaN                     0.043
# 106666                   NaN                     0.094
# 106811                   NaN                     0.002
# 106813                   NaN                     0.028
# 106815                   NaN                     0.000
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 1903                        10.0                        20.0
# 1958                        10.0                        20.0
# 2012                        10.0                        20.0
# 2497                        10.0                        20.0
# 3199                        10.0                        20.0
# ...                          ...                         ...
# 106664                      10.0                        20.0
# 106666                      10.0                        20.0
# 106811                      10.0                        20.0
# 106813                      10.0                        20.0
# 106815                      10.0                        20.0
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 1903                         30.0                     vazio
# 1958                         30.0                     vazio
# 2012                         30.0                     vazio
# 2497                         30.0                     vazio
# 3199                         30.0                     vazio
# ...                           ...                       ...
# 106664                       30.0                     vazio
# 106666                       30.0                     vazio
# 106811                       30.0                     vazio
# 106813                       30.0                     vazio
# 106815                       30.0                     vazio
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 1903                              NaN    9  2005
# 1958                              NaN   10  2005
# 2012                              NaN   10  2005
# 2497                              NaN    2  2006
# 3199                              NaN    8  2006
# ...                               ...  ...   ...
# 106664                            NaN    6  2019
# 106666                            NaN    6  2019
# 106811                            NaN    6  2019
# 106813                            NaN    6  2019
# 106815                            NaN    6  2019
#
# [3400 rows x 20 columns]

# %% [markdown]
# <br/>
#
# Por mais que a função `fillna` seja interessante e útil em muitos casos, no problema em questão estamos interessados em analisar precisamente, p. ex., o **'PREÇO MÉDIO DISTRIBUIÇÃO'**.<br/>
# A fim de não termos valores _sintéticos_ gerados pelo `fillna`, que possam atrapalhar nossa análise, iremos **remover (drop) todas as amostras que possuem qualquer valor NaN** para quaisquer atributos/colunas. <br/>
#
# Para isso, basta utilizarmos o método `dropna`.

# %%
# remove no proprio dataframe todas as linhas/observacao/registro com valor
# NaN em qualquer colula/atributo
data_pre.dropna(inplace=True)

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 103392 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   103392 non-null  datetime64[ns]
#  1   DATA FINAL                     103392 non-null  datetime64[ns]
#  2   REGIÃO                         103392 non-null  object
#  3   ESTADO                         103392 non-null  object
#  4   PRODUTO                        103392 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   103392 non-null  int64
#  6   UNIDADE DE MEDIDA              103392 non-null  object
#  7   PREÇO MÉDIO REVENDA            103392 non-null  float64
#  8   DESVIO PADRÃO REVENDA          103392 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           103392 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           103392 non-null  float64
#  11  MARGEM MÉDIA REVENDA           103392 non-null  float64
#  12  COEF DE VARIAÇÃO REVENDA       103392 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       103392 non-null  float64
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     103392 non-null  float64
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      103392 non-null  float64
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      103392 non-null  float64
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  103392 non-null  float64
#  18  MÊS                            103392 non-null  int64
#  19  ANO                            103392 non-null  int64
# dtypes: datetime64[ns](2), float64(11), int64(3), object(4)
# memory usage: 16.6+ MB

# %% [markdown]
# Nosso data frame agora, após essa _limpeza_, ficou mais enxuto, contentdo 103392 registros frente aos 106823 registros originais. <br/>
#
# Essas são apenas algumas das possíveis _técnicas de limpeza de dados_. Outras estratégias, p. ex., **confiam na detecção de outliers**, que não veremos neste curso.

# %% [markdown]
# #### **Salvando o Dataset Preprocessado**

# %%
data_pre.to_csv(
    './datasets/GasPricesinBrazil_2004-2019_preprocessado_final.csv', index=False
)

# %% [markdown]
# <h2>3. Estatísticas Descritivas</h2>
# <hr/>

# %% [markdown]
# O Pandas fornecem algumas funções/métodos ue computam certas estatísticas descritivas.

# %% [markdown]
# `describe`: exibe várias **estatísticas descritivas** para os _atributos_ de um dataframe ou para uma _Series_.

# %%
data_final = pd.read_csv(
    './datasets/GasPricesinBrazil_2004-2019_preprocessado_final.csv'
)

# %%
data_final
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 106818               GNV                             7             R$/m3
# 106819               GNV                            23             R$/m3
# 106820               GNV                            24             R$/m3
# 106821               GNV                            52             R$/m3
# 106822               GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                     1.288                  0.016                 1.190
# 1                     1.162                  0.114                 0.890
# 2                     1.389                  0.097                 1.180
# 3                     1.262                  0.070                 1.090
# 4                     1.181                  0.078                 1.050
# ...                     ...                    ...                   ...
# 106818                3.574                  0.065                 3.499
# 106819                3.401                  0.129                 3.230
# 106820                2.912                  0.190                 2.699
# 106821                3.020                  0.229                 2.699
# 106822                3.697                  0.005                 3.689
#
#         PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                0.463                     0.012
# 1                      1.449                0.399                     0.098
# 2                      1.760                0.419                     0.070
# 3                      1.509                0.432                     0.055
# 4                      1.400                 0.24                     0.066
# ...                      ...                  ...                       ...
# 106818                 3.690                0.818                     0.018
# 106819                 3.789                 0.95                     0.038
# 106820                 3.499                0.914                     0.065
# 106821                 3.490                0.646                     0.076
# 106822                 3.699                1.179                     0.001
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.11
# 1                         0.763                      0.088
# 2                          0.97                      0.095
# 3                          0.83                      0.119
# 4                         0.941                      0.077
# ...                         ...                        ...
# 106818                    2.756                          0
# 106819                    2.451                      0.402
# 106820                    1.998                          0
# 106821                    2.374                      0.165
# 106822                    2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                              0.133    5  2004
# 1                              0.115    5  2004
# 2                              0.098    5  2004
# 3                              0.143    5  2004
# 4                              0.082    5  2004
# ...                              ...  ...   ...
# 106818                             0    6  2019
# 106819                         0.164    6  2019
# 106820                             0    6  2019
# 106821                          0.07    6  2019
# 106822                             0    6  2019
#
# [106823 rows x 20 columns]

# %%
data_final.describe()  # dataframe
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 106823.000000        106823.000000
# mean                     233.770976            10.870780
# std                      403.282519            17.752533
# min                        1.000000             0.766000
# 25%                       42.000000             2.072000
# 50%                      104.000000             2.718000
# 75%                      243.000000             3.752000
# max                     4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          106823.000000         106823.000000         106823.000000
# mean                0.657227              9.416038             12.537731
# std                 1.349169             15.092193             20.841497
# min                 0.000000              0.590000              0.999000
# 25%                 0.072000              1.900000              2.310000
# 50%                 0.114000              2.510000              2.999000
# 75%                 0.191000              3.499000              4.150000
# max                10.748000             90.000000            120.000000
#
#        COEF DE VARIAÇÃO REVENDA            MÊS            ANO
# count             106823.000000  106823.000000  106823.000000
# mean                   0.045418       6.484006    2011.802271
# std                    0.025066       3.443391       4.391530
# min                    0.000000       1.000000    2004.000000
# 25%                    0.029000       4.000000    2008.000000
# 50%                    0.041000       6.000000    2012.000000
# 75%                    0.058000       9.000000    2016.000000
# max                    0.395000      12.000000    2019.000000

# %%
data_final['DESVIO PADRÃO REVENDA'].describe()  # aqui nao carrega todo dataframe
# Out:
# count    106823.000000
# mean          0.657227
# std           1.349169
# min           0.000000
# 25%           0.072000
# 50%           0.114000
# 75%           0.191000
# max          10.748000
# Name: DESVIO PADRÃO REVENDA, dtype: float64

# %% [markdown]
# <br/>
#
# Como o resultado do `describe` de um _dataframe_ é outro _dataframe_, podemos filtrar apenas algumas colunas.

# %%
data_final.describe()['DESVIO PADRÃO REVENDA']
# Out:
# count    106823.000000
# mean          0.657227
# std           1.349169
# min           0.000000
# 25%           0.072000
# 50%           0.114000
# 75%           0.191000
# max          10.748000
# Name: DESVIO PADRÃO REVENDA, dtype: float64

# %%
stats = data_final.describe()
stats
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 106823.000000        106823.000000
# mean                     233.770976            10.870780
# std                      403.282519            17.752533
# min                        1.000000             0.766000
# 25%                       42.000000             2.072000
# 50%                      104.000000             2.718000
# 75%                      243.000000             3.752000
# max                     4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          106823.000000         106823.000000         106823.000000
# mean                0.657227              9.416038             12.537731
# std                 1.349169             15.092193             20.841497
# min                 0.000000              0.590000              0.999000
# 25%                 0.072000              1.900000              2.310000
# 50%                 0.114000              2.510000              2.999000
# 75%                 0.191000              3.499000              4.150000
# max                10.748000             90.000000            120.000000
#
#        COEF DE VARIAÇÃO REVENDA            MÊS            ANO
# count             106823.000000  106823.000000  106823.000000
# mean                   0.045418       6.484006    2011.802271
# std                    0.025066       3.443391       4.391530
# min                    0.000000       1.000000    2004.000000
# 25%                    0.029000       4.000000    2008.000000
# 50%                    0.041000       6.000000    2012.000000
# 75%                    0.058000       9.000000    2016.000000
# max                    0.395000      12.000000    2019.000000

# %%
# pode-se fazer pra N atributos
stats[['PREÇO MÉDIO REVENDA', 'DESVIO PADRÃO REVENDA']]
# Out:
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA
# count        106823.000000          106823.000000
# mean             10.870780               0.657227
# std              17.752533               1.349169
# min               0.766000               0.000000
# 25%               2.072000               0.072000
# 50%               2.718000               0.114000
# 75%               3.752000               0.191000
# max              99.357000              10.748000

# %%
data_final[['PREÇO MÉDIO REVENDA', 'DESVIO PADRÃO REVENDA']].describe()
# Out:
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA
# count        106823.000000          106823.000000
# mean             10.870780               0.657227
# std              17.752533               1.349169
# min               0.766000               0.000000
# 25%               2.072000               0.072000
# 50%               2.718000               0.114000
# 75%               3.752000               0.191000
# max              99.357000              10.748000

# %% [markdown]
# **Acessando apenas algumas estatísticas**

# %%
stats
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 106823.000000        106823.000000
# mean                     233.770976            10.870780
# std                      403.282519            17.752533
# min                        1.000000             0.766000
# 25%                       42.000000             2.072000
# 50%                      104.000000             2.718000
# 75%                      243.000000             3.752000
# max                     4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          106823.000000         106823.000000         106823.000000
# mean                0.657227              9.416038             12.537731
# std                 1.349169             15.092193             20.841497
# min                 0.000000              0.590000              0.999000
# 25%                 0.072000              1.900000              2.310000
# 50%                 0.114000              2.510000              2.999000
# 75%                 0.191000              3.499000              4.150000
# max                10.748000             90.000000            120.000000
#
#        COEF DE VARIAÇÃO REVENDA            MÊS            ANO
# count             106823.000000  106823.000000  106823.000000
# mean                   0.045418       6.484006    2011.802271
# std                    0.025066       3.443391       4.391530
# min                    0.000000       1.000000    2004.000000
# 25%                    0.029000       4.000000    2008.000000
# 50%                    0.041000       6.000000    2012.000000
# 75%                    0.058000       9.000000    2016.000000
# max                    0.395000      12.000000    2019.000000

# %%
stats.loc[['min', 'max', 'mean']]
# Out:
#       NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# min                       1.000000              0.76600
# max                    4167.000000             99.35700
# mean                    233.770976             10.87078
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# min                0.000000              0.590000              0.999000
# max               10.748000             90.000000            120.000000
# mean               0.657227              9.416038             12.537731
#
#       COEF DE VARIAÇÃO REVENDA        MÊS          ANO
# min                   0.000000   1.000000  2004.000000
# max                   0.395000  12.000000  2019.000000
# mean                  0.045418   6.484006  2011.802271

# %%
stats.loc[
    ['min', 'max', 'mean'],
    'PREÇO MÍNIMO REVENDA',
]
# Out:
# min      0.590000
# max     90.000000
# mean     9.416038
# Name: PREÇO MÍNIMO REVENDA, dtype: float64

# %%
stats.loc[['min', 'max', 'mean'], ['PREÇO MÍNIMO REVENDA', 'PREÇO MÁXIMO REVENDA']]
# Out:
#       PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA
# min               0.590000              0.999000
# max              90.000000            120.000000
# mean              9.416038             12.537731

# %% [markdown]
# <br/>
#
# `mean`, `std`, `min`, etc: cada uma das estatísticas do `describe` podem ser computadas individualmente:

# %%
data_final.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# 1                1.162                  0.114                  0.89
# 2                1.389                  0.097                  1.18
# 3                1.262                  0.070                  1.09
# 4                1.181                  0.078                  1.05
#
#    PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                 1.350                0.463                     0.012
# 1                 1.449                0.399                     0.098
# 2                 1.760                0.419                     0.070
# 3                 1.509                0.432                     0.055
# 4                 1.400                 0.24                     0.066
#
#   PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                    0.825                       0.11
# 1                    0.763                      0.088
# 2                     0.97                      0.095
# 3                     0.83                      0.119
# 4                    0.941                      0.077
#
#   PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                    0.4201                    0.9666
# 1                    0.5013                      1.05
# 2                    0.5614                     1.161
# 3                    0.5991                   1.22242
# 4                    0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                         0.133    5  2004
# 1                         0.115    5  2004
# 2                         0.098    5  2004
# 3                         0.143    5  2004
# 4                         0.082    5  2004

# %% [markdown]
# #### Qual é o menor preço mínimo de revenda?

# %%
data_final['PREÇO MÍNIMO REVENDA'].min()
# Out:
# np.float64(0.59)

# %% [markdown]
# #### Qual é a média e desvio padrão dos preços mínimos de revenda?

# %%
media = data_final['PREÇO MÍNIMO REVENDA'].mean()
desvio = data_final['PREÇO MÍNIMO REVENDA'].std()  # desvio padrão
print(f'A média foi {media:.2f} com desvio de {desvio:.2f}')
# Out:
# A média foi 9.42 com desvio de 15.09

# %% [markdown]
# #### Quais são os estados considerados?

# %%
data_final['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data_final.ESTADO.unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
sorted(data_final.ESTADO.unique())  # ordenado por alfabetica, devolve uma lista
# Out:
# ['ACRE',
#  'ALAGOAS',
#  'AMAPA',
#  'AMAZONAS',
#  'BAHIA',
#  'CEARA',
#  'DISTRITO FEDERAL',
#  'ESPIRITO SANTO',
#  'GOIAS',
#  'MARANHAO',
#  'MATO GROSSO',
#  'MATO GROSSO DO SUL',
#  'MINAS GERAIS',
#  'PARA',
#  'PARAIBA',
#  'PARANA',
#  'PERNAMBUCO',
#  'PIAUI',
#  'RIO DE JANEIRO',
#  'RIO GRANDE DO NORTE',
#  'RIO GRANDE DO SUL',
#  'RONDONIA',
#  'RORAIMA',
#  'SANTA CATARINA',
#  'SAO PAULO',
#  'SERGIPE',
#  'TOCANTINS']

# %% [markdown]
# #### Quantos registros (aferições) cada estado possui?

# %% [markdown]
# `.value_counts()`:  Conta a frequência dos valores de uma dada variável (de preferência, _categórica_).

# %%
data_final.ESTADO.value_counts()  # numero de registro por estado
# Out:
# ESTADO
# PARAIBA                4263
# BAHIA                  4263
# CEARA                  4263
# RIO GRANDE DO SUL      4263
# RIO DE JANEIRO         4263
# SAO PAULO              4263
# PERNAMBUCO             4262
# RIO GRANDE DO NORTE    4262
# SANTA CATARINA         4262
# MINAS GERAIS           4261
# ESPIRITO SANTO         4260
# SERGIPE                4259
# PARANA                 4251
# ALAGOAS                4250
# MATO GROSSO DO SUL     4246
# MATO GROSSO            4037
# AMAZONAS               3889
# GOIAS                  3663
# PIAUI                  3548
# MARANHAO               3499
# PARA                   3497
# DISTRITO FEDERAL       3483
# TOCANTINS              3483
# ACRE                   3480
# RONDONIA               3479
# RORAIMA                3471
# AMAPA                  3403
# Name: count, dtype: int64

# %%
count_uf = data_final.ESTADO.value_counts()
count_uf
# Out:
# ESTADO
# PARAIBA                4263
# BAHIA                  4263
# CEARA                  4263
# RIO GRANDE DO SUL      4263
# RIO DE JANEIRO         4263
# SAO PAULO              4263
# PERNAMBUCO             4262
# RIO GRANDE DO NORTE    4262
# SANTA CATARINA         4262
# MINAS GERAIS           4261
# ESPIRITO SANTO         4260
# SERGIPE                4259
# PARANA                 4251
# ALAGOAS                4250
# MATO GROSSO DO SUL     4246
# MATO GROSSO            4037
# AMAZONAS               3889
# GOIAS                  3663
# PIAUI                  3548
# MARANHAO               3499
# PARA                   3497
# DISTRITO FEDERAL       3483
# TOCANTINS              3483
# ACRE                   3480
# RONDONIA               3479
# RORAIMA                3471
# AMAPA                  3403
# Name: count, dtype: int64

# %%
# converte em dataframe
count_uf.to_frame()
# Out:
#                      count
# ESTADO
# PARAIBA               4263
# BAHIA                 4263
# CEARA                 4263
# RIO GRANDE DO SUL     4263
# RIO DE JANEIRO        4263
# SAO PAULO             4263
# PERNAMBUCO            4262
# RIO GRANDE DO NORTE   4262
# SANTA CATARINA        4262
# MINAS GERAIS          4261
# ESPIRITO SANTO        4260
# SERGIPE               4259
# PARANA                4251
# ALAGOAS               4250
# MATO GROSSO DO SUL    4246
# MATO GROSSO           4037
# AMAZONAS              3889
# GOIAS                 3663
# PIAUI                 3548
# MARANHAO              3499
# PARA                  3497
# DISTRITO FEDERAL      3483
# TOCANTINS             3483
# ACRE                  3480
# RONDONIA              3479
# RORAIMA               3471
# AMAPA                 3403

# %% [markdown]
# <h2>4. Executando funções para cada item de um DataFrame ou Series</h2>
# <hr/>

# %% [markdown]
# Uma alternativa ao `for-loop` que vimos anteriormente e que é _lento_, é usarmos _funções próprias do pandas_ que **aplicam/mapeiam uma dada função a todos os elementos de um DataFrame ou Series**, retornando novos elementos "transformados".

# %% [markdown]
# <img src='./image/apply_map_applymap.png' width=300/>
#
#
# Fonte: https://towardsdatascience.com/introduction-to-pandas-apply-applymap-and-map-5d3e044e93ff

# %%
df = pd.DataFrame(
    {'A': [1, 2, 3, 4], 'B': [10, 20, 30, 40], 'C': [100, 200, 300, 400]},
    index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'],
)

# %%
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %% [markdown]
# `apply()`: usado para aplicar uma função ao longo de um eixo de um DataFrame ou em valores de uma Series.

# %% [markdown]
# <img src='./image/pandas_axis.jpg' width=500/>
#
# Fonte: https://www.allthesnippets.com/browse/pandas/df_axis.html

# %%
def minha_soma(series):
    return series.sum()  # retorna a soma de todas as linha

# %% [markdown]
# <img src='./image/apply_axis_1.png' width=250/>

# %%
# cria uma nova coluna somando todas as linhas
# 0 index, 1 columns, pode passar o numero também
df['D'] = df.apply(minha_soma, axis='columns')
df
# Out:
#          A   B    C    D
# Linha 1  1  10  100  111
# Linha 2  2  20  200  222
# Linha 3  3  30  300  333
# Linha 4  4  40  400  444

# %% [markdown]
# <img src='./image/apply_axis_0.png' width=250/>

# %%
# vou passar numero pois tbm pode, no caso 0 é para index/linhas
# usa se o loc pra verificar se existe, senao ele cria uma nova
df.loc['Linha 5'] = df.apply(minha_soma, axis=0)
df
# Out:
#           A    B     C     D
# Linha 1   1   10   100   111
# Linha 2   2   20   200   222
# Linha 3   3   30   300   333
# Linha 4   4   40   400   444
# Linha 5  10  100  1000  1110

# %% [markdown]
# ##### Usando `lambda` functions

# %%
# media das colunas na linhna
df['E'] = df[['A', 'B', 'C']].apply(lambda series: series.mean(), axis=1)
df
# Out:
#           A    B     C     D      E
# Linha 1   1   10   100   111   37.0
# Linha 2   2   20   200   222   74.0
# Linha 3   3   30   300   333  111.0
# Linha 4   4   40   400   444  148.0
# Linha 5  10  100  1000  1110  370.0

# %%
df['C'].apply(lambda x: x * 2) # cópia
# Out:
# Linha 1     200
# Linha 2     400
# Linha 3     600
# Linha 4     800
# Linha 5    2000
# Name: C, dtype: int64

# %%
df # dataframe não altera
# Out:
#           A    B     C     D      E
# Linha 1   1   10   100   111   37.0
# Linha 2   2   20   200   222   74.0
# Linha 3   3   30   300   333  111.0
# Linha 4   4   40   400   444  148.0
# Linha 5  10  100  1000  1110  370.0

# %% [markdown]
# <img src='./image/apply_axis_1_mean.png' width=350/>

# %%
# msm coisa se fizer assim
df['F'] = df['C'] * 2 # não precisaria de lambda nesse caso
df
# Out:
#           A    B     C     D      E     F
# Linha 1   1   10   100   111   37.0   200
# Linha 2   2   20   200   222   74.0   400
# Linha 3   3   30   300   333  111.0   600
# Linha 4   4   40   400   444  148.0   800
# Linha 5  10  100  1000  1110  370.0  2000

# %% [markdown]
# <br/>
#
# `applymap()`: usado para aplicar uma função para **cada elemento** (_element-wise_) de um DataFrame.

# %%
df = pd.DataFrame(
    {'A': [1, 2, 3, 4], 'B': [10, 20, 30, 40], 'C': [100, 200, 300, 400]},
    index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'],
)
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %%
# mapea cada celula
df.applymap(lambda x: x ** 2)
# has been deprecated. Use DataFrame.map
# Out:
# C:\Users\Alvaro Fonteles\AppData\Local\Temp\ipykernel_10380\1473115649.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(lambda x: x ** 2)
#           A     B       C
# Linha 1   1   100   10000
# Linha 2   4   400   40000
# Linha 3   9   900   90000
# Linha 4  16  1600  160000

# %%
# mapea cada celula, usando map(), já que acima está em desuso applymap()
df.map(lambda x: x ** 2)
# Out:
#           A     B       C
# Linha 1   1   100   10000
# Linha 2   4   400   40000
# Linha 3   9   900   90000
# Linha 4  16  1600  160000

# %% [markdown]
# <br/>
#
# `map()`: usado para aplicar uma função para **cada elemento** (_element-wise_) de uma _Series_.

# %%
nomes = pd.Series(['Alvaro', 'Fonteles'], index=['Nome', 'Sobrenome'])
df = pd.DataFrame(nomes, columns=['Dados'])
df
# Out:
#               Dados
# Nome         Alvaro
# Sobrenome  Fonteles

# %%
nomes.map(lambda x: x.upper()) # uma cópia
# Out:
# Nome           ALVARO
# Sobrenome    FONTELES
# dtype: object

# %%
nomes
# Out:
# Nome           Alvaro
# Sobrenome    Fonteles
# dtype: object

# %%
# mas pode se usar dessa forma sem o lambda e map
nomes.str.upper() # usa metodo str e o upper
# Out:
# Nome           ALVARO
# Sobrenome    FONTELES
# dtype: object

# %% [markdown]
# <h2>5. Agrupamento</h2>
# <hr/>

# %%
data_final.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# 1                1.162                  0.114                  0.89
# 2                1.389                  0.097                  1.18
# 3                1.262                  0.070                  1.09
# 4                1.181                  0.078                  1.05
#
#    PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                 1.350                0.463                     0.012
# 1                 1.449                0.399                     0.098
# 2                 1.760                0.419                     0.070
# 3                 1.509                0.432                     0.055
# 4                 1.400                 0.24                     0.066
#
#   PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                    0.825                       0.11
# 1                    0.763                      0.088
# 2                     0.97                      0.095
# 3                     0.83                      0.119
# 4                    0.941                      0.077
#
#   PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                    0.4201                    0.9666
# 1                    0.5013                      1.05
# 2                    0.5614                     1.161
# 3                    0.5991                   1.22242
# 4                    0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                         0.133    5  2004
# 1                         0.115    5  2004
# 2                         0.098    5  2004
# 3                         0.143    5  2004
# 4                         0.082    5  2004

# %% [markdown]
# `groupby`: Usado para criar **grupo de elementos** (e.x., baseado nos valores de um atributo). <br/>
# **Funções** podem então ser aplicadas para os _elementos de cada grupo_, de modo que os **resultados de cada grupo são combinados**.

# %%
# NÃO é um dataframe mas retorna um DataFrameGroupBy
grupos = data_final.groupby('REGIÃO') 
grupos

# %%
grupos.groups
# Out:
# {'CENTRO OESTE': [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], 'NORDESTE': [4, 5, 6, 7, 8, 9, 10, 11, 12, 31, 32, 33, 34, 35, 36, 37, 38, 39, 58, 59, 60, 61, 62, 63, 64, 65, 66, 85, 86, 87, 88, 89, 90, 91, 92, 93, 112, 113, 114, 115, 116, 117, 118, 119, 120, 139, 140, 141, 142, 143, 144, 145, 146, 147, 166, 167, 168, 169, 170, 171, 172, 173, 174, 193, 194, 195, 196, 197, 198, 199, 200, 201, 220, 221, 222, 223, 224, 225, 226, 227, 228, 247, 248, 249, 250, 251, 252, 253, 254, 255, 274, 275, 276, 277, 278, 279, 280, 281, 282, 301, ...], 'NORTE': [13, 14, 15, 16, 17, 18, 19, 40, 41, 42, 43, 44, 45, 46, 67, 68, 69, 70, 71, 72, 73, 94, 95, 96, 97, 98, 99, 100, 121, 122, 123, 124, 125, 126, 127, 148, 149, 150, 151, 152, 153, 154, 175, 176, 177, 178, 179, 180, 181, 202, 203, 204, 205, 206, 207, 208, 229, 230, 231, 232, 233, 234, 235, 256, 257, 258, 259, 260, 261, 262, 283, 284, 285, 286, 287, 288, 289, 310, 311, 312, 313, 314, 315, 316, 337, 338, 339, 340, 341, 342, 343, 364, 365, 366, 367, 368, 369, 370, 391, 392, ...], 'SUDESTE': [20, 21, 22, 23, 47, 48, 49, 50, 74, 75, 76, 77, 101, 102, 103, 104, 128, 129, 130, 131, 155, 156, 157, 158, 182, 183, 184, 185, 209, 210, 211, 212, 236, 237, 238, 239, 263, 264, 265, 266, 290, 291, 292, 293, 317, 318, 319, 320, 344, 345, 346, 347, 371, 372, 373, 374, 398, 399, 400, 401, 425, 426, 427, 428, 452, 453, 454, 455, 479, 480, 481, 482, 506, 507, 508, 509, 533, 534, 535, 536, 560, 561, 562, 563, 587, 588, 589, 590, 614, 615, 616, 617, 641, 642, 643, 644, 668, 669, 670, 671, ...], 'SUL': [24, 25, 26, 51, 52, 53, 78, 79, 80, 105, 106, 107, 132, 133, 134, 159, 160, 161, 186, 187, 188, 213, 214, 215, 240, 241, 242, 267, 268, 269, 294, 295, 296, 321, 322, 323, 348, 349, 350, 375, 376, 377, 402, 403, 404, 429, 430, 431, 456, 457, 458, 483, 484, 485, 510, 511, 512, 537, 538, 539, 564, 565, 566, 591, 592, 593, 618, 619, 620, 645, 646, 647, 672, 673, 674, 699, 700, 701, 726, 727, 728, 753, 754, 755, 780, 781, 782, 807, 808, 809, 834, 835, 836, 861, 862, 863, 888, 889, 890, 915, ...]}

# %%
grupos.indices
# Out:
# {'CENTRO OESTE': array([     0,      1,      2, ..., 106791, 106792, 106812],
#        shape=(15429,)),
#  'NORDESTE': array([     4,      5,      6, ..., 106816, 106818, 106822],
#        shape=(36869,)),
#  'NORTE': array([    13,     14,     15, ..., 106802, 106803, 106807],
#        shape=(24702,)),
#  'SUDESTE': array([    20,     21,     22, ..., 106813, 106817, 106821],
#        shape=(17047,)),
#  'SUL': array([    24,     25,     26, ..., 106815, 106819, 106820],
#        shape=(12776,))}

# %%
grupos.get_group('CENTRO OESTE') # retorna um DataFrame
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 27       2004-05-16  2004-05-22  CENTRO OESTE    DISTRITO FEDERAL
# ...             ...         ...           ...                 ...
# 106787   2019-06-23  2019-06-29  CENTRO OESTE    DISTRITO FEDERAL
# 106789   2019-06-23  2019-06-29  CENTRO OESTE               GOIAS
# 106791   2019-06-23  2019-06-29  CENTRO OESTE         MATO GROSSO
# 106792   2019-06-23  2019-06-29  CENTRO OESTE  MATO GROSSO DO SUL
# 106812   2019-06-23  2019-06-29  CENTRO OESTE  MATO GROSSO DO SUL
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 27      ETANOL HIDRATADO                           144              R$/l
# ...                  ...                           ...               ...
# 106787               GLP                            42           R$/13Kg
# 106789               GLP                           209           R$/13Kg
# 106791               GLP                            95           R$/13Kg
# 106792               GLP                           115           R$/13Kg
# 106812               GNV                             2             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                     1.288                  0.016                 1.190
# 1                     1.162                  0.114                 0.890
# 2                     1.389                  0.097                 1.180
# 3                     1.262                  0.070                 1.090
# 27                    1.271                  0.039                 1.060
# ...                     ...                    ...                   ...
# 106787               73.452                  4.875                65.000
# 106789               71.968                  5.381                53.000
# 106791               96.691                  6.835                73.000
# 106792               72.297                  8.054                59.990
# 106812                2.934                  0.049                 2.899
#
#         PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                0.463                     0.012
# 1                      1.449                0.399                     0.098
# 2                      1.760                0.419                     0.070
# 3                      1.509                0.432                     0.055
# 27                     1.300                0.448                     0.031
# ...                      ...                  ...                       ...
# 106787                95.000               21.509                     0.066
# 106789                85.000               15.044                     0.075
# 106791               115.000               19.789                     0.071
# 106792                99.000               16.707                     0.111
# 106812                 2.968                0.901                     0.017
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.11
# 1                         0.763                      0.088
# 2                          0.97                      0.095
# 3                          0.83                      0.119
# 27                        0.823                      0.111
# ...                         ...                        ...
# 106787                   51.943                      7.877
# 106789                   56.924                      4.285
# 106791                   76.902                      8.846
# 106792                    55.59                      5.109
# 106812                    2.033                      0.259
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 27                        0.4094                    1.1931
# ...                          ...                       ...
# 106787                        44                     62.82
# 106789                     45.57                      61.6
# 106791                     61.15                        90
# 106792                        47                        72
# 106812                      1.85                    2.2161
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                              0.133    5  2004
# 1                              0.115    5  2004
# 2                              0.098    5  2004
# 3                              0.143    5  2004
# 27                             0.135    5  2004
# ...                              ...  ...   ...
# 106787                         0.152    6  2019
# 106789                         0.075    6  2019
# 106791                         0.115    6  2019
# 106792                         0.092    6  2019
# 106812                         0.127    6  2019
#
# [15429 rows x 20 columns]

# %%
grupos.describe()
# Out:
#              NÚMERO DE POSTOS PESQUISADOS                                      \
#                                     count        mean         std  min    25%
# REGIÃO
# CENTRO OESTE                      15429.0  137.263983  107.396548  1.0   76.0
# NORDESTE                          36869.0  123.194364  112.856327  1.0   40.0
# NORTE                             24702.0   66.249899   53.119277  1.0   29.0
# SUDESTE                           17047.0  713.297002  786.310843  1.0  158.0
# SUL                               12776.0  353.486146  238.387934  1.0  153.0
#
#                                    PREÇO MÉDIO REVENDA             ...   MÊS  \
#                 50%    75%     max               count       mean  ...   75%
# REGIÃO                                                             ...
# CENTRO OESTE  119.0  178.0   766.0             15429.0  11.843486  ...  9.00
# NORDESTE       93.0  167.0   625.0             36869.0  10.097994  ...  9.00
# NORTE          52.0   94.0   383.0             24702.0  12.670958  ...  9.00
# SUDESTE       403.0  993.0  4167.0             17047.0   9.700178  ...  9.00
# SUL           362.0  560.0  1416.0             12776.0  10.007542  ...  9.25
#
#                         ANO                                                 \
#                max    count         mean       std     min     25%     50%
# REGIÃO
# CENTRO OESTE  12.0  15429.0  2011.862532  4.352302  2004.0  2008.0  2012.0
# NORDESTE      12.0  36869.0  2011.777699  4.404509  2004.0  2008.0  2012.0
# NORTE         12.0  24702.0  2011.832524  4.386504  2004.0  2008.0  2012.0
# SUDESTE       12.0  17047.0  2011.775796  4.399684  2004.0  2008.0  2012.0
# SUL           12.0  12776.0  2011.777239  4.399609  2004.0  2008.0  2012.0
#
#
#                  75%     max
# REGIÃO
# CENTRO OESTE  2016.0  2019.0
# NORDESTE      2016.0  2019.0
# NORTE         2016.0  2019.0
# SUDESTE       2016.0  2019.0
# SUL           2016.0  2019.0
#
# [5 rows x 64 columns]

# %%
grupos.min()
# Out:
#              DATA INICIAL  DATA FINAL            ESTADO           PRODUTO  \
# REGIÃO
# CENTRO OESTE   2004-05-09  2004-05-15  DISTRITO FEDERAL  ETANOL HIDRATADO
# NORDESTE       2004-05-09  2004-05-15           ALAGOAS  ETANOL HIDRATADO
# NORTE          2004-05-09  2004-05-15              ACRE  ETANOL HIDRATADO
# SUDESTE        2004-05-09  2004-05-15    ESPIRITO SANTO  ETANOL HIDRATADO
# SUL            2004-05-09  2004-05-15            PARANA  ETANOL HIDRATADO
#
#               NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# REGIÃO
# CENTRO OESTE                             1           R$/13Kg
# NORDESTE                                 1           R$/13Kg
# NORTE                                    1           R$/13Kg
# SUDESTE                                  1           R$/13Kg
# SUL                                      1           R$/13Kg
#
#               PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# REGIÃO
# CENTRO OESTE                1.097                    0.0
# NORDESTE                    0.975                    0.0
# NORTE                       1.219                    0.0
# SUDESTE                     0.766                    0.0
# SUL                         0.922                    0.0
#
#               PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  \
# REGIÃO
# CENTRO OESTE                  0.87                 1.099                    -
# NORDESTE                      0.79                 0.999                    -
# NORTE                         1.05                 1.219                    -
# SUDESTE                       0.59                 1.099                    -
# SUL                           0.73                 1.199                    -
#
#               COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                       0.0                        -
# NORDESTE                           0.0                        -
# NORTE                              0.0                        -
# SUDESTE                            0.0                        -
# SUL                                0.0                        -
#
#              DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                          -                         -
# NORDESTE                              -                         -
# NORTE                                 -                         -
# SUDESTE                               -                         -
# SUL                                   -                         -
#
#              PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS  \
# REGIÃO
# CENTRO OESTE                         -                             -    1
# NORDESTE                             -                             -    1
# NORTE                                -                             -    1
# SUDESTE                              -                             -    1
# SUL                                  -                             -    1
#
#                ANO
# REGIÃO
# CENTRO OESTE  2004
# NORDESTE      2004
# NORTE         2004
# SUDESTE       2004
# SUL           2004

# %%
grupos.mean(numeric_only=True)
# Out:
#                                NÚMERO DE POSTOS PESQUISADOS  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO                    154.982484
#              GASOLINA COMUM                      155.204777
#              GLP                                 200.619063
#              GNV                                   2.880499
#              ÓLEO DIESEL                         131.744268
#              ÓLEO DIESEL S10                      71.498888
# NORDESTE     ETANOL HIDRATADO                    153.857022
#              GASOLINA COMUM                      174.003255
#              GLP                                 126.175754
#              GNV                                  16.719462
#              ÓLEO DIESEL                         135.465110
#              ÓLEO DIESEL S10                      93.673906
# NORTE        ETANOL HIDRATADO                     46.100296
#              GASOLINA COMUM                       77.515471
#              GLP                                  89.856025
#              GNV                                   1.275711
#              ÓLEO DIESEL                          67.879505
#              ÓLEO DIESEL S10                      39.986011
# SUDESTE      ETANOL HIDRATADO                   1037.788217
#              GASOLINA COMUM                     1051.909236
#              GLP                                 756.676330
#              GNV                                  74.804528
#              ÓLEO DIESEL                         771.300955
#              ÓLEO DIESEL S10                     418.820266
# SUL          ETANOL HIDRATADO                    454.700510
#              GASOLINA COMUM                      495.765180
#              GLP                                 485.472611
#              GNV                                  19.042680
#              ÓLEO DIESEL                         364.018684
#              ÓLEO DIESEL S10                     229.859961
#
#                                PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO             2.135950               0.111622
#              GASOLINA COMUM               3.078123               0.103984
#              GLP                         48.181149               2.904754
#              GNV                          2.004153               0.025300
#              ÓLEO DIESEL                  2.481534               0.081501
#              ÓLEO DIESEL S10              3.241185               0.100953
# NORDESTE     ETANOL HIDRATADO             2.322075               0.115420
#              GASOLINA COMUM               3.002337               0.108090
#              GLP                         42.221312               2.687344
#              GNV                          1.925318               0.060461
#              ÓLEO DIESEL                  2.347550               0.069304
#              ÓLEO DIESEL S10              3.041957               0.091740
# NORTE        ETANOL HIDRATADO             2.530796               0.120423
#              GASOLINA COMUM               3.149212               0.140008
#              GLP                         47.174539               2.825744
#              GNV                          2.000190               0.009245
#              ÓLEO DIESEL                  2.569905               0.105580
#              ÓLEO DIESEL S10              3.310619               0.127323
# SUDESTE      ETANOL HIDRATADO             2.164832               0.134500
#              GASOLINA COMUM               3.000565               0.122024
#              GLP                         42.077813               3.116207
#              GNV                          1.779684               0.130339
#              ÓLEO DIESEL                  2.339699               0.082670
#              ÓLEO DIESEL S10              3.054425               0.109619
# SUL          ETANOL HIDRATADO             2.268864               0.123692
#              GASOLINA COMUM               2.973136               0.117797
#              GLP                         43.535465               3.417876
#              GNV                          1.907944               0.073314
#              ÓLEO DIESEL                  2.332862               0.081929
#              ÓLEO DIESEL S10              2.981745               0.110322
#
#                                PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO              1.927421              2.432146
#              GASOLINA COMUM                2.867660              3.338924
#              GLP                          40.957995             55.215088
#              GNV                           1.980121              2.025790
#              ÓLEO DIESEL                   2.310914              2.686322
#              ÓLEO DIESEL S10               3.034001              3.486368
# NORDESTE     ETANOL HIDRATADO              2.101505              2.655658
#              GASOLINA COMUM                2.780906              3.277833
#              GLP                          36.329123             47.837415
#              GNV                           1.865387              2.077530
#              ÓLEO DIESEL                   2.204314              2.535367
#              ÓLEO DIESEL S10               2.851449              3.303555
# NORTE        ETANOL HIDRATADO              2.355618              2.857434
#              GASOLINA COMUM                2.956985              3.538673
#              GLP                          42.299359             54.264647
#              GNV                           1.995431              2.009260
#              ÓLEO DIESEL                   2.399594              2.829854
#              ÓLEO DIESEL S10               3.124608              3.637403
# SUDESTE      ETANOL HIDRATADO              1.811892              2.631190
#              GASOLINA COMUM                2.698406              3.463277
#              GLP                          33.298655             51.311326
#              GNV                           1.620741              2.173035
#              ÓLEO DIESEL                   2.118881              2.659866
#              ÓLEO DIESEL S10               2.764236              3.455381
# SUL          ETANOL HIDRATADO              1.947870              2.673207
#              GASOLINA COMUM                2.678423              3.340955
#              GLP                          34.981443             53.414662
#              GNV                           1.823597              2.097937
#              ÓLEO DIESEL                   2.125472              2.611837
#              ÓLEO DIESEL S10               2.707422              3.366178
#
#                                COEF DE VARIAÇÃO REVENDA       MÊS          ANO
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO                  0.055482  6.500637  2011.433121
#              GASOLINA COMUM                    0.033592  6.500637  2011.433121
#              GLP                               0.057588  6.500478  2011.430985
#              GNV                               0.012368  6.456336  2011.953381
#              ÓLEO DIESEL                       0.032104  6.500637  2011.433121
#              ÓLEO DIESEL S10                   0.030342  6.318013  2015.762046
# NORDESTE     ETANOL HIDRATADO                  0.052014  6.500849  2011.432191
#              GASOLINA COMUM                    0.036350  6.500637  2011.433121
#              GLP                               0.060799  6.500354  2011.433083
#              GNV                               0.031211  6.496502  2011.355516
#              ÓLEO DIESEL                       0.029399  6.500637  2011.433121
#              ÓLEO DIESEL S10                   0.030019  6.316881  2015.758144
# NORTE        ETANOL HIDRATADO                  0.049130  6.499445  2011.346040
#              GASOLINA COMUM                    0.045072  6.500000  2011.434292
#              GLP                               0.059644  6.500000  2011.434292
#              GNV                               0.004575  6.516411  2011.652079
#              ÓLEO DIESEL                       0.041250  6.500000  2011.434292
#              ÓLEO DIESEL S10                   0.038558  6.319627  2015.764307
# SUDESTE      ETANOL HIDRATADO                  0.064103  6.500637  2011.433121
#              GASOLINA COMUM                    0.041105  6.500637  2011.433121
#              GLP                               0.070811  6.500159  2011.433896
#              GNV                               0.073378  6.497130  2011.432079
#              ÓLEO DIESEL                       0.034798  6.500637  2011.433121
#              ÓLEO DIESEL S10                   0.035362  6.322485  2015.754438
# SUL          ETANOL HIDRATADO                  0.055959  6.501274  2011.430331
#              GASOLINA COMUM                    0.039307  6.500637  2011.433121
#              GLP                               0.075282  6.500637  2011.433121
#              GNV                               0.036284  6.495945  2011.442168
#              ÓLEO DIESEL                       0.034150  6.500637  2011.433121
#              ÓLEO DIESEL S10                   0.036429  6.322485  2015.754438

# %%
data_final.groupby('REGIÃO').min()
# Out:
#              DATA INICIAL  DATA FINAL            ESTADO           PRODUTO  \
# REGIÃO
# CENTRO OESTE   2004-05-09  2004-05-15  DISTRITO FEDERAL  ETANOL HIDRATADO
# NORDESTE       2004-05-09  2004-05-15           ALAGOAS  ETANOL HIDRATADO
# NORTE          2004-05-09  2004-05-15              ACRE  ETANOL HIDRATADO
# SUDESTE        2004-05-09  2004-05-15    ESPIRITO SANTO  ETANOL HIDRATADO
# SUL            2004-05-09  2004-05-15            PARANA  ETANOL HIDRATADO
#
#               NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# REGIÃO
# CENTRO OESTE                             1           R$/13Kg
# NORDESTE                                 1           R$/13Kg
# NORTE                                    1           R$/13Kg
# SUDESTE                                  1           R$/13Kg
# SUL                                      1           R$/13Kg
#
#               PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# REGIÃO
# CENTRO OESTE                1.097                    0.0
# NORDESTE                    0.975                    0.0
# NORTE                       1.219                    0.0
# SUDESTE                     0.766                    0.0
# SUL                         0.922                    0.0
#
#               PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  \
# REGIÃO
# CENTRO OESTE                  0.87                 1.099                    -
# NORDESTE                      0.79                 0.999                    -
# NORTE                         1.05                 1.219                    -
# SUDESTE                       0.59                 1.099                    -
# SUL                           0.73                 1.199                    -
#
#               COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                       0.0                        -
# NORDESTE                           0.0                        -
# NORTE                              0.0                        -
# SUDESTE                            0.0                        -
# SUL                                0.0                        -
#
#              DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                          -                         -
# NORDESTE                              -                         -
# NORTE                                 -                         -
# SUDESTE                               -                         -
# SUL                                   -                         -
#
#              PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS  \
# REGIÃO
# CENTRO OESTE                         -                             -    1
# NORDESTE                             -                             -    1
# NORTE                                -                             -    1
# SUDESTE                              -                             -    1
# SUL                                  -                             -    1
#
#                ANO
# REGIÃO
# CENTRO OESTE  2004
# NORDESTE      2004
# NORTE         2004
# SUDESTE       2004
# SUL           2004

# %% [markdown]
# <br/>
#
# Também podemos ter agrupamentos por mais de um atributo.

# %%
data_final.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# 1                1.162                  0.114                  0.89
# 2                1.389                  0.097                  1.18
# 3                1.262                  0.070                  1.09
# 4                1.181                  0.078                  1.05
#
#    PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                 1.350                0.463                     0.012
# 1                 1.449                0.399                     0.098
# 2                 1.760                0.419                     0.070
# 3                 1.509                0.432                     0.055
# 4                 1.400                 0.24                     0.066
#
#   PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                    0.825                       0.11
# 1                    0.763                      0.088
# 2                     0.97                      0.095
# 3                     0.83                      0.119
# 4                    0.941                      0.077
#
#   PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                    0.4201                    0.9666
# 1                    0.5013                      1.05
# 2                    0.5614                     1.161
# 3                    0.5991                   1.22242
# 4                    0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                         0.133    5  2004
# 1                         0.115    5  2004
# 2                         0.098    5  2004
# 3                         0.143    5  2004
# 4                         0.082    5  2004

# %% [markdown]
# <br/>
#
# #### Quais são os preços médios dos Produtos (Combustíveis) para cada Região?

# %%
grupos = data_final.groupby(['REGIÃO', 'PRODUTO'])
grupos

# %%
grupos.groups
# Out:
# {('CENTRO OESTE', 'ETANOL HIDRATADO'): [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], ('CENTRO OESTE', 'GASOLINA COMUM'): [12064, 12065, 12066, 12067, 12091, 12092, 12093, 12094, 12118, 12119, 12120, 12121, 12145, 12146, 12147, 12148, 12172, 12173, 12174, 12175, 12199, 12200, 12201, 12202, 12226, 12227, 12228, 12229, 12253, 12254, 12255, 12256, 12280, 12281, 12282, 12283, 12307, 12308, 12309, 12310, 12334, 12335, 12336, 12337, 12361, 12362, 12363, 12364, 12388, 12389, 12390, 12391, 12415, 12416, 12417, 12418, 12442, 12443, 12444, 12445, 12469, 12470, 12471, 12472, 12496, 12497, 12498, 12499, 12523, 12524, 12525, 12526, 12550, 12551, 12552, 12553, 12577, 12578, 12579, 12580, 12604, 12605, 12606, 12607, 12631, 12632, 12633, 12634, 12658, 12659, 12660, 12661, 12685, 12686, 12687, 12688, 12712, 12713, 12714, 12715, ...], ('CENTRO OESTE', 'GLP'): [24132, 24133, 24134, 24135, 24159, 24160, 24161, 24162, 24186, 24187, 24188, 24189, 24213, 24214, 24215, 24216, 24240, 24241, 24242, 24243, 24267, 24268, 24269, 24270, 24294, 24295, 24296, 24297, 24321, 24322, 24323, 24324, 24348, 24349, 24350, 24351, 24375, 24376, 24377, 24378, 24402, 24403, 24404, 24405, 24429, 24430, 24431, 24432, 24456, 24457, 24458, 24459, 24483, 24484, 24485, 24486, 24510, 24511, 24512, 24513, 24537, 24538, 24539, 24540, 24564, 24565, 24566, 24567, 24591, 24592, 24593, 24594, 24618, 24619, 24620, 24621, 24645, 24646, 24647, 24648, 24672, 24673, 24674, 24675, 24699, 24700, 24701, 24702, 24726, 24727, 24728, 24729, 24753, 24754, 24755, 24756, 24780, 24781, 24782, 24783, ...], ('CENTRO OESTE', 'GNV'): [36196, 36211, 36226, 36241, 36256, 36271, 36286, 36301, 36316, 36331, 36346, 36361, 36377, 36393, 36409, 36425, 36441, 36457, 36473, 36489, 36505, 36521, 36537, 36553, 36569, 36585, 36601, 36617, 36633, 36649, 36665, 36681, 36697, 36713, 36729, 36745, 36761, 36777, 36793, 36809, 36825, 36841, 36857, 36873, 36889, 36905, 36921, 36937, 36953, 36969, 36985, 37001, 37017, 37033, 37049, 37065, 37081, 37097, 37113, 37129, 37145, 37161, 37177, 37193, 37209, 37225, 37242, 37257, 37258, 37274, 37290, 37307, 37322, 37338, 37353, 37368, 37383, 37399, 37415, 37430, 37446, 37462, 37478, 37494, 37510, 37526, 37542, 37558, 37574, 37590, 37606, 37621, 37637, 37653, 37669, 37686, 37702, 37718, 37734, 37750, ...], ('CENTRO OESTE', 'ÓLEO DIESEL'): [43547, 43548, 43549, 43550, 43574, 43575, 43576, 43577, 43601, 43602, 43603, 43604, 43628, 43629, 43630, 43631, 43655, 43656, 43657, 43658, 43682, 43683, 43684, 43685, 43709, 43710, 43711, 43712, 43736, 43737, 43738, 43739, 43763, 43764, 43765, 43766, 43790, 43791, 43792, 43793, 43817, 43818, 43819, 43820, 43844, 43845, 43846, 43847, 43871, 43872, 43873, 43874, 43898, 43899, 43900, 43901, 43925, 43926, 43927, 43928, 43952, 43953, 43954, 43955, 43979, 43980, 43981, 43982, 44006, 44007, 44008, 44009, 44033, 44034, 44035, 44036, 44060, 44061, 44062, 44063, 44087, 44088, 44089, 44090, 44114, 44115, 44116, 44117, 44141, 44142, 44143, 44144, 44168, 44169, 44170, 44171, 44195, 44196, 44197, 44198, ...], ('CENTRO OESTE', 'ÓLEO DIESEL S10'): [55672, 55674, 55819, 55821, 55822, 55967, 55969, 55971, 55972, 56119, 56121, 56123, 56124, 56272, 56274, 56276, 56277, 56425, 56427, 56429, 56430, 56577, 56579, 56581, 56582, 56729, 56731, 56733, 56734, 56882, 56884, 56886, 56887, 57035, 57037, 57039, 57040, 57187, 57189, 57191, 57192, 57339, 57341, 57343, 57344, 57490, 57492, 57494, 57495, 57642, 57644, 57646, 57647, 57795, 57797, 57799, 57800, 57947, 57949, 57951, 57952, 58099, 58101, 58103, 58104, 58251, 58253, 58255, 58256, 58402, ...

# %%
grupos.mean(numeric_only=True) # existem não numericos
# Out:
#                                NÚMERO DE POSTOS PESQUISADOS  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO                    154.982484
#              GASOLINA COMUM                      155.204777
#              GLP                                 200.619063
#              GNV                                   2.880499
#              ÓLEO DIESEL                         131.744268
#              ÓLEO DIESEL S10                      71.498888
# NORDESTE     ETANOL HIDRATADO                    153.857022
#              GASOLINA COMUM                      174.003255
#              GLP                                 126.175754
#              GNV                                  16.719462
#              ÓLEO DIESEL                         135.465110
#              ÓLEO DIESEL S10                      93.673906
# NORTE        ETANOL HIDRATADO                     46.100296
#              GASOLINA COMUM                       77.515471
#              GLP                                  89.856025
#              GNV                                   1.275711
#              ÓLEO DIESEL                          67.879505
#              ÓLEO DIESEL S10                      39.986011
# SUDESTE      ETANOL HIDRATADO                   1037.788217
#              GASOLINA COMUM                     1051.909236
#              GLP                                 756.676330
#              GNV                                  74.804528
#              ÓLEO DIESEL                         771.300955
#              ÓLEO DIESEL S10                     418.820266
# SUL          ETANOL HIDRATADO                    454.700510
#              GASOLINA COMUM                      495.765180
#              GLP                                 485.472611
#              GNV                                  19.042680
#              ÓLEO DIESEL                         364.018684
#              ÓLEO DIESEL S10                     229.859961
#
#                                PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO             2.135950               0.111622
#              GASOLINA COMUM               3.078123               0.103984
#              GLP                         48.181149               2.904754
#              GNV                          2.004153               0.025300
#              ÓLEO DIESEL                  2.481534               0.081501
#              ÓLEO DIESEL S10              3.241185               0.100953
# NORDESTE     ETANOL HIDRATADO             2.322075               0.115420
#              GASOLINA COMUM               3.002337               0.108090
#              GLP                         42.221312               2.687344
#              GNV                          1.925318               0.060461
#              ÓLEO DIESEL                  2.347550               0.069304
#              ÓLEO DIESEL S10              3.041957               0.091740
# NORTE        ETANOL HIDRATADO             2.530796               0.120423
#              GASOLINA COMUM               3.149212               0.140008
#              GLP                         47.174539               2.825744
#              GNV                          2.000190               0.009245
#              ÓLEO DIESEL                  2.569905               0.105580
#              ÓLEO DIESEL S10              3.310619               0.127323
# SUDESTE      ETANOL HIDRATADO             2.164832               0.134500
#              GASOLINA COMUM               3.000565               0.122024
#              GLP                         42.077813               3.116207
#              GNV                          1.779684               0.130339
#              ÓLEO DIESEL                  2.339699               0.082670
#              ÓLEO DIESEL S10              3.054425               0.109619
# SUL          ETANOL HIDRATADO             2.268864               0.123692
#              GASOLINA COMUM               2.973136               0.117797
#              GLP                         43.535465               3.417876
#              GNV                          1.907944               0.073314
#              ÓLEO DIESEL                  2.332862               0.081929
#              ÓLEO DIESEL S10              2.981745               0.110322
#
#                                PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO              1.927421              2.432146
#              GASOLINA COMUM                2.867660              3.338924
#              GLP                          40.957995             55.215088
#              GNV                           1.980121              2.025790
#              ÓLEO DIESEL                   2.310914              2.686322
#              ÓLEO DIESEL S10               3.034001              3.486368
# NORDESTE     ETANOL HIDRATADO              2.101505              2.655658
#              GASOLINA COMUM                2.780906              3.277833
#              GLP                          36.329123             47.837415
#              GNV                           1.865387              2.077530
#              ÓLEO DIESEL                   2.204314              2.535367
#              ÓLEO DIESEL S10               2.851449              3.303555
# NORTE        ETANOL HIDRATADO              2.355618              2.857434
#              GASOLINA COMUM                2.956985              3.538673
#              GLP                          42.299359             54.264647
#              GNV                           1.995431              2.009260
#              ÓLEO DIESEL                   2.399594              2.829854
#              ÓLEO DIESEL S10               3.124608              3.637403
# SUDESTE      ETANOL HIDRATADO              1.811892              2.631190
#              GASOLINA COMUM                2.698406              3.463277
#              GLP                          33.298655             51.311326
#              GNV                           1.620741              2.173035
#              ÓLEO DIESEL                   2.118881              2.659866
#              ÓLEO DIESEL S10               2.764236              3.455381
# SUL          ETANOL HIDRATADO              1.947870              2.673207
#              GASOLINA COMUM                2.678423              3.340955
#              GLP                          34.981443             53.414662
#              GNV                           1.823597              2.097937
#              ÓLEO DIESEL                   2.125472              2.611837
#              ÓLEO DIESEL S10               2.707422              3.366178
#
#                                COEF DE VARIAÇÃO REVENDA       MÊS          ANO
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO                  0.055482  6.500637  2011.433121
#              GASOLINA COMUM                    0.033592  6.500637  2011.433121
#              GLP                               0.057588  6.500478  2011.430985
#              GNV                               0.012368  6.456336  2011.953381
#              ÓLEO DIESEL                       0.032104  6.500637  2011.433121
#              ÓLEO DIESEL S10                   0.030342  6.318013  2015.762046
# NORDESTE     ETANOL HIDRATADO                  0.052014  6.500849  2011.432191
#              GASOLINA COMUM                    0.036350  6.500637  2011.433121
#              GLP                               0.060799  6.500354  2011.433083
#              GNV                               0.031211  6.496502  2011.355516
#              ÓLEO DIESEL                       0.029399  6.500637  2011.433121
#              ÓLEO DIESEL S10                   0.030019  6.316881  2015.758144
# NORTE        ETANOL HIDRATADO                  0.049130  6.499445  2011.346040
#              GASOLINA COMUM                    0.045072  6.500000  2011.434292
#              GLP                               0.059644  6.500000  2011.434292
#              GNV                               0.004575  6.516411  2011.652079
#              ÓLEO DIESEL                       0.041250  6.500000  2011.434292
#              ÓLEO DIESEL S10                   0.038558  6.319627  2015.764307
# SUDESTE      ETANOL HIDRATADO                  0.064103  6.500637  2011.433121
#              GASOLINA COMUM                    0.041105  6.500637  2011.433121
#              GLP                               0.070811  6.500159  2011.433896
#              GNV                               0.073378  6.497130  2011.432079
#              ÓLEO DIESEL                       0.034798  6.500637  2011.433121
#              ÓLEO DIESEL S10                   0.035362  6.322485  2015.754438
# SUL          ETANOL HIDRATADO                  0.055959  6.501274  2011.430331
#              GASOLINA COMUM                    0.039307  6.500637  2011.433121
#              GLP                               0.075282  6.500637  2011.433121
#              GNV                               0.036284  6.495945  2011.442168
#              ÓLEO DIESEL                       0.034150  6.500637  2011.433121
#              ÓLEO DIESEL S10                   0.036429  6.322485  2015.754438

# %%
grupos['PREÇO MÉDIO REVENDA'].mean()
# Out:
# REGIÃO        PRODUTO
# CENTRO OESTE  ETANOL HIDRATADO     2.135950
#               GASOLINA COMUM       3.078123
#               GLP                 48.181149
#               GNV                  2.004153
#               ÓLEO DIESEL          2.481534
#               ÓLEO DIESEL S10      3.241185
# NORDESTE      ETANOL HIDRATADO     2.322075
#               GASOLINA COMUM       3.002337
#               GLP                 42.221312
#               GNV                  1.925318
#               ÓLEO DIESEL          2.347550
#               ÓLEO DIESEL S10      3.041957
# NORTE         ETANOL HIDRATADO     2.530796
#               GASOLINA COMUM       3.149212
#               GLP                 47.174539
#               GNV                  2.000190
#               ÓLEO DIESEL          2.569905
#               ÓLEO DIESEL S10      3.310619
# SUDESTE       ETANOL HIDRATADO     2.164832
#               GASOLINA COMUM       3.000565
#               GLP                 42.077813
#               GNV                  1.779684
#               ÓLEO DIESEL          2.339699
#               ÓLEO DIESEL S10      3.054425
# SUL           ETANOL HIDRATADO     2.268864
#               GASOLINA COMUM       2.973136
#               GLP                 43.535465
#               GNV                  1.907944
#               ÓLEO DIESEL          2.332862
#               ÓLEO DIESEL S10      2.981745
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
grupos['PREÇO MÉDIO REVENDA'].describe()
# Out:
#                                 count       mean        std     min       25%  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO  3140.0   2.135950   0.561154   1.162   1.71600
#              GASOLINA COMUM    3140.0   3.078123   0.616315   1.936   2.66800
#              GLP               3137.0  48.181149  15.189152  28.791  37.34000
#              GNV               1523.0   2.004153   0.457802   1.097   1.59900
#              ÓLEO DIESEL       3140.0   2.481534   0.627607   1.435   2.03300
#              ÓLEO DIESEL S10   1349.0   3.241185   0.433797   2.212   2.82000
# NORDESTE     ETANOL HIDRATADO  7064.0   2.322075   0.605121   1.181   1.82500
#              GASOLINA COMUM    7065.0   3.002337   0.641163   1.949   2.58400
#              GLP               7061.0  42.221312  11.654978  28.367  33.59800
#              GNV               5575.0   1.925318   0.555183   0.975   1.60300
#              ÓLEO DIESEL       7065.0   2.347550   0.606381   1.313   1.90000
#              ÓLEO DIESEL S10   3039.0   3.041957   0.442555   2.130   2.60000
# NORTE        ETANOL HIDRATADO  5404.0   2.530796   0.655421   1.226   2.04600
#              GASOLINA COMUM    5494.0   3.149212   0.640964   1.995   2.70525
#              GLP               5494.0  47.174539  14.477296  28.086  36.50925
#              GNV                457.0   2.000190   0.602366   1.219   1.39900
#              ÓLEO DIESEL       5494.0   2.569905   0.650350   1.450   2.08800
#              ÓLEO DIESEL S10   2359.0   3.310619   0.533966   2.172   2.87800
# SUDESTE      ETANOL HIDRATADO  3140.0   2.164832   0.652355   0.766   1.69275
#              GASOLINA COMUM    3140.0   3.000565   0.698573   1.888   2.50200
#              GLP               3139.0  42.077813  11.522013  28.026  33.63850
#              GNV               3136.0   1.779684   0.507284   0.996   1.47300
#              ÓLEO DIESEL       3140.0   2.339699   0.588641   1.356   1.87600
#              ÓLEO DIESEL S10   1352.0   3.054425   0.419618   2.180   2.64700
# SUL          ETANOL HIDRATADO  2354.0   2.268864   0.703567   0.922   1.72100
#              GASOLINA COMUM    2355.0   2.973136   0.624032   1.961   2.54300
#              GLP               2355.0  43.535465  11.628193  29.440  34.82450
#              GNV               2343.0   1.907944   0.500694   1.168   1.51200
#              ÓLEO DIESEL       2355.0   2.332862   0.528454   1.374   1.95100
#              ÓLEO DIESEL S10   1014.0   2.981745   0.366952   2.140   2.66300
#
#                                    50%       75%     max
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO   2.0010   2.47900   3.999
#              GASOLINA COMUM     2.8560   3.46025   4.963
#              GLP               42.8570  55.90500  99.357
#              GNV                1.9550   2.35250   3.890
#              ÓLEO DIESEL        2.2455   3.01900   4.162
#              ÓLEO DIESEL S10    3.2640   3.58400   4.200
# NORDESTE     ETANOL HIDRATADO   2.1880   2.67550   3.927
#              GASOLINA COMUM     2.7420   3.42500   4.951
#              GLP               37.5750  48.18300  79.630
#              GNV                1.8210   2.16850   3.811
#              ÓLEO DIESEL        2.0820   2.87300   4.114
#              ÓLEO DIESEL S10    3.0870   3.33800   4.069
# NORTE        ETANOL HIDRATADO   2.3430   2.93525   4.459
#              GASOLINA COMUM     2.9320   3.57975   5.362
#              GLP               42.4535  54.63575  87.270
#              GNV                1.8500   2.30000   4.020
#              ÓLEO DIESEL        2.3340   3.08000   4.774
#              ÓLEO DIESEL S10    3.3070   3.65300   4.878
# SUDESTE      ETANOL HIDRATADO   2.0435   2.57200   4.115
#              GASOLINA COMUM     2.7930   3.45150   5.119
#              GLP               38.2660  49.25100  79.192
#              GNV                1.6940   2.00300   3.594
#              ÓLEO DIESEL        2.0825   2.82500   3.994
#              ÓLEO DIESEL S10    3.0900   3.38600   4.080
# SUL          ETANOL HIDRATADO   2.1140   2.60325   4.287
#              GASOLINA COMUM     2.7320   3.34350   4.953
#              GLP               40.0470  51.41250  72.088
#              GNV                1.8000   2.19250   3.499
#              ÓLEO DIESEL        2.0900   2.78550   3.800
#              ÓLEO DIESEL S10    2.9910   3.25400   3.815

# %% [markdown]
# <br/>
#
# `.agg`: **agrega (roda)** uma série de funções para os elementos de um dataframe ou de grupos de um dataframe.

# %%
df = pd.DataFrame(
    [[1, 2, 3], [4, 5, 6], [7, 8, 9], [None, None, None]], columns=['A', 'B', 'C']
)
df
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  6.0
# 2  7.0  8.0  9.0
# 3  NaN  NaN  NaN

# %%
# nova feature com '' aspas
df.agg(['sum', 'min']) # nesse caso ignora o NaN
# Out:
#         A     B     C
# sum  12.0  15.0  18.0
# min   1.0   2.0   3.0

# %%
grupos = data_final.groupby('REGIÃO')

# %%
grupos['PREÇO MÉDIO REVENDA'].agg(['min', 'max'])
# Out:
#                 min     max
# REGIÃO
# CENTRO OESTE  1.097  99.357
# NORDESTE      0.975  79.630
# NORTE         1.219  87.270
# SUDESTE       0.766  79.192
# SUL           0.922  72.088

# %% [markdown]
# <h2>6. Ordenação</h2>
# <hr/>

# %%
notas = pd.DataFrame(
    {
        'nome': ['João', 'Maria', 'José', 'Alice'],
        'idade': [20, 21, 19, 20],
        'nota_final': [5.0, 10.0, 6.0, 10.0],
    }
)
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %% [markdown]
# `.sort_values()`: ordena valores ao longo de um eixo.

# %%
notas.sort_values(by='nota_final')
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 2   José     19         6.0
# 1  Maria     21        10.0
# 3  Alice     20        10.0

# %% [markdown]
# Por padrão, o método retorna uma cópia dos dados ordenados em **ordem crescente (ascendente)**. Podemos alterar isso pelo argumento `ascending`.

# %%
notas.sort_values(by='nota_final', ascending=False).reset_index(drop=True)
# Out:
#     nome  idade  nota_final
# 0  Maria     21        10.0
# 1  Alice     20        10.0
# 2   José     19         6.0
# 3   João     20         5.0

# %% [markdown]
# <br/>
#
# Podemos ordenar a partir de **mais de uma coluna**:

# %%
notas.sort_values(by=['nota_final', 'nome'], ascending=[False, True])
# Out:
#     nome  idade  nota_final
# 3  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %% [markdown]
# Ordena os registros, primeiramente, pela coluna 'nota_final' em **ordem descrente**. <br/>
# Então, reordena os registros _"empatados"_, ou seja, com a **mesma nota final**, em _ordem alfabética_ (ordem crescente).

# %% [markdown]
# <br/>
#
# Note que o dataframe original **não foi alterado** após a ordenação.

# %%
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %% [markdown]
# Para alterá-lo, use o argumento `inplace=True`:

# %%
notas.sort_values(by=['nota_final', 'nome'], ascending=[False, True], inplace=True)

# %%
notas
# Out:
#     nome  idade  nota_final
# 3  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %% [markdown]
# <h2>7. Exercícios</h2>
# <hr/>

# %% [markdown]
# Vamos aplicar os conceitos que vimos em alguns exercícios. <br/>
# Para isso, utilizaremos o dataset de _preços de combustíveis no Brasil_.

# %%
data_final
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 106818               GNV                             7             R$/m3
# 106819               GNV                            23             R$/m3
# 106820               GNV                            24             R$/m3
# 106821               GNV                            52             R$/m3
# 106822               GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                     1.288                  0.016                 1.190
# 1                     1.162                  0.114                 0.890
# 2                     1.389                  0.097                 1.180
# 3                     1.262                  0.070                 1.090
# 4                     1.181                  0.078                 1.050
# ...                     ...                    ...                   ...
# 106818                3.574                  0.065                 3.499
# 106819                3.401                  0.129                 3.230
# 106820                2.912                  0.190                 2.699
# 106821                3.020                  0.229                 2.699
# 106822                3.697                  0.005                 3.689
#
#         PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                0.463                     0.012
# 1                      1.449                0.399                     0.098
# 2                      1.760                0.419                     0.070
# 3                      1.509                0.432                     0.055
# 4                      1.400                 0.24                     0.066
# ...                      ...                  ...                       ...
# 106818                 3.690                0.818                     0.018
# 106819                 3.789                 0.95                     0.038
# 106820                 3.499                0.914                     0.065
# 106821                 3.490                0.646                     0.076
# 106822                 3.699                1.179                     0.001
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.11
# 1                         0.763                      0.088
# 2                          0.97                      0.095
# 3                          0.83                      0.119
# 4                         0.941                      0.077
# ...                         ...                        ...
# 106818                    2.756                          0
# 106819                    2.451                      0.402
# 106820                    1.998                          0
# 106821                    2.374                      0.165
# 106822                    2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                              0.133    5  2004
# 1                              0.115    5  2004
# 2                              0.098    5  2004
# 3                              0.143    5  2004
# 4                              0.082    5  2004
# ...                              ...  ...   ...
# 106818                             0    6  2019
# 106819                         0.164    6  2019
# 106820                             0    6  2019
# 106821                          0.07    6  2019
# 106822                             0    6  2019
#
# [106823 rows x 20 columns]

# %% [markdown]
# Como há apenas medições de janeiro a junho para o ano de 2019, resolvemos **remover os dados** deste ano da análise.

# %%
data_final.query('ANO != 2019')
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 103064   2018-12-30  2019-01-05      NORDESTE  RIO GRANDE DO NORTE
# 103065   2018-12-30  2019-01-05           SUL    RIO GRANDE DO SUL
# 103066   2018-12-30  2019-01-05           SUL       SANTA CATARINA
# 103067   2018-12-30  2019-01-05       SUDESTE            SAO PAULO
# 103068   2018-12-30  2019-01-05      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 103064               GNV                            10             R$/m3
# 103065               GNV                            16             R$/m3
# 103066               GNV                            15             R$/m3
# 103067               GNV                            41             R$/m3
# 103068               GNV                             2             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                     1.288                  0.016                 1.190
# 1                     1.162                  0.114                 0.890
# 2                     1.389                  0.097                 1.180
# 3                     1.262                  0.070                 1.090
# 4                     1.181                  0.078                 1.050
# ...                     ...                    ...                   ...
# 103064                3.465                  0.060                 3.370
# 103065                3.402                  0.103                 3.199
# 103066                2.944                  0.124                 2.790
# 103067                2.353                  0.451                 1.999
# 103068                3.649                  0.000                 3.649
#
#         PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                0.463                     0.012
# 1                      1.449                0.399                     0.098
# 2                      1.760                0.419                     0.070
# 3                      1.509                0.432                     0.055
# 4                      1.400                 0.24                     0.066
# ...                      ...                  ...                       ...
# 103064                 3.590                0.759                     0.017
# 103065                 3.499                1.296                     0.030
# 103066                 3.199                 0.67                     0.042
# 103067                 3.429                0.467                     0.192
# 103068                 3.649                    -                     0.000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.11
# 1                         0.763                      0.088
# 2                          0.97                      0.095
# 3                          0.83                      0.119
# 4                         0.941                      0.077
# ...                         ...                        ...
# 103064                    2.706                          0
# 103065                    2.106                      0.249
# 103066                    2.274                      0.283
# 103067                    1.886                       0.25
# 103068                        -                          -
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 103064                    2.7059                    2.7059
# 103065                    1.8775                    2.3724
# 103066                    1.8738                     2.274
# 103067                      1.64                     2.332
# 103068                         -                         -
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                              0.133    5  2004
# 1                              0.115    5  2004
# 2                              0.098    5  2004
# 3                              0.143    5  2004
# 4                              0.082    5  2004
# ...                              ...  ...   ...
# 103064                             0   12  2018
# 103065                         0.118   12  2018
# 103066                         0.124   12  2018
# 103067                         0.133   12  2018
# 103068                             -   12  2018
#
# [103069 rows x 20 columns]

# %% [markdown]
# Note que temos um novo dataframe com 99739 linhas, mas com índices fora desse intervalo. <br/>
# Acontece que os registros mantiveram seus índices originais após a query. <br/>
#
# Para resetar os índices de _0 a num_linhas-1_, basta usarmos o método `.reset_index()`.

# %%
df = data_final.query('ANO != 2019')

# %% [markdown]
# ### 7.1 Qual a proporção de postos pesquisados para cada combustível em cada região

# %%
grupos = df.groupby('PRODUTO')
grupos

# %%
grupos['REGIÃO'].value_counts().to_frame()
# Out:
#                                count
# PRODUTO          REGIÃO
# ETANOL HIDRATADO NORDESTE       6839
#                  NORTE          5244
#                  CENTRO OESTE   3040
#                  SUDESTE        3040
#                  SUL            2279
# GASOLINA COMUM   NORDESTE       6840
#                  NORTE          5319
#                  CENTRO OESTE   3040
#                  SUDESTE        3040
#                  SUL            2280
# GLP              NORDESTE       6836
#                  NORTE          5319
#                  SUDESTE        3039
#                  CENTRO OESTE   3037
#                  SUL            2280
# GNV              NORDESTE       5398
#                  SUDESTE        3036
#                  SUL            2269
#                  CENTRO OESTE   1493
#                  NORTE           444
# ÓLEO DIESEL      NORDESTE       6840
#                  NORTE          5319
#                  CENTRO OESTE   3040
#                  SUDESTE        3040
#                  SUL            2280
# ÓLEO DIESEL S10  NORDESTE       2814
#                  NORTE          2184
#                  SUDESTE        1252
#                  CENTRO OESTE   1249
#                  SUL             939

# %% [markdown]
# ### 7.2 Como os preços da Gasolina Comum em Ceará variaram em 2018?

# %%
gasolina_sp_2018 = df.query('PRODUTO == "GASOLINA COMUM" and ESTADO == "SAO PAULO" and ANO == 2018')
gasolina_sp_2018.head()
# Out:
#       DATA INICIAL  DATA FINAL   REGIÃO     ESTADO         PRODUTO  \
# 95351   2018-01-07  2018-01-13  SUDESTE  SAO PAULO  GASOLINA COMUM
# 95502   2018-01-14  2018-01-20  SUDESTE  SAO PAULO  GASOLINA COMUM
# 95654   2018-01-21  2018-01-27  SUDESTE  SAO PAULO  GASOLINA COMUM
# 95806   2018-01-28  2018-02-03  SUDESTE  SAO PAULO  GASOLINA COMUM
# 95958   2018-02-04  2018-02-10  SUDESTE  SAO PAULO  GASOLINA COMUM
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 95351                          1641              R$/l                3.988
# 95502                          1648              R$/l                4.002
# 95654                          1648              R$/l                4.006
# 95806                          1644              R$/l                4.019
# 95958                          1646              R$/l                4.004
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 95351                  0.156                 3.499                 4.599
# 95502                  0.155                 3.549                 4.499
# 95654                  0.160                 3.499                 4.899
# 95806                  0.156                 3.579                 4.699
# 95958                  0.157                 3.579                 4.597
#
#       MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 95351                0.411                     0.039                    3.577
# 95502                0.412                     0.039                     3.59
# 95654                 0.41                     0.040                    3.596
# 95806                0.423                     0.039                    3.596
# 95958                0.416                     0.039                    3.588
#
#       DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 95351                      0.104                      2.99
# 95502                      0.102                      2.99
# 95654                      0.102                      2.99
# 95806                      0.107                     2.924
# 95958                      0.102                      2.99
#
#       PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 95351                     3.951                         0.029    1  2018
# 95502                    3.9014                         0.028    1  2018
# 95654                    3.9014                         0.028    1  2018
# 95806                    3.9537                          0.03    1  2018
# 95958                    3.9537                         0.028    2  2018

# %%
gasolina_sp_2018.shape
# Out:
# (52, 20)

# %% [markdown]
# #### **Estatísticas Descritivas**

# %%
gasolina_sp_2018.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                     52.000000            52.000000
# mean                    1610.211538             4.202769
# std                      213.627432             0.180672
# min                      102.000000             3.970000
# 25%                     1639.000000             4.008000
# 50%                     1642.000000             4.202000
# 75%                     1644.000000             4.336250
# max                     1649.000000             4.512000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count              52.000000             52.000000             52.000000
# mean                0.175500              3.671500              4.975750
# std                 0.017955              0.163808              0.211198
# min                 0.150000              3.369000              4.499000
# 25%                 0.159750              3.499000              4.899000
# 50%                 0.173000              3.679000              4.999000
# 75%                 0.189000              3.784000              5.099000
# max                 0.216000              3.969000              5.299000
#
#        COEF DE VARIAÇÃO REVENDA        MÊS     ANO
# count                 52.000000  52.000000    52.0
# mean                   0.041750   6.615385  2018.0
# std                    0.003965   3.470627     0.0
# min                    0.034000   1.000000  2018.0
# 25%                    0.039000   4.000000  2018.0
# 50%                    0.040000   7.000000  2018.0
# 75%                    0.044000   9.250000  2018.0
# max                    0.051000  12.000000  2018.0

# %%
gasolina_sp_2018['PREÇO MÉDIO REVENDA'].describe().to_frame()
# Out:
#        PREÇO MÉDIO REVENDA
# count            52.000000
# mean              4.202769
# std               0.180672
# min               3.970000
# 25%               4.008000
# 50%               4.202000
# 75%               4.336250
# max               4.512000

# %% [markdown]
# ### 7.3 Como os preços da Gasolina Comum e do Etanol em São Paulo variaram em 2018?

# %%
df.query('(PRODUTO == "GASOLINA COMUM" or PRODUTO == "ETANOL HIDRATADO") and ESTADO == "SAO PAULO" and ANO == 2018')
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 95270    2018-01-07  2018-01-13  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 95351    2018-01-07  2018-01-13  SUDESTE  SAO PAULO    GASOLINA COMUM
# 95421    2018-01-14  2018-01-20  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 95502    2018-01-14  2018-01-20  SUDESTE  SAO PAULO    GASOLINA COMUM
# 95573    2018-01-21  2018-01-27  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 102724   2018-12-16  2018-12-22  SUDESTE  SAO PAULO    GASOLINA COMUM
# 102793   2018-12-23  2018-12-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 102874   2018-12-23  2018-12-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 102944   2018-12-30  2019-01-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 103025   2018-12-30  2019-01-05  SUDESTE  SAO PAULO    GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 95270                           1664              R$/l                2.833
# 95351                           1641              R$/l                3.988
# 95421                           1661              R$/l                2.868
# 95502                           1648              R$/l                4.002
# 95573                           1662              R$/l                2.874
# ...                              ...               ...                  ...
# 102724                          1637              R$/l                4.129
# 102793                          1662              R$/l                2.644
# 102874                          1641              R$/l                4.129
# 102944                          1661              R$/l                2.643
# 103025                          1643              R$/l                4.113
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 95270                   0.139                 2.449                 3.399
# 95351                   0.156                 3.499                 4.599
# 95421                   0.134                 2.399                 3.399
# 95502                   0.155                 3.549                 4.499
# 95573                   0.135                 2.399                 3.399
# ...                       ...                   ...                   ...
# 102724                  0.201                 3.699                 5.099
# 102793                  0.163                 2.149                 3.699
# 102874                  0.201                 3.699                 4.999
# 102944                  0.161                 2.259                 3.699
# 103025                  0.201                 3.599                 4.999
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 95270                 0.338                     0.049
# 95351                 0.411                     0.039
# 95421                 0.331                     0.047
# 95502                 0.412                     0.039
# 95573                 0.324                     0.047
# ...                     ...                       ...
# 102724                 0.49                     0.049
# 102793                0.305                     0.062
# 102874                0.484                     0.049
# 102944                0.303                     0.061
# 103025                0.503                     0.049
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 95270                     2.495                      0.092
# 95351                     3.577                      0.104
# 95421                     2.537                      0.087
# 95502                      3.59                      0.102
# 95573                      2.55                      0.095
# ...                         ...                        ...
# 102724                    3.639                       0.11
# 102793                    2.339                      0.094
# 102874                    3.645                      0.107
# 102944                     2.34                      0.097
# 103025                     3.61                        0.1
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 95270                     2.1842                    2.8833
# 95351                       2.99                     3.951
# 95421                       2.26                    2.8471
# 95502                       2.99                    3.9014
# 95573                       1.69                    2.9722
# ...                          ...                       ...
# 102724                      3.35                    3.9892
# 102793                    2.0067                    2.7443
# 102874                      3.35                    3.9892
# 102944                    1.9072                    2.7957
# 103025                      3.35                    3.9585
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 95270                          0.037    1  2018
# 95351                          0.029    1  2018
# 95421                          0.034    1  2018
# 95502                          0.028    1  2018
# 95573                          0.037    1  2018
# ...                              ...  ...   ...
# 102724                          0.03   12  2018
# 102793                          0.04   12  2018
# 102874                         0.029   12  2018
# 102944                         0.041   12  2018
# 103025                         0.028   12  2018
#
# [104 rows x 20 columns]

# %%
lista_de_estados = ["GASOLINA COMUM", "ETANOL HIDRATADO"]
df.query('PRODUTO in @lista_de_estados and ESTADO == "SAO PAULO" and ANO == 2018')
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 95270    2018-01-07  2018-01-13  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 95351    2018-01-07  2018-01-13  SUDESTE  SAO PAULO    GASOLINA COMUM
# 95421    2018-01-14  2018-01-20  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 95502    2018-01-14  2018-01-20  SUDESTE  SAO PAULO    GASOLINA COMUM
# 95573    2018-01-21  2018-01-27  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 102724   2018-12-16  2018-12-22  SUDESTE  SAO PAULO    GASOLINA COMUM
# 102793   2018-12-23  2018-12-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 102874   2018-12-23  2018-12-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 102944   2018-12-30  2019-01-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 103025   2018-12-30  2019-01-05  SUDESTE  SAO PAULO    GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 95270                           1664              R$/l                2.833
# 95351                           1641              R$/l                3.988
# 95421                           1661              R$/l                2.868
# 95502                           1648              R$/l                4.002
# 95573                           1662              R$/l                2.874
# ...                              ...               ...                  ...
# 102724                          1637              R$/l                4.129
# 102793                          1662              R$/l                2.644
# 102874                          1641              R$/l                4.129
# 102944                          1661              R$/l                2.643
# 103025                          1643              R$/l                4.113
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 95270                   0.139                 2.449                 3.399
# 95351                   0.156                 3.499                 4.599
# 95421                   0.134                 2.399                 3.399
# 95502                   0.155                 3.549                 4.499
# 95573                   0.135                 2.399                 3.399
# ...                       ...                   ...                   ...
# 102724                  0.201                 3.699                 5.099
# 102793                  0.163                 2.149                 3.699
# 102874                  0.201                 3.699                 4.999
# 102944                  0.161                 2.259                 3.699
# 103025                  0.201                 3.599                 4.999
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 95270                 0.338                     0.049
# 95351                 0.411                     0.039
# 95421                 0.331                     0.047
# 95502                 0.412                     0.039
# 95573                 0.324                     0.047
# ...                     ...                       ...
# 102724                 0.49                     0.049
# 102793                0.305                     0.062
# 102874                0.484                     0.049
# 102944                0.303                     0.061
# 103025                0.503                     0.049
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 95270                     2.495                      0.092
# 95351                     3.577                      0.104
# 95421                     2.537                      0.087
# 95502                      3.59                      0.102
# 95573                      2.55                      0.095
# ...                         ...                        ...
# 102724                    3.639                       0.11
# 102793                    2.339                      0.094
# 102874                    3.645                      0.107
# 102944                     2.34                      0.097
# 103025                     3.61                        0.1
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 95270                     2.1842                    2.8833
# 95351                       2.99                     3.951
# 95421                       2.26                    2.8471
# 95502                       2.99                    3.9014
# 95573                       1.69                    2.9722
# ...                          ...                       ...
# 102724                      3.35                    3.9892
# 102793                    2.0067                    2.7443
# 102874                      3.35                    3.9892
# 102944                    1.9072                    2.7957
# 103025                      3.35                    3.9585
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 95270                          0.037    1  2018
# 95351                          0.029    1  2018
# 95421                          0.034    1  2018
# 95502                          0.028    1  2018
# 95573                          0.037    1  2018
# ...                              ...  ...   ...
# 102724                          0.03   12  2018
# 102793                          0.04   12  2018
# 102874                         0.029   12  2018
# 102944                         0.041   12  2018
# 103025                         0.028   12  2018
#
# [104 rows x 20 columns]

# %%
gasolina_etanol_sp_2018 = df.query('PRODUTO in ["GASOLINA COMUM", "ETANOL HIDRATADO"] and ESTADO == "SAO PAULO" and ANO == 2018')
gasolina_etanol_sp_2018
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 95270    2018-01-07  2018-01-13  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 95351    2018-01-07  2018-01-13  SUDESTE  SAO PAULO    GASOLINA COMUM
# 95421    2018-01-14  2018-01-20  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 95502    2018-01-14  2018-01-20  SUDESTE  SAO PAULO    GASOLINA COMUM
# 95573    2018-01-21  2018-01-27  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 102724   2018-12-16  2018-12-22  SUDESTE  SAO PAULO    GASOLINA COMUM
# 102793   2018-12-23  2018-12-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 102874   2018-12-23  2018-12-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 102944   2018-12-30  2019-01-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 103025   2018-12-30  2019-01-05  SUDESTE  SAO PAULO    GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 95270                           1664              R$/l                2.833
# 95351                           1641              R$/l                3.988
# 95421                           1661              R$/l                2.868
# 95502                           1648              R$/l                4.002
# 95573                           1662              R$/l                2.874
# ...                              ...               ...                  ...
# 102724                          1637              R$/l                4.129
# 102793                          1662              R$/l                2.644
# 102874                          1641              R$/l                4.129
# 102944                          1661              R$/l                2.643
# 103025                          1643              R$/l                4.113
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 95270                   0.139                 2.449                 3.399
# 95351                   0.156                 3.499                 4.599
# 95421                   0.134                 2.399                 3.399
# 95502                   0.155                 3.549                 4.499
# 95573                   0.135                 2.399                 3.399
# ...                       ...                   ...                   ...
# 102724                  0.201                 3.699                 5.099
# 102793                  0.163                 2.149                 3.699
# 102874                  0.201                 3.699                 4.999
# 102944                  0.161                 2.259                 3.699
# 103025                  0.201                 3.599                 4.999
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 95270                 0.338                     0.049
# 95351                 0.411                     0.039
# 95421                 0.331                     0.047
# 95502                 0.412                     0.039
# 95573                 0.324                     0.047
# ...                     ...                       ...
# 102724                 0.49                     0.049
# 102793                0.305                     0.062
# 102874                0.484                     0.049
# 102944                0.303                     0.061
# 103025                0.503                     0.049
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 95270                     2.495                      0.092
# 95351                     3.577                      0.104
# 95421                     2.537                      0.087
# 95502                      3.59                      0.102
# 95573                      2.55                      0.095
# ...                         ...                        ...
# 102724                    3.639                       0.11
# 102793                    2.339                      0.094
# 102874                    3.645                      0.107
# 102944                     2.34                      0.097
# 103025                     3.61                        0.1
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 95270                     2.1842                    2.8833
# 95351                       2.99                     3.951
# 95421                       2.26                    2.8471
# 95502                       2.99                    3.9014
# 95573                       1.69                    2.9722
# ...                          ...                       ...
# 102724                      3.35                    3.9892
# 102793                    2.0067                    2.7443
# 102874                      3.35                    3.9892
# 102944                    1.9072                    2.7957
# 103025                      3.35                    3.9585
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 95270                          0.037    1  2018
# 95351                          0.029    1  2018
# 95421                          0.034    1  2018
# 95502                          0.028    1  2018
# 95573                          0.037    1  2018
# ...                              ...  ...   ...
# 102724                          0.03   12  2018
# 102793                          0.04   12  2018
# 102874                         0.029   12  2018
# 102944                         0.041   12  2018
# 103025                         0.028   12  2018
#
# [104 rows x 20 columns]

# %%
# considerando os preços do etanol e da gasolina juntos, teremos essas estatística descritivas 
gasolina_etanol_sp_2018['PREÇO MÉDIO REVENDA'].describe().to_frame()
# Out:
#        PREÇO MÉDIO REVENDA
# count           104.000000
# mean              3.457337
# std               0.766239
# min               2.393000
# 25%               2.726000
# 50%               3.431000
# 75%               4.199000
# max               4.512000

# %%
gasolina_etanol_sp_2018.groupby('PRODUTO')['PREÇO MÉDIO REVENDA'].describe()
# Out:
#                   count      mean       std    min     25%    50%      75%  \
# PRODUTO
# ETANOL HIDRATADO   52.0  2.711904  0.141365  2.393  2.6315  2.720  2.83825
# GASOLINA COMUM     52.0  4.202769  0.180672  3.970  4.0080  4.202  4.33625
#
#                     max
# PRODUTO
# ETANOL HIDRATADO  2.892
# GASOLINA COMUM    4.512

# %% [markdown]
# <h2>8. Assuntos para continuar os estudos</h2>
# <hr/>
#
# - join
# - concat
# - plot
# - data cleaning
